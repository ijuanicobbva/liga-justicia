// %% [markdown]
// <a href="https://colab.research.google.com/github/ijuanicobbva/liga-justicia/blob/main/t_nztg_trade_prod_inf_bo_eom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// <center><h1>t_nztg_trade_prod_inf_bo_eom</h1></center>

// %% [markdown]
// ## Package

// %%
object Constants {
    
  //Paths
  val path_taxonomy = "/data/master/ktny/data/t_ktny_catalog_values_taxonomy"
  val path_t_ktny_catalog_values_taxonomy = path_taxonomy
  val path_t_mdco_renta_fija_ope_bis = "/data/master/mdco/data/risk/t_mdco_renta_fija_ope_bis"
  val path_t_mdco_tsi028_contraparte = "/data/master/mdco/data/engineering/t_mdco_tsi028_contraparte"
  val path_t_mdco_products_int_rate_options = "/data/master/mdco/data/retailBusinessBanking/t_mdco_products_int_rate_options"
  val path_t_mdco_forward_int_rate_products = "/data/master/mdco/data/retailBusinessBanking/t_mdco_forward_int_rate_products"
  val path_t_mdco_tsi011_swaps_tasa = "/data/master/mdco/data/risk/t_mdco_tsi011_swaps_tasa"
  val path_t_mdco_tsi013_swaps_iv = "/data/master/mdco/data/risk/t_mdco_tsi013_swaps_iv"
  val path_t_mdco_tsi014_swaps_cre = "/data/master/mdco/data/risk/t_mdco_tsi014_swaps_cre"
  val path_t_mdco_sire_fx_prdt = "/data/master/mdco/data/risk/t_mdco_sire_fx_prdt"
  val path_t_mdco_tsi001_operacion = "/data/master/mdco/data/retailBusinessBanking/t_mdco_tsi001_operacion"
  val path_t_mdco_tsi009_fwd_div = "/data/master/mdco/data/engineering/t_mdco_tsi009_fwd_div"
  val path_t_mdco_derivados_mmoo_bis = "/data/master/mdco/data/risk/t_mdco_derivados_mmoo_bis"
  val path_t_mdco_fin_derv_otc_bis = "/data/master/mdco/data/risk/t_mdco_fin_derv_otc_bis"
  val path_t_mdco_tsi012_swaps_div = "/data/master/mdco/data/engineering/t_mdco_tsi012_swaps_div"
  val path_t_mdco_internal_oper_murex = "/data/master/mdco/data/finance/t_mdco_internal_oper_murex"
  val path_t_mrdc_liquidity_flows_over_swap = "/data/master/mrdc/data/t_mrdc_liquidity_flows_over_swap"
  val path_t_mdco_tsi004_opcion_div = "/data/master/mdco/data/engineering/t_mdco_tsi004_opcion_div"
  val path_t_mdco_liq_over_rate_options = "/data/master/mdco/data/retailBusinessBanking/t_mdco_liq_over_rate_options"
  val path_t_mrdc_tsi016_depositos = "/data/master/mrdc/data/t_mrdc_tsi016_depositos"
  val path_t_mdco_guarantee_core = "/data/master/mdco/data/finance/t_mdco_guarantee_core"
  val output_path = "/data/sandboxes/finz/data/projects/cdd/modelo/nztg/data/t_nztg_trade_prod_inf_bo_eom"
    
  //Constants
  val g_catalog_id = "g_catalog_id"
  val C112 = "C112"
  val gf_catalog_val_id = "gf_catalog_val_id"
  val gf_catlg_field_value_es_desc = "gf_catlg_field_value_es_desc"
  val load_date_partition = "/load_date="
  val operation_deal_front_star_id = "operation_deal_front_star_id"
  val operation_deal_back_star_id = "operation_deal_back_star_id"
  val product_type = "product_type"
  val seller_branch_id = "seller_branch_id"
  val stock_issuance_id = "stock_issuance_id"
  val contract_affiliation_id = "contract_affiliation_id"
  val customer_platform_id = "customer_platform_id"
  val bbva_intergroup_id = "bbva_intergroup_id"
  val customer_corporate_id = "customer_corporate_id"
  val prods = List("CDM", "CDP", "CNG", "LIB", " LMG", "CET", "CVT", "SPR", "GPR", "LMG", "PRB")
  val cutoff_date_partition = "/cutoff_date="
  val oper_origin_app_assigned_id = "oper_origin_app_assigned_id"
  val app_counterparty_id = "app_counterparty_id"
  val counterpart_id = "counterpart_id"
  val coupon_rate_name = "coupon_rate_name"
  val count_convention = "count_convention"
  val calculation_interest_name = "calculation_interest_name"
  val market_operation_type = "market_operation_type"
  val source_application_id = "source_application_id"
  val total_securities_nominal_amount = "total_securities_nominal_amount"
  val coupon_rate_type = "coupon_rate_type"
  val coupon_term_days_number = "coupon_term_days_number"
  val return_interest_rate_per = "return_interest_rate_per"
  val market_operation_settlement_date = "market_operation_settlement_date"
  val current_commitment_amount = "current_commitment_amount"
  val market_operation_start_date = "market_operation_start_date"
  val left = "left"
  val emptyString = ""
  val id = "id"
  val MX = "MX"
  val MX0074 = "MX0074"
  val value = "value"
  val A050 = "A050"
  val A218 = "A218"
  val oneString = "1"
  val tenZero = "0000000000"
  val gf_origin_application_id = "gf_origin_application_id"
  val gf_front_sys_trd_id = "gf_front_sys_trd_id"
  val gf_back_sys_trd_id = "gf_back_sys_trd_id"
  val gf_trd_leg_id = "gf_trd_leg_id"
  val gf_trd_phase_id = "gf_trd_phase_id"
  val gf_trd_leg_adj_eff_date = "gf_trd_leg_adj_eff_date"
  val gf_trd_leg_adj_trmnt_date = "gf_trd_leg_adj_trmnt_date"
  val gf_trd_phase_adj_eff_date = "gf_trd_phase_adj_eff_date"
  val gf_trd_phase_adj_trmnt_date = "gf_trd_phase_adj_trmnt_date"
  val X = "X"
  var nullString: String = _
  val gf_underlying_amount = "gf_underlying_amount"
  val g_call_put_option_type = "g_call_put_option_type"
  val g_exercise_option_type = "g_exercise_option_type"
  val gf_opt_adj_ex_dt_desc = "gf_opt_adj_ex_dt_desc"
  val gf_am_opt_fst_ex_adj_date = "gf_am_opt_fst_ex_adj_date"
  val gf_option_strike_amount = "gf_option_strike_amount"
  val g_interest_rate_type = "g_interest_rate_type"
  val g_option_exercise_freq_type = "g_option_exercise_freq_type"
  val gf_pmt_dt_ref_typo_desc = "gf_pmt_dt_ref_typo_desc"
  val gf_upfront_pmt_amount = "gf_upfront_pmt_amount"
  val F = "F"
  val gf_fixed_rate_per = "gf_fixed_rate_per"
  val g_amortization_frequency_type = "g_amortization_frequency_type"
  val V = "V"
  val gf_float_rt_ini_per = "gf_float_rt_ini_per"
  val gf_current_interest_rate_per = "gf_current_interest_rate_per"
  val gf_net_life_cap_per = "gf_net_life_cap_per"
  val gf_net_life_floor_per = "gf_net_life_floor_per"
  val gf_swap_tenor_months_number = "gf_swap_tenor_months_number"
  val g_day_count_convention_type = "g_day_count_convention_type"
  val g_renewal_frequency_type = "g_renewal_frequency_type"
  val g_reference_index_id = "g_reference_index_id"
  val g_amortization_type = "g_amortization_type"
  val gf_forward_price_amount = "gf_forward_price_amount"
  val gf_fx_forward_exch_rate_amount = "gf_fx_forward_exch_rate_amount"
  val gf_am_opt_lst_ex_adj_date = "gf_am_opt_lst_ex_adj_date"
  val g_interest_pymt_frequency_type = "g_interest_pymt_frequency_type"
  val g_compounding_frequency_type = "g_compounding_frequency_type"
  val counterparty_id = "counterparty_id"
  val market_oper_recv_notional_amount = "market_oper_recv_notional_amount"
  val forward_price_amount = "forward_price_amount"
  val portfolio_investment_name = "portfolio_investment_name"
  val maximum_operation_rate_per = "maximum_operation_rate_per"
  val market_operation_expiry_date = "market_operation_expiry_date"
  val minimum_operation_rate_per = "minimum_operation_rate_per"
  val original_operation_id = "original_operation_id"
  val calculation_base_currency_type = "calculation_base_currency_type"
  val FXLI = "FXLI"
  val subproduct_type = "subproduct_type"
  val counterparty_systems_oper_id = "counterparty_systems_oper_id"
  val warrant_type = "warrant_type"
  val C = "C"
  val CALL = "CALL"
  val P = "P"
  val PUT = "PUT"
  val product_name = "product_name"
  val trading_mark_type = "trading_mark_type"
  val market_oper_pay_notional_amount = "market_oper_pay_notional_amount"
  val option_style_mark_type = "option_style_mark_type"
  val expiration_date = "expiration_date"
  val strike_amount = "strike_amount"
  val underline_reference_type = "underline_reference_type"
  val contract_amount = "contract_amount"
  val F3 = "F3"
  val optProd = List("F5", "F6")
  val fin_derv_leg_exch_int_mark_type = "fin_derv_leg_exch_int_mark_type"
  val operation_stage_number = "operation_stage_number"
  val fin_derv_active_value_start_date = "fin_derv_active_value_start_date"
  val underlying_expiry_date = "underlying_expiry_date"
  val fin_derv_oper_phase_end_date = "fin_derv_oper_phase_end_date"
  val A = "A"
  val value_date = "value_date"
  val fin_derv_leg_flow_frequency_name = "fin_derv_leg_flow_frequency_name"
  val forward_swap_recv_rate_amount = "forward_swap_recv_rate_amount"
  val forward_swap_pay_rate_amount = "forward_swap_pay_rate_amount"
  val fin_derv_oper_phase_start_date = "fin_derv_oper_phase_start_date"
  val operation_repayment_number = "operation_repayment_number"
  val current_rate_coupon_per = "current_rate_coupon_per"
  val CAP = "CAP"
  val IRC = "IRC"
  val IRS = "IRS"
  val gl_account_id = "gl_account_id"
  val gl_account_type = "gl_account_type"
  val H = "H"
  val securities_dealing_desk_name = "securities_dealing_desk_name"
  val portfolio_type = "portfolio_type"
  val contract_register_date = "contract_register_date"
  val operation_sire_assigned_id = "operation_sire_assigned_id"
  val sire_id = "sire_id"
  val source_system_type = "source_system_type"
  val contract_id = "contract_id"
  val settlement_date = "settlement_date"
  val operation_currency_type = "operation_currency_type"
  val financial_product_id = "financial_product_id"
  val operation_parts_number = "operation_parts_number"
  val nominal_value_securities_number = "nominal_value_securities_number"
  val settlement_freq_id = "settlement_freq_id"
  val curr_creditor_interest_type = "curr_creditor_interest_type"
  val operations_date_payment_type = "operations_date_payment_type"
  val purchase_sale_ctrct_amount = "purchase_sale_ctrct_amount"
  val nominal_amount = "nominal_amount"
  val fndr_variable_rate_int_type = "fndr_variable_rate_int_type"
  val prch_sale_option_ir_cvtn_type = "prch_sale_option_ir_cvtn_type"
  val break_clause_frequency_type = "break_clause_frequency_type"
  val swap_legs_id = "swap_legs_id"
  val front_system_number_id = "front_system_number_id"
  val fin_derv_oper_curr_flow_type = "fin_derv_oper_curr_flow_type"
  val FL = "FL"
  val fin_derv_flow_start_date = "fin_derv_flow_start_date"
  val murex_operation_id = "murex_operation_id"
  val period_end_date = "period_end_date"
  val asset_future_price_amount = "asset_future_price_amount"
  val fixed_var_flow_leg_mark_type = "fixed_var_flow_leg_mark_type"
  val inner = "inner"
  val CFC = "CFC"
  val OPCIONES = "OPCIONES"
  val AMERICANA = "AMERICANA"
  val WARRANTN = "WARRANTN"
  val OSW = "OSW"
  val amortization1_id = "amortization1_id"
  val amortization_id = "amortization_id"
  val transaction_product_type = "transaction_product_type"
  val current_operation_nom_amount = "current_operation_nom_amount"
  val forward_rate_amount = "forward_rate_amount"
  val underlying_main_index_id = "underlying_main_index_id"
  val LoansDeposits = "Loans/Deposits"
  val MUREX = "MUREX"
  val gf_front_sys_name = "gf_front_sys_name"
  val gf_dflt_cvr_bk_min_oblg_number = "gf_dflt_cvr_bk_min_oblg_number"
  val g_entific_id = "g_entific_id"
  val gf_trade_region_id = "gf_trade_region_id"
  val gf_local_contract_number_id = "gf_local_contract_number_id"
  val gf_trd_date = "gf_trd_date"
  val gf_trd_strategy_id = "gf_trd_strategy_id"
  val gf_telemaco_trade_id = "gf_telemaco_trade_id"
  val gf_trd_party_payer_recv_type = "gf_trd_party_payer_recv_type"
  val gf_trd_info_period_typo_desc = "gf_trd_info_period_typo_desc"
  val gf_cutoff_date = "gf_cutoff_date"
  val g_entity_id = "g_entity_id"
  val gf_srce_system_entity_id = "gf_srce_system_entity_id"
  val gf_entity_name = "gf_entity_name"
  val gf_front_sys_trd_info_date = "gf_front_sys_trd_info_date"
  val gf_front_sys_trd_info_tme_date = "gf_front_sys_trd_info_tme_date"
  val gf_trd_leg_unadj_eff_date = "gf_trd_leg_unadj_eff_date"
  val gf_trd_leg_eff_dt_bdc_desc = "gf_trd_leg_eff_dt_bdc_desc"
  val gf_trd_leg_unadj_trmnt_date = "gf_trd_leg_unadj_trmnt_date"
  val gf_trd_leg_trmnt_dt_bdc_desc = "gf_trd_leg_trmnt_dt_bdc_desc"
  val gf_trd_phase_unadj_eff_date = "gf_trd_phase_unadj_eff_date"
  val gf_trd_phase_eff_dt_bdc_desc = "gf_trd_phase_eff_dt_bdc_desc"
  val gf_trd_phase_unadj_trmnt_date = "gf_trd_phase_unadj_trmnt_date"
  val gf_trd_phase_trmnt_dt_bdc_desc = "gf_trd_phase_trmnt_dt_bdc_desc"
  val gf_trd_leg_notl_amount = "gf_trd_leg_notl_amount"
  val g_trd_leg_notl_curncy_id = "g_trd_leg_notl_curncy_id"
  val gf_trd_leg_curr_notl_amount = "gf_trd_leg_curr_notl_amount"
  val g_trd_leg_curr_notl_curncy_id = "g_trd_leg_curr_notl_curncy_id"
  val gf_underline_asset_id = "gf_underline_asset_id"
  val g_undly_asset_isin_id = "g_undly_asset_isin_id"
  val gf_undly_asset_name = "gf_undly_asset_name"
  val gf_undly_asset_murex_id = "gf_undly_asset_murex_id"
  val gf_undly_asset_bloomberg_id = "gf_undly_asset_bloomberg_id"
  val gf_undly_secur_label_desc = "gf_undly_secur_label_desc"
  val gf_undly_asset_effective_date = "gf_undly_asset_effective_date"
  val g_undly_curncy_id = "g_undly_curncy_id"
  val gf_udl_divd_valtn_dt_bdc_desc = "gf_udl_divd_valtn_dt_bdc_desc"
  val gf_undly_unadj_divd_valtn_date = "gf_undly_unadj_divd_valtn_date"
  val gf_trd_undly_asset_number = "gf_trd_undly_asset_number"
  val gf_undly_divd_pyt_cond_desc = "gf_undly_divd_pyt_cond_desc"
  val gf_undly_divd_pyt_ratio_per = "gf_undly_divd_pyt_ratio_per"
  val gf_undly_am_depositary_rcpt_id = "gf_undly_am_depositary_rcpt_id"
  val gf_underlying_maturity_date = "gf_underlying_maturity_date"
  val gf_undly_prc_calc_meth_desc = "gf_undly_prc_calc_meth_desc"
  val g_undly_fx_rt_bc_id = "g_undly_fx_rt_bc_id"
  val g_undly_fx_rt_qcncy_id = "g_undly_fx_rt_qcncy_id"
  val gf_undly_prc_fxg_tme_bc_desc = "gf_undly_prc_fxg_tme_bc_desc"
  val gf_undly_prc_fxg_dt_bdc_desc = "gf_undly_prc_fxg_dt_bdc_desc"
  val gf_undly_prc_fxg_tme_date = "gf_undly_prc_fxg_tme_date"
  val gf_undly_prc_fxg_drc_type = "gf_undly_prc_fxg_drc_type"
  val gf_undly_prc_fxg_p_freq_type = "gf_undly_prc_fxg_p_freq_type"
  val gf_undly_prc_fxg_p_freq_d_desc = "gf_undly_prc_fxg_p_freq_d_desc"
  val gf_undly_fxg_p_end_dt_desc = "gf_undly_fxg_p_end_dt_desc"
  val gf_undly_fxg_p_strt_dt_desc = "gf_undly_fxg_p_strt_dt_desc"
  val gf_undly_avg_prc_wgt_fctr_desc = "gf_undly_avg_prc_wgt_fctr_desc"
  val gf_undly_prc_fxg_dt_desc = "gf_undly_prc_fxg_dt_desc"
  val gf_undly_prc_fxg_amt_desc = "gf_undly_prc_fxg_amt_desc"
  val gf_undly_prc_fxg_dt_bc_desc = "gf_undly_prc_fxg_dt_bc_desc"
  val gf_undly_prc_source_id = "gf_undly_prc_source_id"
  val gf_undly_avg_prc_amount = "gf_undly_avg_prc_amount"
  val gf_undly_avg_prc_use_type = "gf_undly_avg_prc_use_type"
  val gf_undly_divd_pmtd_bdc_desc = "gf_undly_divd_pmtd_bdc_desc"
  val gf_undly_unadj_divd_pmt_date = "gf_undly_unadj_divd_pmt_date"
  val gf_undly_divd_amount = "gf_undly_divd_amount"
  val gf_undly_divd_dt_ref_cal_desc = "gf_undly_divd_dt_ref_cal_desc"
  val gf_undly_divd_dt_ref_ofst_id = "gf_undly_divd_dt_ref_ofst_id"
  val gf_undly_divd_pmt_ofst_d_desc = "gf_undly_divd_pmt_ofst_d_desc"
  val gf_undly_divd_reinv_ind_type = "gf_undly_divd_reinv_ind_type"
  val gf_undly_divd_paid_per = "gf_undly_divd_paid_per"
  val gf_undly_divd_reinv_per = "gf_undly_divd_reinv_per"
  val gf_undly_exch_mkt_id = "gf_undly_exch_mkt_id"
  val g_undly_asset_mtm_currency_id = "g_undly_asset_mtm_currency_id"
  val gf_undly_ini_prc_meth_desc = "gf_undly_ini_prc_meth_desc"
  val gf_udl_ini_cln_net_prc_amount = "gf_udl_ini_cln_net_prc_amount"
  val gf_undly_dpsty_rcpt_ind_type = "gf_undly_dpsty_rcpt_ind_type"
  val gf_undly_adj_setl_date = "gf_undly_adj_setl_date"
  val gf_undly_setl_typo_desc = "gf_undly_setl_typo_desc"
  val gf_undly_unadj_setl_date = "gf_undly_unadj_setl_date"
  val gf_undly_undly_id = "gf_undly_undly_id"
  val gf_undly_undly_name = "gf_undly_undly_name"
  val gf_undly_undly_murex_id = "gf_undly_undly_murex_id"
  val gf_undly_undly_bbg_id = "gf_undly_undly_bbg_id"
  val gf_undly_undly_exch_mkt_id = "gf_undly_undly_exch_mkt_id"
  val gf_undly_undly_isin_id = "gf_undly_undly_isin_id"
  val gf_undly_undly_prd_typo_desc = "gf_undly_undly_prd_typo_desc"
  val gf_undly_undly_amount = "gf_undly_undly_amount"
  val g_undly_undly_curncy_id = "g_undly_undly_curncy_id"
  val gf_undly_undly_maty_date = "gf_undly_undly_maty_date"
  val gf_opt_unadj_eff_date = "gf_opt_unadj_eff_date"
  val gf_opt_eff_date_bdc_desc = "gf_opt_eff_date_bdc_desc"
  val gf_opt_adj_eff_date = "gf_opt_adj_eff_date"
  val gf_opt_expiry_cut_name = "gf_opt_expiry_cut_name"
  val g_opt_call_curncy_id = "g_opt_call_curncy_id"
  val gf_opt_call_amount = "gf_opt_call_amount"
  val g_opt_put_curncy_id = "g_opt_put_curncy_id"
  val gf_opt_put_amount = "gf_opt_put_amount"
  val gf_opt_prem_pmt_amount = "gf_opt_prem_pmt_amount"
  val gf_opt_prem_pmt_typo_desc = "gf_opt_prem_pmt_typo_desc"
  val gf_opt_prem_fnl_amount = "gf_opt_prem_fnl_amount"
  val g_opt_prem_pmt_curncy_id = "g_opt_prem_pmt_curncy_id"
  val gf_opt_prem_pmt_meth_desc = "gf_opt_prem_pmt_meth_desc"
  val gf_opt_prem_unadj_pmt_date = "gf_opt_prem_unadj_pmt_date"
  val gf_opt_prem_position_type = "gf_opt_prem_position_type"
  val gf_opt_prem_adj_pmt_date = "gf_opt_prem_adj_pmt_date"
  val gf_opt_prem_pmt_bdc_desc = "gf_opt_prem_pmt_bdc_desc"
  val g_opt_prem_fx_rt_bc_id = "g_opt_prem_fx_rt_bc_id"
  val g_opt_prem_fx_rt_qcncy_id = "g_opt_prem_fx_rt_qcncy_id"
  val gf_opt_prem_fx_rt_amount = "gf_opt_prem_fx_rt_amount"
  val gf_opt_prem_cnv_amount = "gf_opt_prem_cnv_amount"
  val g_opt_prem_cnv_curncy_id = "g_opt_prem_cnv_curncy_id"
  val gf_trd_ini_opt_number = "gf_trd_ini_opt_number"
  val gf_trd_curr_opt_number = "gf_trd_curr_opt_number"
  val gf_undly_unit_opt_number = "gf_undly_unit_opt_number"
  val gf_trd_prem_opt_amount = "gf_trd_prem_opt_amount"
  val g_trd_prem_amt_opt_curncy_id = "g_trd_prem_amt_opt_curncy_id"
  val gf_opt_unadj_ex_dt_desc = "gf_opt_unadj_ex_dt_desc"
  val gf_opt_ex_date_bdc_desc = "gf_opt_ex_date_bdc_desc"
  val gf_opt_earliest_ex_date = "gf_opt_earliest_ex_date"
  val gf_earliest_ex_bus_center_desc = "gf_earliest_ex_bus_center_desc"
  val gf_opt_latst_ex_date = "gf_opt_latst_ex_date"
  val gf_latst_ex_bus_center_desc = "gf_latst_ex_bus_center_desc"
  val gf_am_opt_fst_ex_unadj_date = "gf_am_opt_fst_ex_unadj_date"
  val gf_am_opt_fst_ex_dt_bdc_desc = "gf_am_opt_fst_ex_dt_bdc_desc"
  val gf_am_opt_lst_ex_unadj_date = "gf_am_opt_lst_ex_unadj_date"
  val gf_am_opt_lst_ex_dt_bdc_desc = "gf_am_opt_lst_ex_dt_bdc_desc"
  val gf_ex_folup_cnfrm_ind_type = "gf_ex_folup_cnfrm_ind_type"
  val gf_option_fbck_ex_ind_type = "gf_option_fbck_ex_ind_type"
  val gf_cmpnd_opt_unadj_ex_date = "gf_cmpnd_opt_unadj_ex_date"
  val gf_cmpnd_opt_ex_dt_bdc_desc = "gf_cmpnd_opt_ex_dt_bdc_desc"
  val gf_cmpnd_opt_adj_ex_date = "gf_cmpnd_opt_adj_ex_date"
  val gf_cmpnd_opt_type = "gf_cmpnd_opt_type"
  val gf_cmpnd_opt_strike_amount = "gf_cmpnd_opt_strike_amount"
  val gf_opt_auto_ex_ind_type = "gf_opt_auto_ex_ind_type"
  val gf_dig_opt_ind_type = "gf_dig_opt_ind_type"
  val gf_opt_strk_quote_basis_desc = "gf_opt_strk_quote_basis_desc"
  val g_opt_strk_curncy_id = "g_opt_strk_curncy_id"
  val gf_opt_strk_quotn_type = "gf_opt_strk_quotn_type"
  val gf_opt_pyt_amount = "gf_opt_pyt_amount"
  val gf_opt_pyt_frmul_desc = "gf_opt_pyt_frmul_desc"
  val g_opt_pyt_curncy_id = "g_opt_pyt_curncy_id"
  val g_opt_pyt_fx_rt_bc_id = "g_opt_pyt_fx_rt_bc_id"
  val g_opt_pyt_fx_rt_qcncy_id = "g_opt_pyt_fx_rt_qcncy_id"
  val gf_dig_opt_pyt_styl_desc = "gf_dig_opt_pyt_styl_desc"
  val gf_dig_opt_strk_cond_desc = "gf_dig_opt_strk_cond_desc"
  val gf_opt_cond_fnl_sessn_ind_type = "gf_opt_cond_fnl_sessn_ind_type"
  val gf_dig_opt_strk_drctn_desc = "gf_dig_opt_strk_drctn_desc"
  val gf_dig_opt_sec_strk_drctn_desc = "gf_dig_opt_sec_strk_drctn_desc"
  val gf_dig_opt_sec_strk_cond_desc = "gf_dig_opt_sec_strk_cond_desc"
  val gf_dig_opt_sec_strk_amount = "gf_dig_opt_sec_strk_amount"
  val gf_barrier_value_amount = "gf_barrier_value_amount"
  val gf_opt_barrier_typo_desc = "gf_opt_barrier_typo_desc"
  val gf_opt_barrier_scope_desc = "gf_opt_barrier_scope_desc"
  val gf_opt_brr_fnl_sessn_ind_type = "gf_opt_brr_fnl_sessn_ind_type"
  val gf_opt_brr_styl_desc = "gf_opt_brr_styl_desc"
  val gf_opt_brr_dirctn_desc = "gf_opt_brr_dirctn_desc"
  val gf_brr_undly_prc_fxg_srce_id = "gf_brr_undly_prc_fxg_srce_id"
  val g_brr_undly_fx_rt_bc_id = "g_brr_undly_fx_rt_bc_id"
  val g_brr_undly_fx_rt_qcncy_id = "g_brr_undly_fx_rt_qcncy_id"
  val gf_brr_undly_prc_fxg_dt_desc = "gf_brr_undly_prc_fxg_dt_desc"
  val gf_brr_undly_prc_fxg_end_date = "gf_brr_undly_prc_fxg_end_date"
  val gf_brr_undly_prc_fxg_strt_date = "gf_brr_undly_prc_fxg_strt_date"
  val gf_brr_undly_prc_fxg_freq_type = "gf_brr_undly_prc_fxg_freq_type"
  val gf_opt_brr_rbt_amount = "gf_opt_brr_rbt_amount"
  val g_opt_brr_rbt_curncy_id = "g_opt_brr_rbt_curncy_id"
  val gf_opt_brr_rbt_typo_desc = "gf_opt_brr_rbt_typo_desc"
  val gf_opt_sec_brr_val_amount = "gf_opt_sec_brr_val_amount"
  val gf_opt_sec_brr_typo_desc = "gf_opt_sec_brr_typo_desc"
  val gf_opt_sec_brr_dirctn_desc = "gf_opt_sec_brr_dirctn_desc"
  val gf_opt_sec_brr_scope_desc = "gf_opt_sec_brr_scope_desc"
  val gf_opt_sec_brr_styl_desc = "gf_opt_sec_brr_styl_desc"
  val gf_opt_sec_brr_fxg_end_date = "gf_opt_sec_brr_fxg_end_date"
  val gf_opt_sec_brr_fxg_strt_date = "gf_opt_sec_brr_fxg_strt_date"
  val gf_opt_sec_brr_rbt_amount = "gf_opt_sec_brr_rbt_amount"
  val g_opt_sec_brr_rbt_curncy_id = "g_opt_sec_brr_rbt_curncy_id"
  val gf_opt_sec_brr_rbt_typo_desc = "gf_opt_sec_brr_rbt_typo_desc"
  val gf_opt_thd_brr_val_amount = "gf_opt_thd_brr_val_amount"
  val gf_opt_thd_brr_typo_desc = "gf_opt_thd_brr_typo_desc"
  val gf_opt_thd_brr_dirctn_desc = "gf_opt_thd_brr_dirctn_desc"
  val gf_opt_thd_brr_scope_desc = "gf_opt_thd_brr_scope_desc"
  val gf_opt_thd_brr_styl_desc = "gf_opt_thd_brr_styl_desc"
  val gf_opt_thd_brr_fxg_end_date = "gf_opt_thd_brr_fxg_end_date"
  val gf_opt_thd_brr_fxg_strt_date = "gf_opt_thd_brr_fxg_strt_date"
  val gf_opt_thd_brr_rbt_amount = "gf_opt_thd_brr_rbt_amount"
  val g_opt_thd_brr_rbt_curncy_id = "g_opt_thd_brr_rbt_curncy_id"
  val gf_opt_thd_brr_rbt_typo_desc = "gf_opt_thd_brr_rbt_typo_desc"
  val gf_sec_opt_brr_val_amount = "gf_sec_opt_brr_val_amount"
  val gf_sec_opt_brr_typo_desc = "gf_sec_opt_brr_typo_desc"
  val gf_sec_opt_brr_scope_desc = "gf_sec_opt_brr_scope_desc"
  val gf_sec_opt_brr_sessn_ind_type = "gf_sec_opt_brr_sessn_ind_type"
  val gf_sec_opt_brr_styl_desc = "gf_sec_opt_brr_styl_desc"
  val gf_secop_brr_fxg_end_date = "gf_secop_brr_fxg_end_date"
  val gf_secop_brr_fxg_strt_date = "gf_secop_brr_fxg_strt_date"
  val gf_secop_brr_prc_fxg_freq_type = "gf_secop_brr_prc_fxg_freq_type"
  val gf_sec_opt_brr_dirctn_desc = "gf_sec_opt_brr_dirctn_desc"
  val gf_sec_opt_brr_rbt_amount = "gf_sec_opt_brr_rbt_amount"
  val g_sec_opt_brr_rbt_curncy_id = "g_sec_opt_brr_rbt_curncy_id"
  val gf_sec_opt_brr_rbt_typo_desc = "gf_sec_opt_brr_rbt_typo_desc"
  val gf_sec_opt_sec_brr_val_amount = "gf_sec_opt_sec_brr_val_amount"
  val gf_sec_opt_sec_brr_typo_desc = "gf_sec_opt_sec_brr_typo_desc"
  val gf_sec_opt_sec_brr_dirctn_desc = "gf_sec_opt_sec_brr_dirctn_desc"
  val gf_sec_opt_sec_brr_scope_desc = "gf_sec_opt_sec_brr_scope_desc"
  val gf_sec_opt_sec_brr_styl_desc = "gf_sec_opt_sec_brr_styl_desc"
  val gf_sec_opt_sec_brr_end_date = "gf_sec_opt_sec_brr_end_date"
  val gf_sec_opt_sec_brr_strt_date = "gf_sec_opt_sec_brr_strt_date"
  val gf_sec_opt_sec_brr_rbt_amount = "gf_sec_opt_sec_brr_rbt_amount"
  val g_secop_sec_brr_rbt_curncy_id = "g_secop_sec_brr_rbt_curncy_id"
  val gf_sec_opt_sec_brr_rbt_desc = "gf_sec_opt_sec_brr_rbt_desc"
  val gf_sec_opt_thd_brr_val_amount = "gf_sec_opt_thd_brr_val_amount"
  val gf_sec_opt_thd_brr_typo_desc = "gf_sec_opt_thd_brr_typo_desc"
  val gf_sec_opt_thd_brr_dirctn_desc = "gf_sec_opt_thd_brr_dirctn_desc"
  val gf_sec_opt_thd_brr_scope_desc = "gf_sec_opt_thd_brr_scope_desc"
  val gf_sec_opt_thd_brr_styl_desc = "gf_sec_opt_thd_brr_styl_desc"
  val gf_sec_opt_thd_brr_end_date = "gf_sec_opt_thd_brr_end_date"
  val gf_sec_opt_thd_brr_strt_date = "gf_sec_opt_thd_brr_strt_date"
  val gf_sec_opt_thd_brr_rbt_amount = "gf_sec_opt_thd_brr_rbt_amount"
  val g_secop_thd_brr_rbt_curncy_id = "g_secop_thd_brr_rbt_curncy_id"
  val gf_sec_opt_thd_brr_rbt_desc = "gf_sec_opt_thd_brr_rbt_desc"
  val gf_opt_flt_strk_prc_fxg_date = "gf_opt_flt_strk_prc_fxg_date"
  val g_opt_flt_strk_fx_rt_bc_id = "g_opt_flt_strk_fx_rt_bc_id"
  val g_opt_flt_strk_fx_rt_qcncy_id = "g_opt_flt_strk_fx_rt_qcncy_id"
  val gf_opt_flt_strk_prc_sprd_per = "gf_opt_flt_strk_prc_sprd_per"
  val gf_opt_flt_strk_sprd_amount = "gf_opt_flt_strk_sprd_amount"
  val gf_fwd_strt_opt_styl_desc = "gf_fwd_strt_opt_styl_desc"
  val gf_fwd_strt_opt_strk_per = "gf_fwd_strt_opt_strk_per"
  val gf_fwd_strt_opt_strt_date = "gf_fwd_strt_opt_strt_date"
  val gf_warrant_label_desc = "gf_warrant_label_desc"
  val gf_warrant_quantity_number = "gf_warrant_quantity_number"
  val gf_accrl_opt_typo_desc = "gf_accrl_opt_typo_desc"
  val g_fst_stp_opt_call_curncy_id = "g_fst_stp_opt_call_curncy_id"
  val g_fst_stp_opt_put_curncy_id = "g_fst_stp_opt_put_curncy_id"
  val gf_fst_stp_opt_notl_amount = "gf_fst_stp_opt_notl_amount"
  val g_fst_stp_opt_notl_curncy_id = "g_fst_stp_opt_notl_curncy_id"
  val gf_fst_stp_opt_strk_quot_desc = "gf_fst_stp_opt_strk_quot_desc"
  val gf_fst_stp_opt_strk_amt_desc = "gf_fst_stp_opt_strk_amt_desc"
  val gf_fst_stp_opt_strk_eff_desc = "gf_fst_stp_opt_strk_eff_desc"
  val gf_fst_stp_opt_strk_cond_desc = "gf_fst_stp_opt_strk_cond_desc"
  val gf_fst_stp_opt_eff_dt_desc = "gf_fst_stp_opt_eff_dt_desc"
  val gf_fstp_opt_expr_dt_desc = "gf_fstp_opt_expr_dt_desc"
  val gf_fstp_opt_nmnl_wgt_amt_desc = "gf_fstp_opt_nmnl_wgt_amt_desc"
  val gf_fstp_opt_sec_strk_amt_desc = "gf_fstp_opt_sec_strk_amt_desc"
  val gf_fstp_opt_sec_strk_efdt_desc = "gf_fstp_opt_sec_strk_efdt_desc"
  val gf_fstp_opt_sec_strk_cond_desc = "gf_fstp_opt_sec_strk_cond_desc"
  val g_sec_stp_opt_call_curncy_id = "g_sec_stp_opt_call_curncy_id"
  val g_sec_stp_opt_put_curncy_id = "g_sec_stp_opt_put_curncy_id"
  val gf_sec_stp_opt_notl_amount = "gf_sec_stp_opt_notl_amount"
  val g_sec_stp_opt_notl_curncy_id = "g_sec_stp_opt_notl_curncy_id"
  val gf_sec_stp_opt_strk_quot_desc = "gf_sec_stp_opt_strk_quot_desc"
  val gf_sec_stp_opt_strk_amt_desc = "gf_sec_stp_opt_strk_amt_desc"
  val gf_sec_stp_opt_strk_eff_desc = "gf_sec_stp_opt_strk_eff_desc"
  val gf_sec_stp_opt_strk_cond_desc = "gf_sec_stp_opt_strk_cond_desc"
  val gf_sec_stp_opt_sec_strk_desc = "gf_sec_stp_opt_sec_strk_desc"
  val gf_sec_stp_sec_strk_efdt_desc = "gf_sec_stp_sec_strk_efdt_desc"
  val gf_sec_stp_sec_strk_cond_desc = "gf_sec_stp_sec_strk_cond_desc"
  val gf_accrl_rgn_calc_type = "gf_accrl_rgn_calc_type"
  val gf_accrl_rgn_upbnd_dirctn_desc = "gf_accrl_rgn_upbnd_dirctn_desc"
  val gf_accrl_rgn_upbnd_val_desc = "gf_accrl_rgn_upbnd_val_desc"
  val gf_accrl_rgn_lwbnd_dirctn_desc = "gf_accrl_rgn_lwbnd_dirctn_desc"
  val gf_accrl_rgn_lwbnd_val_desc = "gf_accrl_rgn_lwbnd_val_desc"
  val gf_accrl_rgn_fctr_desc = "gf_accrl_rgn_fctr_desc"
  val gf_accrl_rgn_notl_curncy_desc = "gf_accrl_rgn_notl_curncy_desc"
  val gf_accrl_rgn_notl_amount_desc = "gf_accrl_rgn_notl_amount_desc"
  val gf_opt_accr_rgn_notl_wgt_desc = "gf_opt_accr_rgn_notl_wgt_desc"
  val gf_accrl_opt_accr_amount = "gf_accrl_opt_accr_amount"
  val g_accrl_opt_accr_curncy_id = "g_accrl_opt_accr_curncy_id"
  val gf_evgn_opt_ext_pd_type = "gf_evgn_opt_ext_pd_type"
  val gf_cncl_opt_fee_adj_pmt_date = "gf_cncl_opt_fee_adj_pmt_date"
  val gf_cncl_opt_fee_unadj_pmt_date = "gf_cncl_opt_fee_unadj_pmt_date"
  val gf_cncl_opt_fee_pmtd_bdc_desc = "gf_cncl_opt_fee_pmtd_bdc_desc"
  val gf_cncl_opt_brm_ex_fee_desc = "gf_cncl_opt_brm_ex_fee_desc"
  val gf_cncl_opt_brm_noex_fee_desc = "gf_cncl_opt_brm_noex_fee_desc"
  val gf_cncl_opt_brm_ex_unadj_desc = "gf_cncl_opt_brm_ex_unadj_desc"
  val gf_cncl_opt_brm_ex_adj_desc = "gf_cncl_opt_brm_ex_adj_desc"
  val gf_cncl_opt_brm_ex_dt_bdc_desc = "gf_cncl_opt_brm_ex_dt_bdc_desc"
  val gf_cncl_opt_brm_ex_dt_bc_desc = "gf_cncl_opt_brm_ex_dt_bc_desc"
  val gf_cncl_opt_ex_fee_amount = "gf_cncl_opt_ex_fee_amount"
  val gf_cncl_opt_non_ex_fee_amount = "gf_cncl_opt_non_ex_fee_amount"
  val gf_cncl_opt_am_ex_adj_date = "gf_cncl_opt_am_ex_adj_date"
  val gf_cncl_opt_am_ex_dt_bdc_desc = "gf_cncl_opt_am_ex_dt_bdc_desc"
  val gf_cncl_opt_am_ex_unadj_date = "gf_cncl_opt_am_ex_unadj_date"
  val gf_cncl_opt_erlst_ex_dt_bc_id = "gf_cncl_opt_erlst_ex_dt_bc_id"
  val gf_cncl_opt_erlst_ex_date = "gf_cncl_opt_erlst_ex_date"
  val gf_cncl_opt_expir_dt_bdc_desc = "gf_cncl_opt_expir_dt_bdc_desc"
  val gf_cncl_opt_expir_adj_date = "gf_cncl_opt_expir_adj_date"
  val gf_cncl_opt_expir_time_bc_desc = "gf_cncl_opt_expir_time_bc_desc"
  val gf_cncl_opt_expir_time_date = "gf_cncl_opt_expir_time_date"
  val gf_cncl_opt_both_ex_ind_type = "gf_cncl_opt_both_ex_ind_type"
  val g_pmt_curncy_id = "g_pmt_curncy_id"
  val gf_pmt_amount = "gf_pmt_amount"
  val gf_pmt_meth_typo_desc = "gf_pmt_meth_typo_desc"
  val gf_unadj_pmt_date = "gf_unadj_pmt_date"
  val gf_pmt_dt_ref_cal_typo_desc = "gf_pmt_dt_ref_cal_typo_desc"
  val gf_adjusted_pmt_date = "gf_adjusted_pmt_date"
  val gf_pmt_dt_bdc_typo_desc = "gf_pmt_dt_bdc_typo_desc"
  val gf_pmt_dt_bus_center_id = "gf_pmt_dt_bus_center_id"
  val gf_pmt_dt_frequency_type = "gf_pmt_dt_frequency_type"
  val gf_pmt_dt_roll_cvtn_typo_desc = "gf_pmt_dt_roll_cvtn_typo_desc"
  val gf_pmt_dt_ofst_id = "gf_pmt_dt_ofst_id"
  val gf_pmt_dt_ofst_day_typo_desc = "gf_pmt_dt_ofst_day_typo_desc"
  val gf_pmt_disc_float_rt_index_id = "gf_pmt_disc_float_rt_index_id"
  val gf_pmt_disc_rt_per = "gf_pmt_disc_rt_per"
  val gf_pmt_disc_typology_desc = "gf_pmt_disc_typology_desc"
  val gf_upfront_pmt_date = "gf_upfront_pmt_date"
  val g_upfront_pmt_curncy_id = "g_upfront_pmt_curncy_id"
  val gf_first_initial_payment_date = "gf_first_initial_payment_date"
  val gf_ini_pmt_amount = "gf_ini_pmt_amount"
  val g_ini_pmt_curncy_id = "g_ini_pmt_curncy_id"
  val gf_flt_rt_calc_meth_typo_desc = "gf_flt_rt_calc_meth_typo_desc"
  val gf_rt_calc_meth_label_desc = "gf_rt_calc_meth_label_desc"
  val gf_flt_indx_calc_frmul_desc = "gf_flt_indx_calc_frmul_desc"
  val gf_cmpnd_meth_typology_desc = "gf_cmpnd_meth_typology_desc"
  val gf_bps_sales_margin_amount = "gf_bps_sales_margin_amount"
  val gf_sales_margin_yield_per = "gf_sales_margin_yield_per"
  val gf_calc_basis_id = "gf_calc_basis_id"
  val gf_calc_p_days_number = "gf_calc_p_days_number"
  val gf_fst_calc_p_unadj_start_date = "gf_fst_calc_p_unadj_start_date"
  val gf_fst_calc_p_strt_dt_bdc_desc = "gf_fst_calc_p_strt_dt_bdc_desc"
  val gf_fst_calc_p_adj_start_date = "gf_fst_calc_p_adj_start_date"
  val gf_first_reg_calc_p_start_date = "gf_first_reg_calc_p_start_date"
  val gf_last_reg_calc_p_end_date = "gf_last_reg_calc_p_end_date"
  val gf_calc_p_bdc_typo_desc = "gf_calc_p_bdc_typo_desc"
  val gf_calc_p_dt_bc_desc = "gf_calc_p_dt_bc_desc"
  val gf_calc_p_roll_cvtn_type = "gf_calc_p_roll_cvtn_type"
  val gf_stub_calc_p_dist_meth_desc = "gf_stub_calc_p_dist_meth_desc"
  val gf_calc_p_frequency_type = "gf_calc_p_frequency_type"
  val gf_calc_p_frequency_desc = "gf_calc_p_frequency_desc"
  val gf_flt_rt_fxg_dt_ref_cal_desc = "gf_flt_rt_fxg_dt_ref_cal_desc"
  val gf_flt_rt_fxg_ref_dt_ofst_id = "gf_flt_rt_fxg_ref_dt_ofst_id"
  val gf_flt_rt_fxg_dt_ofst_day_desc = "gf_flt_rt_fxg_dt_ofst_day_desc"
  val gf_flt_rt_fxg_dt_bdc_desc = "gf_flt_rt_fxg_dt_bdc_desc"
  val gf_flt_rt_fxg_dt_bus_cntr_id = "gf_flt_rt_fxg_dt_bus_cntr_id"
  val gf_flt_rt_fxg_dt_freq_type = "gf_flt_rt_fxg_dt_freq_type"
  val gf_flt_rt_fxg_drc_cvtn_type = "gf_flt_rt_fxg_drc_cvtn_type"
  val gf_amort_formula_desc = "gf_amort_formula_desc"
  val gf_amort_notl_chng_per = "gf_amort_notl_chng_per"
  val gf_amort_notl_chng_relval_desc = "gf_amort_notl_chng_relval_desc"
  val gf_amort_notl_chng_amount = "gf_amort_notl_chng_amount"
  val gf_amort_start_date = "gf_amort_start_date"
  val gf_last_amortized_notl_amount = "gf_last_amortized_notl_amount"
  val gf_amort_incl_mrgn_ind_type = "gf_amort_incl_mrgn_ind_type"
  val gf_amort_dt_cpt_chg_ind_type = "gf_amort_dt_cpt_chg_ind_type"
  val gf_amort_int_reinv_ind_type = "gf_amort_int_reinv_ind_type"
  val gf_amort_int_reinv_frac_per = "gf_amort_int_reinv_frac_per"
  val gf_int_amt_full_pmt_ind_type = "gf_int_amt_full_pmt_ind_type"
  val gf_amort_ini_fixed_amount = "gf_amort_ini_fixed_amount"
  val g_amort_ini_fixed_curncy_id = "g_amort_ini_fixed_curncy_id"
  val gf_float_rt_index_id = "gf_float_rt_index_id"
  val gf_float_rt_index_tenor_id = "gf_float_rt_index_tenor_id"
  val gf_undly_float_rt_indx_id = "gf_undly_float_rt_indx_id"
  val gf_undly_float_rt_indx_tnr_id = "gf_undly_float_rt_indx_tnr_id"
  val gf_float_rt_indx_desc = "gf_float_rt_indx_desc"
  val gf_float_rt_mult_ini_number = "gf_float_rt_mult_ini_number"
  val gf_tl_disper_intrnl_calc_per = "gf_tl_disper_intrnl_calc_per"
  val gf_int_rate_spread_margin_per = "gf_int_rate_spread_margin_per"
  val gf_float_rt_rnd_type = "gf_float_rt_rnd_type"
  val gf_float_rt_rnd_precn_number = "gf_float_rt_rnd_precn_number"
  val g_float_rt_indx_curncy_id = "g_float_rt_indx_curncy_id"
  val gf_float_rt_indx_source_id = "gf_float_rt_indx_source_id"
  val gf_digital_payoff_typo_desc = "gf_digital_payoff_typo_desc"
  val gf_payout_amount = "gf_payout_amount"
  val g_payout_curncy_id = "g_payout_curncy_id"
  val gf_buy_strike_price_amount = "gf_buy_strike_price_amount"
  val gf_sell_strike_price_amount = "gf_sell_strike_price_amount"
  val gf_neg_float_rt_treat_desc = "gf_neg_float_rt_treat_desc"
  val gf_pyt_floor_rt_incl_ind_type = "gf_pyt_floor_rt_incl_ind_type"
  val gf_payout_cap_rt_incl_ind_type = "gf_payout_cap_rt_incl_ind_type"
  val gf_inflation_indx_type_name = "gf_inflation_indx_type_name"
  val gf_infltn_rt_basis_ind_type = "gf_infltn_rt_basis_ind_type"
  val gf_float_rt_payout_frmul_desc = "gf_float_rt_payout_frmul_desc"
  val gf_infltn_rt_calc_iplt_desc = "gf_infltn_rt_calc_iplt_desc"
  val gf_float_rt_indx_bk_frmul_desc = "gf_float_rt_indx_bk_frmul_desc"
  val gf_float_rt_payout_typo_desc = "gf_float_rt_payout_typo_desc"
  val gf_ini_stub_calc_p_indx_id = "gf_ini_stub_calc_p_indx_id"
  val gf_ini_stub_calc_p_indx_tnr_id = "gf_ini_stub_calc_p_indx_tnr_id"
  val gf_ini_stub_calc_p_sec_indx_id = "gf_ini_stub_calc_p_sec_indx_id"
  val gf_ini_stub_p_sec_indx_tnr_id = "gf_ini_stub_p_sec_indx_tnr_id"
  val gf_final_stub_calc_p_indx_id = "gf_final_stub_calc_p_indx_id"
  val gf_fnl_stub_calc_p_indx_tnr_id = "gf_fnl_stub_calc_p_indx_tnr_id"
  val gf_fnl_stub_calc_p_sec_indx_id = "gf_fnl_stub_calc_p_sec_indx_id"
  val gf_fnl_stub_p_sec_indx_tnr_id = "gf_fnl_stub_p_sec_indx_tnr_id"
  val gf_trd_ini_cpt_exch_ind_type = "gf_trd_ini_cpt_exch_ind_type"
  val gf_trd_fnl_cpt_exch_ind_type = "gf_trd_fnl_cpt_exch_ind_type"
  val gf_trd_intcap_exch_ind_type = "gf_trd_intcap_exch_ind_type"
  val g_int_flow_curncy_id = "g_int_flow_curncy_id"
  val g_ini_cpt_exch_curncy_id = "g_ini_cpt_exch_curncy_id"
  val g_intcap_exch_curncy_id = "g_intcap_exch_curncy_id"
  val g_fnl_capital_exch_curncy_id = "g_fnl_capital_exch_curncy_id"
  val gf_ini_cpt_fx_fxg_dt_ofst_id = "gf_ini_cpt_fx_fxg_dt_ofst_id"
  val gf_ini_cpt_fx_fxg_dt_ofst_desc = "gf_ini_cpt_fx_fxg_dt_ofst_desc"
  val gf_ini_cpt_fx_fxg_dt_bdc_desc = "gf_ini_cpt_fx_fxg_dt_bdc_desc"
  val gf_ini_cpt_fx_fxg_dt_bc_desc = "gf_ini_cpt_fx_fxg_dt_bc_desc"
  val gf_ini_cpt_fx_fxg_dt_cal_desc = "gf_ini_cpt_fx_fxg_dt_cal_desc"
  val gf_ini_cpt_fx_settl_rt_srce_id = "gf_ini_cpt_fx_settl_rt_srce_id"
  val gf_intcap_fx_fxg_dt_ofst_id = "gf_intcap_fx_fxg_dt_ofst_id"
  val gf_intcap_fx_fxg_dt_ofst_desc = "gf_intcap_fx_fxg_dt_ofst_desc"
  val gf_intcap_fx_fxg_dt_bdc_desc = "gf_intcap_fx_fxg_dt_bdc_desc"
  val gf_intcap_fx_fxg_dt_bc_desc = "gf_intcap_fx_fxg_dt_bc_desc"
  val gf_intcap_fx_fxg_dt_cal_desc = "gf_intcap_fx_fxg_dt_cal_desc"
  val gf_intcap_fx_rt_settl_srce_id = "gf_intcap_fx_rt_settl_srce_id"
  val gf_fnl_cpt_fx_fxg_dt_ofst_id = "gf_fnl_cpt_fx_fxg_dt_ofst_id"
  val gf_fnl_cpt_fx_fxg_dt_ofst_desc = "gf_fnl_cpt_fx_fxg_dt_ofst_desc"
  val gf_fnl_cpt_fx_fxg_dt_bdc_desc = "gf_fnl_cpt_fx_fxg_dt_bdc_desc"
  val gf_fnl_cpt_fx_fxg_dt_bc_id = "gf_fnl_cpt_fx_fxg_dt_bc_id"
  val gf_fnl_cpt_fx_fxg_dt_cal_desc = "gf_fnl_cpt_fx_fxg_dt_cal_desc"
  val gf_fnl_cpt_fx_rt_settl_srce_id = "gf_fnl_cpt_fx_rt_settl_srce_id"
  val gf_int_flw_fx_fxg_dt_ofst_id = "gf_int_flw_fx_fxg_dt_ofst_id"
  val gf_int_flw_fx_fxg_dt_ofst_desc = "gf_int_flw_fx_fxg_dt_ofst_desc"
  val gf_int_flw_fx_fxg_dt_bdc_desc = "gf_int_flw_fx_fxg_dt_bdc_desc"
  val gf_int_flw_fx_fxg_dt_bc_desc = "gf_int_flw_fx_fxg_dt_bc_desc"
  val gf_int_flw_fx_fxg_dt_cal_desc = "gf_int_flw_fx_fxg_dt_cal_desc"
  val gf_int_flw_settl_rt_srce_id = "gf_int_flw_settl_rt_srce_id"
  val gf_valtn_fnl_prc_meth_desc = "gf_valtn_fnl_prc_meth_desc"
  val gf_valtn_fnl_prc_dt_bdc_desc = "gf_valtn_fnl_prc_dt_bdc_desc"
  val gf_valtn_fnl_prc_dt_ref_bc_id = "gf_valtn_fnl_prc_dt_ref_bc_id"
  val gf_valtn_fnl_prc_dt_ofst_id = "gf_valtn_fnl_prc_dt_ofst_id"
  val gf_valtn_fnl_prc_ofst_day_desc = "gf_valtn_fnl_prc_ofst_day_desc"
  val gf_adj_unit_prd_cond_desc = "gf_adj_unit_prd_cond_desc"
  val gf_return_swap_typo_desc = "gf_return_swap_typo_desc"
  val gf_tax_cr_divd_amount = "gf_tax_cr_divd_amount"
  val gf_tax_cr_dt_ref_cal_desc = "gf_tax_cr_dt_ref_cal_desc"
  val gf_tax_cr_dt_ref_ofst_id = "gf_tax_cr_dt_ref_ofst_id"
  val gf_tax_cr_dt_ofst_day_desc = "gf_tax_cr_dt_ofst_day_desc"
  val gf_tax_cr_reinv_ind_type = "gf_tax_cr_reinv_ind_type"
  val gf_tax_cr_paid_per = "gf_tax_cr_paid_per"
  val gf_tax_cr_reinv_per = "gf_tax_cr_reinv_per"
  val gf_settl_amount = "gf_settl_amount"
  val gf_settl_typo_desc = "gf_settl_typo_desc"
  val g_settl_curncy_id = "g_settl_curncy_id"
  val g_settl_fx_rt_bc_id = "g_settl_fx_rt_bc_id"
  val g_settl_fx_rt_qcncy_id = "g_settl_fx_rt_qcncy_id"
  val gf_settl_fx_rt_amount = "gf_settl_fx_rt_amount"
  val gf_settl_fx_rt_fxg_date = "gf_settl_fx_rt_fxg_date"
  val g_quanto_opt_fx_rt_bc_id = "g_quanto_opt_fx_rt_bc_id"
  val g_quanto_opt_fx_rt_qcncy_id = "g_quanto_opt_fx_rt_qcncy_id"
  val gf_quanto_opt_fx_rt_amount = "gf_quanto_opt_fx_rt_amount"
  val gf_setl_calc_cvtn_desc = "gf_setl_calc_cvtn_desc"
  val gf_setl_clean_prc_amount = "gf_setl_clean_prc_amount"
  val gf_setl_dirty_prc_amount = "gf_setl_dirty_prc_amount"
  val gf_settl_limit_date = "gf_settl_limit_date"
  val gf_unadj_settl_date = "gf_unadj_settl_date"
  val gf_adj_settl_date = "gf_adj_settl_date"
  val gf_settl_bdc_desc = "gf_settl_bdc_desc"
  val gf_settl_pmt_meth_typo_desc = "gf_settl_pmt_meth_typo_desc"
  val gf_setl_csh_transf_amount = "gf_setl_csh_transf_amount"
  val g_csh_setl_transf_curncy_id = "g_csh_setl_transf_curncy_id"
  val gf_setl_phys_transf_ast_id = "gf_setl_phys_transf_ast_id"
  val gf_setl_phys_transf_ast_number = "gf_setl_phys_transf_ast_number"
  val g_ndlvr_settl_curncy_id = "g_ndlvr_settl_curncy_id"
  val g_ndlvr_fx_rt_bc_id = "g_ndlvr_fx_rt_bc_id"
  val g_ndlvr_fx_rt_qcncy_id = "g_ndlvr_fx_rt_qcncy_id"
  val gf_ndlvr_fx_rt_fxg_date = "gf_ndlvr_fx_rt_fxg_date"
  val gf_ndlvr_fx_fxg_dt_ofst_id = "gf_ndlvr_fx_fxg_dt_ofst_id"
  val gf_ndlvr_fx_fxg_dt_bdc_desc = "gf_ndlvr_fx_fxg_dt_bdc_desc"
  val gf_ndlvr_fx_fxg_dt_cal_desc = "gf_ndlvr_fx_fxg_dt_cal_desc"
  val gf_ndlvr_fx_rt_source_id = "gf_ndlvr_fx_rt_source_id"
  val gf_ndlvr_fx_rt_source_page_id = "gf_ndlvr_fx_rt_source_page_id"
  val g_csh_settl_curncy_id = "g_csh_settl_curncy_id"
  val gf_csh_settl_calc_rt_typo_desc = "gf_csh_settl_calc_rt_typo_desc"
  val gf_csh_setl_accr_int_ind_type = "gf_csh_setl_accr_int_ind_type"
  val gf_csh_setl_dt_ofst_d_number = "gf_csh_setl_dt_ofst_d_number"
  val gf_csh_setl_dt_ofst_d_desc = "gf_csh_setl_dt_ofst_d_desc"
  val gf_csh_setl_ast_min_qtn_amount = "gf_csh_setl_ast_min_qtn_amount"
  val g_csh_setl_ast_min_qcncy_id = "g_csh_setl_ast_min_qcncy_id"
  val gf_csh_setl_ast_max_qtn_amount = "gf_csh_setl_ast_max_qtn_amount"
  val g_csh_setl_ast_max_qcncy_id = "g_csh_setl_ast_max_qcncy_id"
  val gf_cs_ref_ast_qtn_desc = "gf_cs_ref_ast_qtn_desc"
  val gf_cs_qtn_dtofd_number = "gf_cs_qtn_dtofd_number"
  val gf_cs_qtn_dtofd_desc = "gf_cs_qtn_dtofd_desc"
  val gf_csh_setl_ast_qtn_freq_type = "gf_csh_setl_ast_qtn_freq_type"
  val gf_csh_setl_ast_qtn_dt_number = "gf_csh_setl_ast_qtn_dt_number"
  val gf_cs_fnl_prc_valtn_meth_desc = "gf_cs_fnl_prc_valtn_meth_desc"
  val gf_csh_setl_ast_qtn_bc_desc = "gf_csh_setl_ast_qtn_bc_desc"
  val gf_cs_ref_ast_qtn_hms_date = "gf_cs_ref_ast_qtn_hms_date"
  val gf_phys_settl_typo_desc = "gf_phys_settl_typo_desc"
  val gf_clrhs_phys_settl_ind_type = "gf_clrhs_phys_settl_ind_type"
  val gf_settl_dlvry_by_val_ind_type = "gf_settl_dlvry_by_val_ind_type"
  val gf_phys_setl_dt_ofst_d_number = "gf_phys_setl_dt_ofst_d_number"
  val gf_phys_setl_dt_ofst_d_desc = "gf_phys_setl_dt_ofst_d_desc"
  val gf_ps_max_dtofd_number = "gf_ps_max_dtofd_number"
  val gf_ps_max_dtofd_desc = "gf_ps_max_dtofd_desc"
  val gf_ps_oblg_aclt_ind_type = "gf_ps_oblg_aclt_ind_type"
  val gf_phys_setl_accr_int_ind_type = "gf_phys_setl_accr_int_ind_type"
  val gf_dlvob_asgn_loan_ind_type = "gf_dlvob_asgn_loan_ind_type"
  val gf_dlvrbl_oblg_categ_desc = "gf_dlvrbl_oblg_categ_desc"
  val gf_loan_cnst_req_ind_type = "gf_loan_cnst_req_ind_type"
  val gf_dlvob_loan_prtcp_ind_type = "gf_dlvob_loan_prtcp_ind_type"
  val gf_dlvob_dspu_rsln_ind_type = "gf_dlvob_dspu_rsln_ind_type"
  val gf_dlvrbl_oblg_listed_ind_type = "gf_dlvrbl_oblg_listed_ind_type"
  val gf_dlvrbl_oblg_maty_desc = "gf_dlvrbl_oblg_maty_desc"
  val gf_dlvob_not_bear_ind_type = "gf_dlvob_not_bear_ind_type"
  val gf_dlvob_not_ctg_ind_type = "gf_dlvob_not_ctg_ind_type"
  val gf_dlvob_not_paybl_lc_ind_type = "gf_dlvob_not_paybl_lc_ind_type"
  val g_dlvob_paybl_lc_id = "g_dlvob_paybl_lc_id"
  val gf_dlvob_intl_iss_ind_type = "gf_dlvob_intl_iss_ind_type"
  val gf_oblg_not_subj_law_ind_type = "gf_oblg_not_subj_law_ind_type"
  val gf_dlvob_not_svrgn_ind_type = "gf_dlvob_not_svrgn_ind_type"
  val gf_dlvob_not_sbor_ind_type = "gf_dlvob_not_sbor_ind_type"
  val gf_dlvob_pari_passu_ind_type = "gf_dlvob_pari_passu_ind_type"
  val gf_dlvrbl_oblg_curncy_desc = "gf_dlvrbl_oblg_curncy_desc"
  val gf_dlvrbl_oblg_xferbl_ind_type = "gf_dlvrbl_oblg_xferbl_ind_type"
  val gf_ps_escr_agnt_ind_type = "gf_ps_escr_agnt_ind_type"
  val gf_cr_claus_position_type = "gf_cr_claus_position_type"
  val gf_cr_claus_issuer_name = "gf_cr_claus_issuer_name"
  val gf_cr_claus_srty_typo_desc = "gf_cr_claus_srty_typo_desc"
  val gf_cr_claus_undly_ptctn_desc = "gf_cr_claus_undly_ptctn_desc"
  val gf_cr_claus_ptctn_frmul_desc = "gf_cr_claus_ptctn_frmul_desc"
  val gf_cc_grt_ref_oblg_id = "gf_cc_grt_ref_oblg_id"
  val gf_cc_grt_bk_oblg_id_desc = "gf_cc_grt_bk_oblg_id_desc"
  val gf_cc_grt_bk_oblg_nom_desc = "gf_cc_grt_bk_oblg_nom_desc"
  val gf_cc_grt_bk_oblg_nl_ccy_desc = "gf_cc_grt_bk_oblg_nl_ccy_desc"
  val gf_cc_grt_bk_oblg_re_desc = "gf_cc_grt_bk_oblg_re_desc"
  val gf_cc_no_ref_oblg_ind_type = "gf_cc_no_ref_oblg_ind_type"
  val gf_cc_grt_bk_oblg_re_id_desc = "gf_cc_grt_bk_oblg_re_id_desc"
  val gf_cc_grt_bk_oblg_srty_desc = "gf_cc_grt_bk_oblg_srty_desc"
  val gf_cc_trc_atch_point_per = "gf_cc_trc_atch_point_per"
  val gf_cc_trc_exht_point_per = "gf_cc_trc_exht_point_per"
  val gf_cc_trc_nom_amount = "gf_cc_trc_nom_amount"
  val g_cc_trc_nom_curncy_id = "g_cc_trc_nom_curncy_id"
  val gf_cc_ptctn_bc_desc = "gf_cc_ptctn_bc_desc"
  val gf_cc_ptctn_terms_bdc_desc = "gf_cc_ptctn_terms_bdc_desc"
  val gf_cc_ptctn_adj_eff_date = "gf_cc_ptctn_adj_eff_date"
  val gf_cc_ptctn_unadj_eff_date = "gf_cc_ptctn_unadj_eff_date"
  val gf_cc_ptctn_adj_trmnt_date = "gf_cc_ptctn_adj_trmnt_date"
  val gf_cc_ptctn_unadj_trmnt_date = "gf_cc_ptctn_unadj_trmnt_date"
  val gf_cc_revlv_ind_type = "gf_cc_revlv_ind_type"
  val gf_re_thpty_oblg_trd_ind_type = "gf_re_thpty_oblg_trd_ind_type"
  val gf_cc_oblg_ref_ent_id = "gf_cc_oblg_ref_ent_id"
  val gf_cc_ref_oblg_grt_isin_id = "gf_cc_ref_oblg_grt_isin_id"
  val gf_cc_ref_oblg_issr_id = "gf_cc_ref_oblg_issr_id"
  val gf_cc_ref_oblg_srty_desc = "gf_cc_ref_oblg_srty_desc"
  val gf_cc_ref_oblg_prc_amount = "gf_cc_ref_oblg_prc_amount"
  val gf_cc_ptctn_nom_amount = "gf_cc_ptctn_nom_amount"
  val g_cc_ptctn_nom_curncy_id = "g_cc_ptctn_nom_curncy_id"
  val gf_cc_ptctn_curr_nom_amount = "gf_cc_ptctn_curr_nom_amount"
  val g_cc_ptctn_curr_nom_curncy_id = "g_cc_ptctn_curr_nom_curncy_id"
  val gf_cc_ptctn_bnkrpc_ind_type = "gf_cc_ptctn_bnkrpc_ind_type"
  val gf_cr_evt_cnfrm_mn_srce_number = "gf_cr_evt_cnfrm_mn_srce_number"
  val gf_cr_evt_dflt_min_amount = "gf_cr_evt_dflt_min_amount"
  val g_cr_evt_dflt_min_curncy_id = "g_cr_evt_dflt_min_curncy_id"
  val gf_cc_prtct_failr_pay_ind_type = "gf_cc_prtct_failr_pay_ind_type"
  val gf_cc_ptctn_fp_gp_ind_type = "gf_cc_ptctn_fp_gp_ind_type"
  val gf_cc_failr_pay_gp_type = "gf_cc_failr_pay_gp_type"
  val gf_failr_pay_cc_gp_day_desc = "gf_failr_pay_cc_gp_day_desc"
  val gf_cr_evt_failr_pay_mn_amount = "gf_cr_evt_failr_pay_mn_amount"
  val g_cr_failr_pay_mn_curncy_id = "g_cr_failr_pay_mn_curncy_id"
  val gf_cc_prtct_oblg_aclt_ind_type = "gf_cc_prtct_oblg_aclt_ind_type"
  val gf_cc_prtct_oblg_dflt_ind_type = "gf_cc_prtct_oblg_dflt_ind_type"
  val gf_cc_prtct_mrtm_rpdt_ind_type = "gf_cc_prtct_mrtm_rpdt_ind_type"
  val gf_cc_prtct_rstru_ind_type = "gf_cc_prtct_rstru_ind_type"
  val gf_cond_xferbl_rstru_ind_type = "gf_cond_xferbl_rstru_ind_type"
  val gf_rstru_mt_lmt_ind_type = "gf_rstru_mt_lmt_ind_type"
  val gf_rstru_mult_hold_ind_type = "gf_rstru_mult_hold_ind_type"
  val gf_cc_oblg_catg_desc = "gf_cc_oblg_catg_desc"
  val gf_cc_dig_pmt_amount = "gf_cc_dig_pmt_amount"
  val gf_cc_dig_pmt_rt_per = "gf_cc_dig_pmt_rt_per"
  val gf_cc_lvrg_fctr_amount = "gf_cc_lvrg_fctr_amount"
  val gf_cc_dflt_prtct_pmt_desc = "gf_cc_dflt_prtct_pmt_desc"
  val gf_cc_prem_pmt_typo_desc = "gf_cc_prem_pmt_typo_desc"
  val gf_cc_prem_pmt_calc_typo_desc = "gf_cc_prem_pmt_calc_typo_desc"
  val gf_cc_prem_pmt_nom_typo_desc = "gf_cc_prem_pmt_nom_typo_desc"
  val gf_premium_npv_amount = "gf_premium_npv_amount"
  val g_uniq_issuer_id = "g_uniq_issuer_id"
  val g_uniq_issuer_name = "g_uniq_issuer_name"
  val gf_sec_yield_per = "gf_sec_yield_per"
  val gf_sec_irr_per = "gf_sec_irr_per"
  val gf_clean_market_price_amount = "gf_clean_market_price_amount"
  val gf_dirty_market_price_amount = "gf_dirty_market_price_amount"
  val gf_sec_nego_prc_typo_desc = "gf_sec_nego_prc_typo_desc"
  val gf_accr_cpn_int_amount = "gf_accr_cpn_int_amount"
  val g_accr_cpn_int_curncy_id = "g_accr_cpn_int_curncy_id"
  val gf_captl_factor_amount = "gf_captl_factor_amount"
  val gf_sec_all_in_price_per = "gf_sec_all_in_price_per"
  val gf_sec_gross_prin_amount = "gf_sec_gross_prin_amount"
  val gf_sec_net_prin_amount = "gf_sec_net_prin_amount"
  val gf_coupon_typology_desc = "gf_coupon_typology_desc"
  val gf_instm_murex_generator_id = "gf_instm_murex_generator_id"
  val gf_sec_debt_auct_round_number = "gf_sec_debt_auct_round_number"
  val gf_sec_cmpt_auct_ind_type = "gf_sec_cmpt_auct_ind_type"
  val gf_sec_amort_sngl_pmt_ind_type = "gf_sec_amort_sngl_pmt_ind_type"
  val gf_nego_sec_der_ind_type = "gf_nego_sec_der_ind_type"
  val gf_secur_days_to_mt_number = "gf_secur_days_to_mt_number"
  val gf_secur_cpn_transf_ind_type = "gf_secur_cpn_transf_ind_type"
  val gf_amortizable_secur_ind_type = "gf_amortizable_secur_ind_type"
  val gf_accr_cpn_settl_ind_type = "gf_accr_cpn_settl_ind_type"
  val gf_product_basket_id = "gf_product_basket_id"
  val gf_product_basket_typo_desc = "gf_product_basket_typo_desc"
  val gf_prin_gen_int_amount = "gf_prin_gen_int_amount"
  val gf_repo_callable_date = "gf_repo_callable_date"
  val gf_repo_colat_int_dspch_desc = "gf_repo_colat_int_dspch_desc"
  val gf_repo_prin_fill_typo_desc = "gf_repo_prin_fill_typo_desc"
  val gf_repo_prin_alloc_typo_desc = "gf_repo_prin_alloc_typo_desc"
  val gf_repo_total_price_amount = "gf_repo_total_price_amount"
  val gf_repo_accr_cpn_days_number = "gf_repo_accr_cpn_days_number"
  val gf_trd_repo_accr_coupon_per = "gf_trd_repo_accr_coupon_per"
  val gf_reprice_frequency_type = "gf_reprice_frequency_type"
  val gf_ctpty_min_acpt_colat_number = "gf_ctpty_min_acpt_colat_number"
  val gf_repo_mrgn_hrcut_per = "gf_repo_mrgn_hrcut_per"
  val gf_bps_repo_mrgn_hrcut_amount = "gf_bps_repo_mrgn_hrcut_amount"
  val gf_repo_mrgn_hrcut_base_desc = "gf_repo_mrgn_hrcut_base_desc"
  val gf_repo_mrgn_hrcut_frmul_desc = "gf_repo_mrgn_hrcut_frmul_desc"
  val gf_repo_mrgn_factor_number = "gf_repo_mrgn_factor_number"
  val gf_repo_mrgn_typo_desc = "gf_repo_mrgn_typo_desc"
  val gf_repo_calc_fix_rt_per = "gf_repo_calc_fix_rt_per"
  val gf_repo_mt_typo_desc = "gf_repo_mt_typo_desc"
  val gf_repo_notc_p_type = "gf_repo_notc_p_type"
  val gf_repo_notc_p_day_typo_desc = "gf_repo_notc_p_day_typo_desc"
  val gf_op_repo_erlst_unadj_date = "gf_op_repo_erlst_unadj_date"
  val gf_op_repo_erlst_adj_date = "gf_op_repo_erlst_adj_date"
  val gf_op_repo_erls_call_bdc_desc = "gf_op_repo_erls_call_bdc_desc"
  val gf_op_repo_call_ctpty_desc = "gf_op_repo_call_ctpty_desc"
  val gf_repo_colat_sbst_desc = "gf_repo_colat_sbst_desc"
  val gf_repo_colat_max_sbst_desc = "gf_repo_colat_max_sbst_desc"
  val gf_repo_colat_sbst_freq_type = "gf_repo_colat_sbst_freq_type"
  val gf_repo_duration_typo_desc = "gf_repo_duration_typo_desc"
  val gf_repo_uncolat_ind_type = "gf_repo_uncolat_ind_type"
  val gf_colat_price_ref_indx_desc = "gf_colat_price_ref_indx_desc"
  val gf_colat_prc_indx_ini_rt_desc = "gf_colat_prc_indx_ini_rt_desc"
  val gf_colat_indx_ini_sprd_desc = "gf_colat_indx_ini_sprd_desc"
  val gf_colat_accr_cpn_amt_desc = "gf_colat_accr_cpn_amt_desc"
  val gf_colat_clean_price_amt_desc = "gf_colat_clean_price_amt_desc"
  val gf_colat_dirty_price_amt_desc = "gf_colat_dirty_price_amt_desc"
  val gf_colat_nmnl_amt_desc = "gf_colat_nmnl_amt_desc"
  val g_colat_nmnl_amt_curncy_desc = "g_colat_nmnl_amt_curncy_desc"
  val gf_colat_secur_nbr_desc = "gf_colat_secur_nbr_desc"
  val gf_trd_colat_shr_desc = "gf_trd_colat_shr_desc"
  val gf_colat_typo_desc = "gf_colat_typo_desc"
  val gf_colat_ownership_desc = "gf_colat_ownership_desc"
  val gf_colat_dlvry_meth_type = "gf_colat_dlvry_meth_type"
  val gf_colat_ytm_price_mdl_desc = "gf_colat_ytm_price_mdl_desc"
  val gf_collateral_ytm_desc = "gf_collateral_ytm_desc"
  val gf_colat_unit_price_desc = "gf_colat_unit_price_desc"
  val g_colat_unit_price_curncy_desc = "g_colat_unit_price_curncy_desc"
  val gf_colat_setl_cln_prc_desc = "gf_colat_setl_cln_prc_desc"
  val gf_colat_setl_drty_prc_desc = "gf_colat_setl_drty_prc_desc"
  val gf_colat_haircut_amount = "gf_colat_haircut_amount"
  val gf_collateral_isin_desc = "gf_collateral_isin_desc"
  val gf_collateral_currency_id_desc = "gf_collateral_currency_id_desc"
  val g_collateral_reuse_ind_type = "g_collateral_reuse_ind_type"
  val gf_colat_value_amount = "gf_colat_value_amount"
  val gf_uncolat_sft_ind_type = "gf_uncolat_sft_ind_type"
  val gf_buy_currency_calc_basis_id = "gf_buy_currency_calc_basis_id"
  val gf_sell_currency_calc_basis_id = "gf_sell_currency_calc_basis_id"
  val g_forex_trade_buy_currency_id = "g_forex_trade_buy_currency_id"
  val gf_forex_trade_buy_amount = "gf_forex_trade_buy_amount"
  val g_forex_trade_sell_currency_id = "g_forex_trade_sell_currency_id"
  val gf_forex_trade_sell_amount = "gf_forex_trade_sell_amount"
  val gf_fx_trd_bc_delivery_date = "gf_fx_trd_bc_delivery_date"
  val gf_fx_trd_qcncy_delivery_date = "gf_fx_trd_qcncy_delivery_date"
  val gf_fx_trd_bc_pmt_meth_desc = "gf_fx_trd_bc_pmt_meth_desc"
  val gf_fx_trd_qcncy_pmt_meth_desc = "gf_fx_trd_qcncy_pmt_meth_desc"
  val gf_fx_trd_bc_value_date = "gf_fx_trd_bc_value_date"
  val gf_fx_trd_qcncy_value_date = "gf_fx_trd_qcncy_value_date"
  val g_fx_rt_base_curncy_id = "g_fx_rt_base_curncy_id"
  val g_fx_rt_quote_curncy_id = "g_fx_rt_quote_curncy_id"
  val gf_exchange_rate_amount = "gf_exchange_rate_amount"
  val gf_fx_rt_margin_amount = "gf_fx_rt_margin_amount"
  val gf_fx_rt_ctval_amount = "gf_fx_rt_ctval_amount"
  val gf_fx_spot_exch_rate_amount = "gf_fx_spot_exch_rate_amount"
  val gf_spot_fx_rate_fxg_date = "gf_spot_fx_rate_fxg_date"
  val g_trd_cross_rt_bc_id = "g_trd_cross_rt_bc_id"
  val g_trd_cross_rt_qcncy_id = "g_trd_cross_rt_qcncy_id"
  val gf_trd_cross_rt_amount = "gf_trd_cross_rt_amount"
  val gf_trd_accr_coupon_amount = "gf_trd_accr_coupon_amount"
  val gf_float_rt_est_curve_id = "gf_float_rt_est_curve_id"
  val gf_issuing_securities_name = "gf_issuing_securities_name"
  val gf_trade_repo_data_insert_date = "gf_trade_repo_data_insert_date"
  val g_mifid_undly_option_isin_id = "g_mifid_undly_option_isin_id"
  val gf_valtn_meth_disc_curve_name = "gf_valtn_meth_disc_curve_name"
  val gf_trd_leg_asset_tot_number = "gf_trd_leg_asset_tot_number"
  val gf_trd_fin_prod_secur_type = "gf_trd_fin_prod_secur_type"
  val gf_product_ric_id = "gf_product_ric_id"
  val gf_cr_clause_label_desc = "gf_cr_clause_label_desc"
  val gf_trd_first_cshflw_date = "gf_trd_first_cshflw_date"
  val gf_opt_pyt_type_desc = "gf_opt_pyt_type_desc"
  val gf_opt_strk_qcncy_pair_id = "gf_opt_strk_qcncy_pair_id"
  val gf_coupon_date = "gf_coupon_date"
  val gf_fin_prod_secur_group_name = "gf_fin_prod_secur_group_name"
  val gf_fin_prod_secur_murex_id = "gf_fin_prod_secur_murex_id"
  val g_murex_generator_curncy_id = "g_murex_generator_curncy_id"
  val g_ndf_fx_trd_ind_type = "g_ndf_fx_trd_ind_type"
  val gf_fut_cont_secur_label_desc = "gf_fut_cont_secur_label_desc"
  val gf_trd_prem_amount = "gf_trd_prem_amount"
  val gf_nl_expressed_type = "gf_nl_expressed_type"
  val gf_spot_leg_colat_nl_amt_desc = "gf_spot_leg_colat_nl_amt_desc"
  val gf_fwd_leg_colat_nl_amt_desc = "gf_fwd_leg_colat_nl_amt_desc"
  val g_spot_leg_clt_nl_amt_ccy_desc = "g_spot_leg_clt_nl_amt_ccy_desc"
  val g_fwd_leg_clt_nl_amt_ccy_desc = "g_fwd_leg_clt_nl_amt_ccy_desc"
  val g_spot_leg_fx_bc_id = "g_spot_leg_fx_bc_id"
  val g_spot_leg_fx_qcncy_id = "g_spot_leg_fx_qcncy_id"
  val g_fwd_leg_fx_bc_id = "g_fwd_leg_fx_bc_id"
  val g_fwd_leg_fx_qcncy_id = "g_fwd_leg_fx_qcncy_id"
  val gf_spot_leg_exch_rate_amount = "gf_spot_leg_exch_rate_amount"
  val gf_fwd_leg_exch_rate_amount = "gf_fwd_leg_exch_rate_amount"
  val gf_spot_leg_sec_gs_prin_amount = "gf_spot_leg_sec_gs_prin_amount"
  val gf_fwd_leg_sec_gs_prin_amount = "gf_fwd_leg_sec_gs_prin_amount"
  val gf_spot_leg_settl_amount = "gf_spot_leg_settl_amount"
  val gf_fwd_leg_settl_amount = "gf_fwd_leg_settl_amount"
  val g_spot_leg_settl_amt_curncy_id = "g_spot_leg_settl_amt_curncy_id"
  val g_fwd_leg_settl_amt_curncy_id = "g_fwd_leg_settl_amt_curncy_id"
  val g_spot_leg_settl_curncy_id = "g_spot_leg_settl_curncy_id"
  val g_fwd_leg_settl_curncy_id = "g_fwd_leg_settl_curncy_id"
  val gf_spot_leg_settl_bdc_desc = "gf_spot_leg_settl_bdc_desc"
  val gf_fwd_leg_settl_bdc_desc = "gf_fwd_leg_settl_bdc_desc"
  val gf_spot_leg_bdc_unstl_date = "gf_spot_leg_bdc_unstl_date"
  val gf_fwd_leg_bdc_unstl_date = "gf_fwd_leg_bdc_unstl_date"
  val gf_spot_leg_bdc_adj_settl_date = "gf_spot_leg_bdc_adj_settl_date"
  val gf_fwd_leg_bdc_adj_settl_date = "gf_fwd_leg_bdc_adj_settl_date"
  val gf_spot_leg_ps_tr_asset_id = "gf_spot_leg_ps_tr_asset_id"
  val gf_fwd_leg_ps_tr_asset_id = "gf_fwd_leg_ps_tr_asset_id"
  val g_fx_swap_near_leg_buy_ccy_id = "g_fx_swap_near_leg_buy_ccy_id"
  val g_fx_swap_far_leg_buy_ccy_id = "g_fx_swap_far_leg_buy_ccy_id"
  val gf_fx_swap_near_leg_buy_amount = "gf_fx_swap_near_leg_buy_amount"
  val gf_fx_swap_far_leg_buy_amount = "gf_fx_swap_far_leg_buy_amount"
  val g_fx_swap_near_leg_sell_ccy_id = "g_fx_swap_near_leg_sell_ccy_id"
  val g_fx_swap_far_leg_sell_ccy_id = "g_fx_swap_far_leg_sell_ccy_id"
  val gf_fxs_near_leg_sell_amount = "gf_fxs_near_leg_sell_amount"
  val gf_fxs_far_leg_sell_amount = "gf_fxs_far_leg_sell_amount"
  val g_fx_swap_near_leg_rt_bc_id = "g_fx_swap_near_leg_rt_bc_id"
  val g_fx_swap_far_leg_rt_bc_id = "g_fx_swap_far_leg_rt_bc_id"
  val g_fx_swap_near_leg_rt_qcncy_id = "g_fx_swap_near_leg_rt_qcncy_id"
  val g_fx_swap_far_leg_rt_qcncy_id = "g_fx_swap_far_leg_rt_qcncy_id"
  val gf_fx_swap_near_leg_exr_amount = "gf_fx_swap_near_leg_exr_amount"
  val gf_fx_swap_far_leg_exr_amount = "gf_fx_swap_far_leg_exr_amount"
  val gf_fxs_near_leg_rt_mrgn_amount = "gf_fxs_near_leg_rt_mrgn_amount"
  val gf_fxs_far_leg_rt_mrgn_amount = "gf_fxs_far_leg_rt_mrgn_amount"
  val g_fxs_nrlg_ndlvr_setl_ccy_id = "g_fxs_nrlg_ndlvr_setl_ccy_id"
  val g_fxs_frlg_ndlvr_setl_ccy_id = "g_fxs_frlg_ndlvr_setl_ccy_id"
  val g_fxs_near_leg_cross_rt_bc_id = "g_fxs_near_leg_cross_rt_bc_id"
  val g_fxs_far_leg_cross_rt_bc_id = "g_fxs_far_leg_cross_rt_bc_id"
  val g_fxs_nrlg_cross_rt_qcncy_id = "g_fxs_nrlg_cross_rt_qcncy_id"
  val g_fxs_frlg_cross_rt_qcncy_id = "g_fxs_frlg_cross_rt_qcncy_id"
  val gf_fxs_nrlg_cross_rt_amount = "gf_fxs_nrlg_cross_rt_amount"
  val gf_fxs_far_leg_cross_rt_amount = "gf_fxs_far_leg_cross_rt_amount"
  val gf_fxs_nrlg_spot_rt_fxg_date = "gf_fxs_nrlg_spot_rt_fxg_date"
  val gf_fxs_frlg_spot_rt_fxg_date = "gf_fxs_frlg_spot_rt_fxg_date"
  val gf_fxs_nrlg_bc_pmt_meth_desc = "gf_fxs_nrlg_bc_pmt_meth_desc"
  val gf_fxs_frlg_bc_pmt_meth_desc = "gf_fxs_frlg_bc_pmt_meth_desc"
  val gf_fxs_nrlg_qcncy_pmt_desc = "gf_fxs_nrlg_qcncy_pmt_desc"
  val gf_fxs_frlg_qcncy_pmt_desc = "gf_fxs_frlg_qcncy_pmt_desc"
  val gf_fxs_near_leg_rt_ctvl_amount = "gf_fxs_near_leg_rt_ctvl_amount"
  val gf_fxs_far_leg_rt_ctvl_amount = "gf_fxs_far_leg_rt_ctvl_amount"
  val gf_fxs_nrlg_phys_settl_desc = "gf_fxs_nrlg_phys_settl_desc"
  val gf_fxs_frlg_phys_settl_desc = "gf_fxs_frlg_phys_settl_desc"
  val g_fxs_nr_ndv_setl_rt_qcncy_id = "g_fxs_nr_ndv_setl_rt_qcncy_id"
  val g_fxs_fr_ndv_setl_rt_qcncy_id = "g_fxs_fr_ndv_setl_rt_qcncy_id"
  val gf_fxs_nr_ndlvr_setl_rt_src_id = "gf_fxs_nr_ndlvr_setl_rt_src_id"
  val gf_fxs_fr_ndlvr_setl_rt_src_id = "gf_fxs_fr_ndlvr_setl_rt_src_id"
  val gf_fxs_nr_ndv_setl_rt_fxg_date = "gf_fxs_nr_ndv_setl_rt_fxg_date"
  val gf_fxs_fr_ndv_setl_rt_fxg_date = "gf_fxs_fr_ndv_setl_rt_fxg_date"
  val g_fxs_near_leg_ndlvr_rt_bc_id = "g_fxs_near_leg_ndlvr_rt_bc_id"
  val g_fxs_far_leg_ndlvr_rt_bc_id = "g_fxs_far_leg_ndlvr_rt_bc_id"
  val gf_fxs_trd_frlg_value_date = "gf_fxs_trd_frlg_value_date"
  val gf_fxs_trd_nrlg_value_date = "gf_fxs_trd_nrlg_value_date"
  val gf_phys_setl_sec_nom_amt_desc = "gf_phys_setl_sec_nom_amt_desc"
  val gf_phys_setl_sec_isin_desc = "gf_phys_setl_sec_isin_desc"
  val gf_phys_setl_sec_ccy_desc = "gf_phys_setl_sec_ccy_desc"
  val gf_underlying_sec_nom_amt_desc = "gf_underlying_sec_nom_amt_desc"
  val gf_underlying_sec_isin_desc = "gf_underlying_sec_isin_desc"
  val gf_underlying_sec_ccy_desc = "gf_underlying_sec_ccy_desc"
  val gf_initial_interest_rate_per = "gf_initial_interest_rate_per"
  val gf_trd_lst_int_rate_per = "gf_trd_lst_int_rate_per"
  val gf_initial_spread_per = "gf_initial_spread_per"
  val gf_trd_last_spread_per = "gf_trd_last_spread_per"
  val gf_eff_haircut_per = "gf_eff_haircut_per"
  val gf_haircut_calc_type = "gf_haircut_calc_type"
  val gf_po_perspct_hct_drctn_type = "gf_po_perspct_hct_drctn_type"
  val gf_secur_notl_outstd_amount = "gf_secur_notl_outstd_amount"
  val gf_inv_clt_auto_alloc_ind_type = "gf_inv_clt_auto_alloc_ind_type"
  val gf_ctp_choose_clt_bnd_ind_type = "gf_ctp_choose_clt_bnd_ind_type"
  val gf_trd_trmnt_type_desc = "gf_trd_trmnt_type_desc"
  val gf_trd_rdm_aplcnt_type = "gf_trd_rdm_aplcnt_type"
  val gf_hct_trd_udl_iss_dprc_amount = "gf_hct_trd_udl_iss_dprc_amount"
  val gf_trd_udl_sec_dprc_amount = "gf_trd_udl_sec_dprc_amount"
  val gf_year_id = "gf_year_id"
  val gf_month_number = "gf_month_number"
  val gf_day_number = "gf_day_number"
  val gf_odate_date_id = "gf_odate_date_id"
  val gf_audit_date = "gf_audit_date"
  val gf_run_id = "gf_run_id"
  val gf_cncl_opt_expir_unadj_date = "gf_cncl_opt_expir_unadj_date"
  val gf_origin_application_id_aux = "gf_origin_application_id_aux"
  val gf_front_sys_name_aux = "gf_front_sys_name_aux"
  val gf_front_sys_trd_id_aux = "gf_front_sys_trd_id_aux"
  val gf_back_sys_trd_id_aux = "gf_back_sys_trd_id_aux"
  val gf_trd_leg_id_aux = "gf_trd_leg_id_aux"
  val gf_trd_phase_id_aux = "gf_trd_phase_id_aux"
  val gf_trd_leg_adj_eff_date_aux = "gf_trd_leg_adj_eff_date_aux"
  val gf_trd_leg_adj_trmnt_date_aux = "gf_trd_leg_adj_trmnt_date_aux"
  val gf_trd_phase_adj_eff_date_aux = "gf_trd_phase_adj_eff_date_aux"
  val gf_trd_phase_adj_trmnt_date_aux = "gf_trd_phase_adj_trmnt_date_aux"
  val gf_underlying_amount_aux = "gf_underlying_amount_aux"
  val g_call_put_option_type_aux = "g_call_put_option_type_aux"
  val g_exercise_option_type_aux = "g_exercise_option_type_aux"
  val g_option_exercise_freq_type_aux = "g_option_exercise_freq_type_aux"
  val gf_opt_adj_ex_dt_desc_aux = "gf_opt_adj_ex_dt_desc_aux"
  val gf_am_opt_fst_ex_adj_date_aux = "gf_am_opt_fst_ex_adj_date_aux"
  val gf_option_strike_amount_aux = "gf_option_strike_amount_aux"
  val g_interest_rate_type_aux = "g_interest_rate_type_aux"
  val g_interest_pymt_frequency_type_aux = "g_interest_pymt_frequency_type_aux"
  val gf_pmt_dt_ref_typo_desc_aux = "gf_pmt_dt_ref_typo_desc_aux"
  val gf_upfront_pmt_amount_aux = "gf_upfront_pmt_amount_aux"
  val gf_fixed_rate_per_aux = "gf_fixed_rate_per_aux"
  val g_amortization_frequency_type_aux = "g_amortization_frequency_type_aux"
  val gf_float_rt_ini_per_aux = "gf_float_rt_ini_per_aux"
  val gf_current_interest_rate_per_aux = "gf_current_interest_rate_per_aux"
  val gf_net_life_cap_per_aux = "gf_net_life_cap_per_aux"
  val gf_net_life_floor_per_aux = "gf_net_life_floor_per_aux"
  val gf_swap_tenor_months_number_aux = "gf_swap_tenor_months_number_aux"
  val g_day_count_convention_type_aux = "g_day_count_convention_type_aux"
  val g_compounding_frequency_type_aux = "g_compounding_frequency_type_aux"
  val g_renewal_frequency_type_aux = "g_renewal_frequency_type_aux"
  val g_reference_index_id_aux = "g_reference_index_id_aux"
  val g_amortization_type_aux = "g_amortization_type_aux"
  val gf_forward_price_amount_aux = "gf_forward_price_amount_aux"
  val gf_fx_forward_exch_rate_amount_aux = "gf_fx_forward_exch_rate_amount_aux"
  val gf_dflt_cvr_bk_min_oblg_number_aux = "gf_dflt_cvr_bk_min_oblg_number_aux"
  val gf_am_opt_lst_ex_adj_date_aux = "gf_am_opt_lst_ex_adj_date_aux"
  val gf_local_contract_number_id_aux = "gf_local_contract_number_id_aux"
  val gf_initial_interest_rate_per_aux = "gf_initial_interest_rate_per_aux"
  val g_trade_position_type_aux = "g_trade_position_type_aux"
  val g_trade_position_type = "g_trade_position_type"
  val gf_repo_internal_int_rate_per = "gf_repo_internal_int_rate_per"
  val gf_repo_internal_sprd_rate_per = "gf_repo_internal_sprd_rate_per"
  val gf_trd_colat_prod_desc = "gf_trd_colat_prod_desc"
  val gf_collateral_current_ir_desc = "gf_collateral_current_ir_desc"
  val gf_collateral_initial_ir_desc = "gf_collateral_initial_ir_desc"
  val gf_clt_int_cal_pds_freq_desc = "gf_clt_int_cal_pds_freq_desc"
  val gf_clt_int_change_date_desc = "gf_clt_int_change_date_desc"
  val gf_collateral_fixing_freq_desc = "gf_collateral_fixing_freq_desc"
  val gf_collateral_apply_ir_type = "gf_collateral_apply_ir_type"
  val gf_ref_index_interest_rate_per = "gf_ref_index_interest_rate_per"
  val gf_ref_index_interest_rate_per_aux = "gf_ref_index_interest_rate_per_aux"
  val gf_trd_leg_int_chng_next_date = "gf_trd_leg_int_chng_next_date"
  val BGM_BIS = "BGM_BIS"
  val ten_zero = "0000000000"
  val zero_string = "0"
  val XX = "XX"
  val twenty_six = 26
  val six = 6
  val twelve = 12
  val four = 4
  val nine = 9
  val sixteen = 16
  val nineteen = 19
  val DCCO = "DCCO"
  val guarantee_type = "guarantee_type"
  val isin_id = "isin_id"
  val isin_id_coll = "isin_id_coll"
  val current_guaranteed_amount = "current_guaranteed_amount"
  val initial_amount = "initial_amount"
  val CD = "CD"
  val OPR = "OPR"
  val CR = "CR"
  val PAYER = "PAYER"
  val GET = "GET"
  val VR = "VR"
  val VD = "VD"
  val RECEIVER = "RECEIVER"
  val portfolio_investment_type = "portfolio_investment_type"
  val pymt_rcpt_fwd_oper_mark_type = "pymt_rcpt_fwd_oper_mark_type"
  val fin_derivative_leg_mark_type = "fin_derivative_leg_mark_type"
  val operation_nature_type = "operation_nature_type"
  val payment_indicator_type = "payment_indicator_type"
  val local_type = "local_type"
  val COMPRA = "COMPRA"
  val VENTA = "VENTA"
  val holding_id = "holding_id"
  val sire_oper_related_info_type = "sire_oper_related_info_type"
  val fin_derivative_settlement_amount = "fin_derivative_settlement_amount"
  val current_spread_amount = "current_spread_amount"
  val interest_rate_amount = "interest_rate_amount"
  val mark_type = "mark_type"
  val oper_flow_pymt_rcpt_mark_type = "oper_flow_pymt_rcpt_mark_type"
  val transaction_type = "transaction_type"
  val B = "B"
  val S = "S"
  val gf_trd_party_payer_recv_type_aux = "gf_trd_party_payer_recv_type_aux"
  val g_undly_asset_isin_id_aux = "g_undly_asset_isin_id_aux"
  val gf_settl_amount_aux = "gf_settl_amount_aux"
  val gf_sec_irr_per_aux = "gf_sec_irr_per_aux"
  val gf_colat_nmnl_amt_desc_aux = "gf_colat_nmnl_amt_desc_aux"
  val gf_colat_typo_desc_aux = "gf_colat_typo_desc_aux"
  val gf_collateral_isin_desc_aux = "gf_collateral_isin_desc_aux"
  val gf_amortization_id = "gf_amortization_id"
  val gf_current_trd_contract_id = "gf_current_trd_contract_id"
  val gf_management_portfolio_id = "gf_management_portfolio_id"
  val gf_financial_asset_class_type = "gf_financial_asset_class_type"
  val gf_fin_product_group_type = "gf_fin_product_group_type"
  val gf_fin_product_sub_group_type = "gf_fin_product_sub_group_type"
  val gf_trd_flex_tmpl_id = "gf_trd_flex_tmpl_id"
  val gf_trd_flex_tmpl_desc = "gf_trd_flex_tmpl_desc"
  val gf_fin_product_typo_desc = "gf_fin_product_typo_desc"
  val gf_financial_product_desc = "gf_financial_product_desc"
  val gf_lot_size_number = "gf_lot_size_number"
  val gf_trd_instm_qty_number = "gf_trd_instm_qty_number"
  val gf_first_fixing_amount = "gf_first_fixing_amount"
  val gf_sales_margin_per = "gf_sales_margin_per"
  val gf_corporate_margin_per = "gf_corporate_margin_per"
  val gf_net_margin_per = "gf_net_margin_per"
  val gf_schedule_generator_id = "gf_schedule_generator_id"
  val gf_fxg_date_ref_dt_typo_desc = "gf_fxg_date_ref_dt_typo_desc"

  val blank_spaces = "\\s+"

  val NA = "N/A"
  val zeroFour = "04"
  val FourZeros = "0000"
  val Actual360 = "Actual/360"
  val LINACT360 = "LIN ACT/360"
  val throw_a_exception_when_a_path_not_exist = "throw a exception when a path not exist"
  val return_3_elements = "return 3 elements"
  val return_10_elements = "return 10 elements"
  val zero = 0
  val eight = 8
  val eighteen = 18
  val five = 5
  val teen = 10
  val two = 2
  val twenty = 20
  val seventeen = 17
  val thirthy_eight = 38
  val fifteen = 15
          
}
// Out:
// defined object Constants

// %% [markdown]
// ## CatalogReader

// %%
import Constants._
import org.apache.commons.lang3.exception.ExceptionUtils
import org.apache.spark.sql.functions.{col, upper}
import org.apache.spark.sql.{DataFrame, SparkSession}


class Catalog(spark: SparkSession) {

  def catalogPrsPcv(path: String): DataFrame = {
    try {
      spark.read.parquet(path).filter(col(g_catalog_id) === A218)
        .select(
          col(gf_catalog_val_id).as(id),
          col(gf_catlg_field_value_es_desc).as(value)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def catalogOptionType(path: String): DataFrame = {
    try {
      spark.read.parquet(path)
        .filter(col(g_catalog_id) === C112)
        .select(
          col(gf_catalog_val_id),
          upper(col(gf_catlg_field_value_es_desc)).as(gf_catlg_field_value_es_desc)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def catalogApp(path: String): DataFrame = {
    try {
       spark.read.parquet(path).filter(col(g_catalog_id) === A050)
        .select(
          col(gf_catalog_val_id).as(id),
          col(gf_catlg_field_value_es_desc).as(value)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  val sparkI = spark
  import sparkI.implicits._

  def catalogPrev(): DataFrame = {
    try {
      val catprev = Seq(
        ("CDS",NA,XX),
        ("LIN AC/AC ICMA","Actual/Actual.ICMA","18"),
        (LINACT360,Actual360,zeroFour),
        ("LIN 30/360","30/360","03"),
        ("LINACT/360",Actual360,zeroFour),
        ("LIN ACT/ACT","Actual/Actual","02"),
        ("CMP 28/182",NA,XX),
        ("LIN ISDA","1/1_ISDA","22"),
        ("LIN 30E/360","30E / 360","07"),
        ("LIN ACT/365","Actual/365","05"),
        (LINACT360,Actual360,zeroFour),
        (LINACT360,Actual360,zeroFour),
        (LINACT360,Actual360,zeroFour),
        (Actual360,Actual360,zeroFour),
        ("LIN 30/360","30/360","03"),
        (Actual360,Actual360,zeroFour),
        ("Delivery",NA,XX),
        ("ACTUAL/365","Actual/365","05"),
        ("Cash",NA,XX)
      ).toDF(local_type,"holding_type",holding_id)

      catprev

    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

}
// Out:
// defined class Catalog

// %% [markdown]
// ## TsiReader

// %%
import org.apache.commons.lang3.exception.ExceptionUtils
import org.apache.spark.sql.{DataFrame, SparkSession}
import org.apache.spark.sql.functions.{col, lit, regexp_replace, trim, when}

class ReadTsiTables(spark: SparkSession, hdate: String) {

  def readTsiContraparte(path: String): DataFrame = {
    try {
      spark.read.parquet(path)
        .select(
          col(contract_affiliation_id).as(customer_platform_id),
          col(bbva_intergroup_id).as(customer_corporate_id),
          trim(col(counterpart_id)).as(counterpart_id)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiSwapsTasa(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          when(col(oper_origin_app_assigned_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(oper_origin_app_assigned_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(calculation_interest_name)).as(count_convention),
          col(murex_operation_id),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          col(swap_legs_id),
          col(operation_stage_number),
          trim(col(fin_derivative_leg_mark_type)).as(fin_derivative_leg_mark_type),
          trim(col(operations_date_payment_type)).as(operations_date_payment_type),
          col(fin_derivative_settlement_amount),
          col(current_spread_amount),
          col(interest_rate_amount),
          trim(col(calculation_interest_name)).as(calculation_interest_name),
          trim(col(fin_derv_leg_exch_int_mark_type)).as(fin_derv_leg_exch_int_mark_type),
          col(fin_derv_active_value_start_date),
          col(underlying_expiry_date),
          col(fin_derv_oper_phase_start_date),
          col(fin_derv_oper_phase_end_date),
          trim(col(fin_derv_leg_flow_frequency_name)).as(fin_derv_leg_flow_frequency_name),
          col(operation_repayment_number),
          col(operation_sire_assigned_id),
          col(nominal_amount),
          trim(col(break_clause_frequency_type)).as(break_clause_frequency_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiSwapsIv(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          when(col(oper_origin_app_assigned_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(oper_origin_app_assigned_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(calculation_interest_name)).as(count_convention),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          col(operation_parts_number),
          col(operation_stage_number),
          trim(col(fin_derivative_leg_mark_type)).as(fin_derivative_leg_mark_type),
          trim(col(operations_date_payment_type)).as(operations_date_payment_type),
          col(operation_sire_assigned_id),
          col(nominal_amount),
          trim(col(fin_derv_leg_flow_frequency_name)).as(fin_derv_leg_flow_frequency_name),
          col(operation_repayment_number),
          col(fin_derv_oper_phase_end_date),
          col(fin_derv_active_value_start_date),
          trim(col(fin_derv_leg_exch_int_mark_type)).as(fin_derv_leg_exch_int_mark_type),
          col(current_spread_amount),
          col(interest_rate_amount)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiSwapsCre(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          when(col(oper_origin_app_assigned_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(oper_origin_app_assigned_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(calculation_interest_name)).as(count_convention),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          col(operation_parts_number),
          col(operation_stage_number),
          trim(col(fin_derivative_leg_mark_type)).as(fin_derivative_leg_mark_type),
          col(operation_sire_assigned_id),
          col(nominal_amount),
          col(fin_derv_oper_phase_end_date),
          col(fin_derv_active_value_start_date),
          col(fin_derv_oper_phase_start_date),
          col(current_spread_amount)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiOperacion(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          trim(col(oper_origin_app_assigned_id)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          col(maximum_operation_rate_per),
          col(market_operation_expiry_date),
          col(minimum_operation_rate_per),
          trim(col(operation_sire_assigned_id)).as(sire_id),
          trim(col(source_system_type)).as(source_system_type),
          col(contract_id),
          col(market_operation_start_date),
          col(settlement_date),
          col(contract_register_date),
          trim(col(operation_currency_type)).as(operation_currency_type),
          trim(col(financial_product_id)).as(financial_product_id)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiOperacionMmo(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          trim(col(sire_oper_related_info_type)).as(sire_oper_related_info_type),
          col(oper_origin_app_assigned_id).as(operation_deal_front_star_id),
          trim(col(portfolio_investment_name)).as(portfolio_type),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(market_operation_type)).as(market_operation_type)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiFwdDiv(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .select(
          trim(col(original_operation_id)).as(operation_deal_front_star_id),
          trim(col(calculation_base_currency_type)).as(calculation_base_currency_type)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiSwapsDiv(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .select(
          trim(col(original_operation_id)).as(operation_deal_front_star_id),
          trim(col(portfolio_type)).as(portfolio_type),
          trim(col(counterparty_id)).as(counterpart_id),
          col(operation_parts_number),
          col(operation_stage_number),
          trim(col(payment_indicator_type)).as(payment_indicator_type),
          trim(col(operations_date_payment_type)).as(operations_date_payment_type),
          col(nominal_value_securities_number).as(nominal_amount),
          trim(col(calculation_interest_name)).as(coupon_rate_name),
          trim(col(settlement_freq_id)).as(fin_derv_leg_flow_frequency_name),
          col(operation_repayment_number),
          trim(col(curr_creditor_interest_type)).as(fin_derv_leg_exch_int_mark_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiOpcionDiv(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .select(
          trim(col(original_operation_id)).as(operation_deal_front_star_id),
          col(asset_future_price_amount)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

}
// Out:
// defined class ReadTsiTables

// %% [markdown]
// ## InputReader

// %%
import Constants._
import org.apache.spark.sql.functions.{col, trim, upper, regexp_replace, lit, when, coalesce}
import org.apache.spark.sql.{DataFrame, SparkSession}
import org.apache.commons.lang3.exception.ExceptionUtils
import org.apache.spark.sql.types.StringType


class InputReader(spark: SparkSession, hdate: String, odate: String) {
  
  def readGuaranteeCore(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + odate)
        .select(
          trim(col(contract_id)).as(contract_id),
          trim(col(guarantee_type)).as(guarantee_type),
          trim(col(isin_id)).as(isin_id_coll),
          col(current_guaranteed_amount)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readRentaFijaOpeBis(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .filter(!trim(col(market_operation_type)).isin(prods:_*))
        .select(
          trim(col(customer_platform_id)).as(customer_platform_id),
          trim(col(customer_corporate_id)).as(customer_corporate_id),
          when(col(operation_deal_front_star_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(operation_deal_front_star_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          when(col(source_application_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(source_application_id), blank_spaces, emptyString)).as(source_application_id),
          when(col(operation_deal_back_star_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(operation_deal_back_star_id), blank_spaces,emptyString)).as(operation_deal_back_star_id),
          col(total_securities_nominal_amount),
          col(market_operation_start_date),
          trim(col(coupon_rate_type)).as(coupon_rate_type),
          col(coupon_term_days_number),
          col(return_interest_rate_per),
          col(current_rate_coupon_per),
          trim(col(coupon_rate_name)).as(coupon_rate_name),
          col(market_operation_settlement_date),
          col(current_commitment_amount),
          col(initial_amount),
          col(seller_branch_id),
          trim(col(market_operation_type)).as(market_operation_type),
          trim(col(isin_id)).as(isin_id),
          trim(col(contract_id)).as(contract_id)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readProductsIntRateOptions(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          when(col(oper_origin_app_assigned_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(oper_origin_app_assigned_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(coupon_rate_name)).as(count_convention),
          trim(col(portfolio_investment_type)).as(portfolio_investment_type),
          col(operation_parts_number),
          col(operation_stage_number),
          col(operation_sire_assigned_id),
          col(purchase_sale_ctrct_amount),
          col(strike_amount),
          coalesce(col(coupon_rate_name), col(prch_sale_option_ir_cvtn_type)).as(coupon_rate_name),
          col(fin_derv_oper_phase_end_date),
          col(fin_derv_oper_phase_start_date)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readForwardIntRateProducts(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          when(col(oper_origin_app_assigned_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(oper_origin_app_assigned_id), blank_spaces,emptyString)).as(operation_deal_front_star_id),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(calculation_interest_name)).as(count_convention),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          col(operation_parts_number),
          col(operation_stage_number),
          trim(col(pymt_rcpt_fwd_oper_mark_type)).as(pymt_rcpt_fwd_oper_mark_type),
          col(operation_sire_assigned_id),
          col(nominal_amount),
          trim(col(fndr_variable_rate_int_type)).as(fndr_variable_rate_int_type),
          trim(col(calculation_interest_name)).as(coupon_rate_name),
          col(fin_derv_oper_phase_end_date),
          col(fin_derv_oper_phase_start_date),
          col(underlying_expiry_date)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def dataCountConvention(productsIntRateOptions: DataFrame, forwardIntRateProducts: DataFrame, tsiSwapsTasa: DataFrame,
                          tsiSwapsIv: DataFrame, tsiSwapsCre: DataFrame): DataFrame = {
    try {
      productsIntRateOptions.select(
        col(operation_deal_front_star_id),
        col(counterpart_id),
        col(count_convention)
      )
        .union(forwardIntRateProducts.select(
          col(operation_deal_front_star_id),
          col(counterpart_id),
          col(count_convention)
        )
        )
        .union(
          tsiSwapsTasa.select(
            col(operation_deal_front_star_id),
            col(counterpart_id),
            col(count_convention)
          )
        )
        .union(tsiSwapsIv.select(
          col(operation_deal_front_star_id),
          col(counterpart_id),
          col(count_convention)
        )
        )
        .union(tsiSwapsCre.select(
          col(operation_deal_front_star_id),
          col(counterpart_id),
          col(count_convention)
        )
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readSireFxPrdt(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .filter(col(subproduct_type) =!= FXLI)
        .select(
          col(counterparty_id).as(counterpart_id),
          when(col(source_application_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(source_application_id), blank_spaces,emptyString)).as(source_application_id),
          trim(col(operation_deal_front_star_id)).as(operation_deal_front_star_id),
          trim(col(operation_deal_back_star_id)).as(operation_deal_back_star_id),
          col(market_oper_recv_notional_amount),
          col(forward_price_amount),
          col(seller_branch_id),
          trim(col(operation_nature_type)).as(operation_nature_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readDerivadosMmooBis(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .select(
          col(counterparty_systems_oper_id).as(counterpart_id),
          when(trim(col(warrant_type)).isin(C, CALL), CALL).when(trim(col(warrant_type)).isin(P, PUT), PUT).otherwise(lit(X)).as(warrant_type),
          trim(col(product_type)).as(product_type),
          when(col(source_application_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(source_application_id), blank_spaces,emptyString)).as(source_application_id),
          trim(col(operation_deal_front_star_id)).as(operation_deal_front_star_id),
          trim(col(operation_deal_back_star_id)).as(operation_deal_back_star_id),
          trim(col(trading_mark_type)).as(trading_mark_type),
          col(market_oper_pay_notional_amount),
          trim(col(option_style_mark_type)).as(option_style_mark_type),
          col(strike_amount),
          trim(col(underline_reference_type)).as(underline_reference_type),
          col(contract_amount),
          col(expiration_date),
          col(market_oper_recv_notional_amount),
          col(value_date),
          col(forward_swap_recv_rate_amount),
          col(forward_swap_pay_rate_amount),
          col(isin_id),
          trim(col(seller_branch_id)).as(seller_branch_id)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readFinDervOtcBis(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .filter(trim(col(subproduct_type)) =!= CAP)
        .filter(!(trim(col(subproduct_type)).isin(IRC, IRS) && trim(col(gl_account_id)).substr(0,1).isin("1","2") ||
          trim(col(gl_account_type)) === H))
        .select(
          trim(col(securities_dealing_desk_name)).as(portfolio_type),
          trim(col(counterparty_id)).as(counterpart_id),
          when(trim(col(warrant_type)).isin(C, CALL), CALL).when(trim(col(warrant_type)).isin(P, PUT), PUT).as(warrant_type),
          trim(col(operation_deal_front_star_id)).as(operation_deal_front_star_id),
          when(col(source_application_id).isNull, lit(emptyString))
            .otherwise(regexp_replace(col(source_application_id), blank_spaces,emptyString)).as(source_application_id),
          trim(col(operation_deal_back_star_id)).as(operation_deal_back_star_id),
          trim(col(option_style_mark_type)).as(option_style_mark_type),
          trim(col(product_type)).as(product_type),
          col(expiration_date),
          col(forward_swap_pay_rate_amount),
          col(forward_swap_recv_rate_amount),
          trim(col(subproduct_type)).as(subproduct_type),
          trim(col(underline_reference_type)).as(underline_reference_type),
          col(value_date),
          trim(col(trading_mark_type)).as(trading_mark_type),
          trim(col(isin_id)).as(isin_id),
          trim(col(seller_branch_id)).as(seller_branch_id)
        )
        .distinct()
    } catch {
      case e: Exception=> ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readInternalOperMurex(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .select(
          trim(col(front_system_number_id)).as(operation_deal_front_star_id),
          trim(col(portfolio_investment_name)).as(portfolio_investment_name),
          trim(col(app_counterparty_id)).as(counterpart_id),
          col(operation_parts_number),
          trim(col(fin_derivative_leg_mark_type)).as(fin_derivative_leg_mark_type),
          trim(col(fin_derv_leg_exch_int_mark_type)).as(fin_derv_leg_exch_int_mark_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readLiquidityFlowsOverSwap(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .filter(col(fin_derv_oper_curr_flow_type) === FL && lit(hdate).between(col(fin_derv_flow_start_date), col(period_end_date)))
        .select(
          trim(col(murex_operation_id)).as(operation_deal_front_star_id),
          trim(col(operation_sire_assigned_id)).as(sire_id),
          col(forward_price_amount),
          trim(col(oper_flow_pymt_rcpt_mark_type)).as(oper_flow_pymt_rcpt_mark_type)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readLiqOverRateOptions(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .filter(col(fin_derv_oper_curr_flow_type) === FL && lit(hdate).between(col(fin_derv_flow_start_date), col(underlying_expiry_date)))
        .select(
          trim(col(operation_sire_assigned_id)).as(sire_id),
          trim(col(oper_origin_app_assigned_id)).as(operation_deal_front_star_id),
          col(forward_price_amount)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readLiqOverRateOptionsOpt(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .filter(col(fin_derv_oper_curr_flow_type) === FL)
        .select(
          trim(col(operation_sire_assigned_id)).as(sire_id),
          trim(col(oper_origin_app_assigned_id)).as(operation_deal_front_star_id),
          col(fixed_var_flow_leg_mark_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def subproductCfc(tsiOperacion: DataFrame, liqOverRateOptionsOpt: DataFrame): DataFrame = {
    try {
      tsiOperacion.join(liqOverRateOptionsOpt, Seq(operation_deal_front_star_id, sire_id), inner)
        .filter(col(financial_product_id) === CFC)
        .drop(operation_sire_assigned_id)
        .select(
          trim(col(operation_deal_front_star_id)).as(operation_deal_front_star_id),
          col(fixed_var_flow_leg_mark_type)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def tsiEconomicData(tsiSwapsIv: DataFrame, tsiSwapsCre: DataFrame, tsiSwapsTasa: DataFrame, productsIntRateOptions: DataFrame,
                      forwardIntRateProducts: DataFrame): DataFrame = {
    try {
      tsiSwapsIv.select(
        col(operation_sire_assigned_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
        col(nominal_amount), lit(emptyString).as(strike_amount), lit(emptyString).as(fndr_variable_rate_int_type), col(count_convention),
        col(fin_derv_leg_flow_frequency_name), lit(emptyString).as(break_clause_frequency_type), col(operation_repayment_number),
        col(fin_derv_oper_phase_end_date), col(fin_derv_active_value_start_date), lit(emptyString).as(fin_derv_oper_phase_start_date),
        lit(emptyString).as(underlying_expiry_date), col(fin_derv_leg_exch_int_mark_type), col(operations_date_payment_type),
        lit(emptyString).as(fin_derivative_settlement_amount), col(fin_derivative_leg_mark_type), col(current_spread_amount), col(interest_rate_amount)
      ).union(
          tsiSwapsCre.select(
            col(operation_sire_assigned_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
            col(nominal_amount), lit(emptyString), lit(emptyString), col(count_convention), lit(emptyString), lit(emptyString),
            lit(emptyString), col(fin_derv_oper_phase_end_date), col(fin_derv_active_value_start_date), col(fin_derv_oper_phase_start_date),
            lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), col(fin_derivative_leg_mark_type),
            col(current_spread_amount), lit(emptyString)
          )).union(
          tsiSwapsTasa.select(
            col(operation_sire_assigned_id), col(operation_deal_front_star_id), col(swap_legs_id), col(operation_stage_number),
            col(nominal_amount), lit(emptyString), lit(emptyString), col(count_convention), col(fin_derv_leg_flow_frequency_name),
            col(break_clause_frequency_type), col(operation_repayment_number), col(fin_derv_oper_phase_end_date), col(fin_derv_active_value_start_date),
            col(fin_derv_oper_phase_start_date), col(underlying_expiry_date), col(fin_derv_leg_exch_int_mark_type), col(operations_date_payment_type),
            col(fin_derivative_settlement_amount), lit(emptyString), col(current_spread_amount), col(interest_rate_amount)
          )).union(
          productsIntRateOptions.select(
            col(operation_sire_assigned_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
            col(purchase_sale_ctrct_amount), col(strike_amount), lit(emptyString), col(coupon_rate_name), lit(emptyString), lit(emptyString),
            lit(emptyString), col(fin_derv_oper_phase_end_date), lit(emptyString), col(fin_derv_oper_phase_start_date), lit(emptyString),
            lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString)
          )).union(
          forwardIntRateProducts.select(
            col(operation_sire_assigned_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
            col(nominal_amount), lit(emptyString), col(fndr_variable_rate_int_type), col(coupon_rate_name), lit(emptyString),
            lit(emptyString), lit(emptyString), col(fin_derv_oper_phase_end_date), lit(emptyString), col(fin_derv_oper_phase_start_date),
            col(underlying_expiry_date), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString)
          )).select(
          col(operation_sire_assigned_id).as(sire_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
          col(nominal_amount), col(strike_amount), col(fndr_variable_rate_int_type), col(count_convention).as(coupon_rate_name),
          col(fin_derv_leg_flow_frequency_name), col(break_clause_frequency_type), col(operation_repayment_number), col(fin_derv_oper_phase_end_date),
          col(fin_derv_active_value_start_date), col(fin_derv_oper_phase_start_date), col(underlying_expiry_date), col(fin_derv_leg_exch_int_mark_type),
          col(operations_date_payment_type), col(fin_derivative_settlement_amount), col(fin_derivative_leg_mark_type).as(mark_type),
          col(current_spread_amount), col(interest_rate_amount)
        ).distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def tsiEconomicDataSwaps(tsiSwapsDiv: DataFrame, internalOperMurex: DataFrame): DataFrame = {
    try {
      tsiSwapsDiv.select(lit(emptyString).as(sire_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
        col(nominal_amount), lit(emptyString).as(strike_amount), lit(emptyString).as(fndr_variable_rate_int_type), col(coupon_rate_name),
        col(fin_derv_leg_flow_frequency_name), lit(emptyString).as(break_clause_frequency_type), col(operation_repayment_number),
        lit(emptyString).as(fin_derv_oper_phase_end_date), lit(emptyString).as(fin_derv_active_value_start_date),
        lit(emptyString).as(fin_derv_oper_phase_start_date), lit(emptyString).as(underlying_expiry_date), col(fin_derv_leg_exch_int_mark_type),
        col(operations_date_payment_type), lit(emptyString).as(fin_derivative_settlement_amount), col(payment_indicator_type),
        lit(emptyString).as(current_spread_amount), lit(emptyString).as(interest_rate_amount)
      ).union(internalOperMurex.select(
            lit(nullString).cast(StringType).as(sire_id), col(operation_deal_front_star_id), col(operation_parts_number), lit(emptyString),
            lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString),
            lit(emptyString), lit(emptyString), lit(emptyString), lit(emptyString), col(fin_derv_leg_exch_int_mark_type), lit(emptyString),
            lit(emptyString), col(fin_derivative_leg_mark_type), lit(emptyString), lit(emptyString))
        ).select(col(sire_id), col(operation_deal_front_star_id), col(operation_parts_number), col(operation_stage_number),
          col(nominal_amount), col(strike_amount), col(fndr_variable_rate_int_type), col(coupon_rate_name),
          col(fin_derv_leg_flow_frequency_name), col(break_clause_frequency_type), col(operation_repayment_number), col(fin_derv_oper_phase_end_date),
          col(fin_derv_active_value_start_date), col(fin_derv_oper_phase_start_date), col(underlying_expiry_date), col(fin_derv_leg_exch_int_mark_type),
          col(operations_date_payment_type), col(fin_derivative_settlement_amount), col(payment_indicator_type).as(mark_type), col(current_spread_amount),
          col(interest_rate_amount))
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def tsiEconomicDataSwapsOpc(liqOverRateOptions: DataFrame, liquidityFlowsOverSwap: DataFrame): DataFrame = {
    try {
     liqOverRateOptions.union(
        liquidityFlowsOverSwap.select(
          col(operation_deal_front_star_id),
          col(sire_id),
          col(forward_price_amount)
        )
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readliquidityFlowsOverSwapAux(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .filter(trim(col(oper_flow_pymt_rcpt_mark_type)).isNotNull)
        .select(
          col(murex_operation_id),
          trim(col(operation_sire_assigned_id)).as(operation_sire_assigned_id),
          col(swap_legs_id),
          trim(col(oper_flow_pymt_rcpt_mark_type)).as(oper_flow_pymt_rcpt_mark_type)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def activeOperationsEconomicData(tsiOperacion: DataFrame, tsiEconomicData: DataFrame, tsiEconomicDataSwapsOpc: DataFrame,
                                   liquidityFlowsOverSwapAux: DataFrame): DataFrame = {
    try {
      tsiOperacion.join(tsiEconomicData, Seq(operation_deal_front_star_id, sire_id), left)
        .join(tsiEconomicDataSwapsOpc, Seq(operation_deal_front_star_id, sire_id), left)
        .join(liquidityFlowsOverSwapAux, col(operation_deal_front_star_id) === col(murex_operation_id) &&
          col(operation_sire_assigned_id) === tsiOperacion.col(sire_id), left)
        .drop(sire_id, murex_operation_id, mark_type, operation_sire_assigned_id, oper_flow_pymt_rcpt_mark_type)
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def activeOperationsEconomicDataSwaps(tsiOperacion: DataFrame, tsiEconomicDataSwaps: DataFrame, tsiOpcionDiv: DataFrame,
                                        liquidityFlowsOverSwapAux: DataFrame): DataFrame = {
    try {
      tsiOperacion.join(tsiEconomicDataSwaps, Seq(operation_deal_front_star_id), left)
        .join(tsiOpcionDiv, Seq(operation_deal_front_star_id), left)
        .join(liquidityFlowsOverSwapAux, col(operation_deal_front_star_id) === col(murex_operation_id) &&
          col(oper_flow_pymt_rcpt_mark_type) === col(mark_type), left)
        .drop(sire_id, murex_operation_id, mark_type, operation_sire_assigned_id, oper_flow_pymt_rcpt_mark_type)
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def activeOperations(activeOperationsEconomicData: DataFrame, activeOperationsEconomicDataSwaps: DataFrame): DataFrame = {
    try {
      activeOperationsEconomicData.union(activeOperationsEconomicDataSwaps)
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiOperacionOtc(path:String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          trim(col(sire_oper_related_info_type)).as(sire_oper_related_info_type),
          trim(col(oper_origin_app_assigned_id)).as(operation_deal_front_star_id),
          trim(col(portfolio_investment_name)).as(portfolio_type),
          trim(col(app_counterparty_id)).as(counterpart_id),
          trim(col(market_operation_type)).as(market_operation_type)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readTsiDepositos(path: String): DataFrame = {
    try {
      spark.read.parquet(path + cutoff_date_partition + hdate)
        .select(
          trim(col(oper_origin_app_assigned_id)).as(operation_deal_front_star_id),
          trim(col(operation_sire_assigned_id)).as(sire_id),
          col(operation_stage_number),
          trim(col(fin_derv_leg_flow_frequency_name)).as(fin_derv_leg_flow_frequency_name),
          trim(col(calculation_interest_name)).as(calculation_interest_name),
          trim(col(amortization1_id)).as(amortization1_id),
          trim(col(amortization_id)).as(amortization_id)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readInternalOperMurexDepos(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
        .filter(trim(col(transaction_product_type)) === LoansDeposits)
        .select(
          col(front_system_number_id).as(operation_deal_front_star_id),
          col(current_operation_nom_amount),
          trim(col(transaction_type)).as(transaction_type),
          trim(col(fin_derv_leg_exch_int_mark_type)).as(fin_derv_leg_exch_int_mark_type),
          col(forward_rate_amount),
          trim(col(underlying_main_index_id)).as(underlying_main_index_id),
          col(forward_price_amount)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def readMdcoMoneyMktBis(path: String): DataFrame = {
    try {
      spark.read.parquet(path + load_date_partition + hdate)
      .select(
        trim(col(operation_deal_front_star_id)).as(operation_deal_front_star_id),
        trim(col(seller_branch_id)).as(seller_branch_id)
      )     
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e    
    }
  }      
}
// Out:
// defined class InputReader

// %% [markdown]
// ## Process

// %%
import Constants._
import org.apache.spark.sql.functions.{abs, broadcast, coalesce, col, concat, current_timestamp, date_format, datediff, lit, lpad, months_between, regexp_replace, split, trim, udf, upper, when}
import org.apache.spark.sql.DataFrame
import org.apache.commons.lang3.exception.ExceptionUtils
import org.apache.spark.sql.types.{DateType, DecimalType, IntegerType, StringType}
import scala.util.Random

class Process(hdate: String) {

  val dateCalendar = udf((x: Int) =>
    try {
      if (x <= 365) {
        x. + ("D")
      }
      else if (x > 365 && (x / 30) > 100) {
        (x / 365). + ("Y")
      }
      else if (x > 365 && (x / 7) < 100) {
        (x / 7). + ("W")
      }
      else if (x > 365 && (x / 7) > 100) {
        (x / 30). + ("M")
      }
      else {
        x.toString
      }
    } catch {
      case e: Exception => lit("00000").toString
    }
  )

  def fixedRent(rentaFijaOpeBis: DataFrame, tsiContraparte: DataFrame, dataCountConvention: DataFrame,
                catalogApp: DataFrame, catalogPrsPcv: DataFrame, guaranteeCore: DataFrame): DataFrame = {
    try {
      rentaFijaOpeBis.join(tsiContraparte, Seq(customer_platform_id, customer_corporate_id), left)
        .join(dataCountConvention, Seq(operation_deal_front_star_id, counterpart_id), left)
        .join(catalogApp, rentaFijaOpeBis.col(source_application_id) === catalogApp.col(id), left)
        .join(broadcast(catalogPrsPcv), rentaFijaOpeBis.col(market_operation_type) === catalogPrsPcv.col(id), left)
        .join(guaranteeCore, Seq(contract_id), left)
        .select(coalesce(catalogApp.col(value), when(rentaFijaOpeBis.col(source_application_id) === emptyString, BGM_BIS)
          .otherwise(rentaFijaOpeBis.col(source_application_id))).as(gf_origin_application_id),
          coalesce(catalogApp.col(value), when(rentaFijaOpeBis.col(source_application_id) === emptyString, BGM_BIS)
            .otherwise(rentaFijaOpeBis.col(source_application_id))).as(gf_front_sys_name),
          when(col(operation_deal_front_star_id) === emptyString, lit(tenZero)).when(col(operation_deal_front_star_id) === zero_string, lit(tenZero))
            .when(col(operation_deal_front_star_id) === 0, col(operation_deal_back_star_id))
            .otherwise(col(operation_deal_front_star_id)).as(gf_front_sys_trd_id),
          when(col(operation_deal_back_star_id) === emptyString, lit(tenZero))
            .when(col(operation_deal_back_star_id) === zero_string, lit(tenZero)).otherwise(col(operation_deal_back_star_id)).as(gf_back_sys_trd_id),
          lit(oneString).cast(IntegerType).as(gf_trd_leg_id), lit(oneString).as(gf_trd_phase_id),
          lit(nullString).cast(StringType).as(gf_trd_leg_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_leg_adj_trmnt_date),
          lit(nullString).cast(StringType).as(gf_trd_phase_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_phase_adj_trmnt_date),
          abs(col(total_securities_nominal_amount)).as(gf_underlying_amount), abs(col(initial_amount)).as(gf_settl_amount),
          when(col(market_operation_type).isin(CD, OPR, CR), PAYER)
            .when(col(market_operation_type).isin(GET, VR, VD, GET), RECEIVER).as(gf_trd_party_payer_recv_type),
          col(isin_id).as(g_undly_asset_isin_id), lit(X).as(g_call_put_option_type), lit(nullString).cast(StringType).as(g_exercise_option_type),
          lit(nullString).cast(StringType).as(g_option_exercise_freq_type), lit(nullString).cast(StringType).as(gf_opt_adj_ex_dt_desc),
          col(market_operation_start_date).as(gf_am_opt_fst_ex_adj_date), lit(nullString).cast(StringType).as(gf_option_strike_amount),
          col(coupon_rate_type).as(g_interest_rate_type), dateCalendar(col(coupon_term_days_number)).as(g_interest_pymt_frequency_type),
          lit(nullString).cast(StringType).as(gf_pmt_dt_ref_typo_desc), lit(nullString).cast(StringType).as(gf_upfront_pmt_amount),
          coalesce(when(col(coupon_rate_type) === F, col(return_interest_rate_per).cast(DecimalType(fifteen, four))), lit(nullString)).as(gf_fixed_rate_per),
          lit(nullString).cast(StringType).as(g_amortization_frequency_type),
          coalesce(when(col(coupon_rate_type) === V, col(return_interest_rate_per).cast(DecimalType(fifteen, four))), lit(nullString)).as(gf_float_rt_ini_per),
          col(return_interest_rate_per).cast(DecimalType(fifteen, four)).as(gf_current_interest_rate_per),
          lit(nullString).cast(StringType).as(gf_net_life_cap_per), lit(nullString).cast(StringType).as(gf_net_life_floor_per),
          lit(nullString).cast(StringType).as(gf_swap_tenor_months_number), lit(nullString).cast(StringType).as(g_day_count_convention_type),
          dateCalendar(col(coupon_term_days_number)).as(g_compounding_frequency_type), lit(nullString).cast(StringType).as(g_renewal_frequency_type),
          concat((split(col(coupon_rate_name), "/")(1)), lit(" "), (split(col(coupon_rate_name), "/")(2))).as(g_reference_index_id),
          lit(nullString).cast(StringType).as(g_amortization_type),
          when(datediff(col(market_operation_settlement_date), date_format(lit(hdate), "yyyy-MM-dd")) > 2, col(current_commitment_amount))
            .otherwise(nullString).as(gf_forward_price_amount),
          lit(nullString).cast(StringType).as(gf_fx_forward_exch_rate_amount), lit(nullString).cast(StringType).as(gf_am_opt_lst_ex_adj_date),
          concat(
            lit(MX0074),
            when(col(seller_branch_id).isNull, lit(FourZeros))
              .otherwise(lpad(trim(col(seller_branch_id)), four, zero_string)),
            when(col(operation_deal_front_star_id) === emptyString, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === zero_string, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === 0, col(operation_deal_back_star_id))
              .otherwise(col(operation_deal_front_star_id))
          ).as(gf_local_contract_number_id),
          col(return_interest_rate_per).as(gf_sec_irr_per),
          col(guarantee_type).as(gf_colat_typo_desc),
          col(isin_id_coll).as(gf_collateral_isin_desc),
          col(current_guaranteed_amount).as(gf_colat_nmnl_amt_desc),
          col(return_interest_rate_per).cast(DecimalType(twelve, nine)).as(gf_initial_interest_rate_per),
          coalesce(catalogPrsPcv.col(value), lit(X)).as(g_trade_position_type),
          col(current_rate_coupon_per).cast(DecimalType(twelve, nine)).as(gf_ref_index_interest_rate_per)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def forexTrading(sireFxPrdt: DataFrame, tsiOperacion: DataFrame, tsiFwdDiv: DataFrame, catalogApp: DataFrame,
                   catalogPrsPcv: DataFrame, guaranteeCore: DataFrame, catalogPrev: DataFrame): DataFrame = {
    try {
      sireFxPrdt.join(tsiOperacion, Seq(operation_deal_front_star_id, counterpart_id), left)
        .join(tsiFwdDiv, Seq(operation_deal_front_star_id), left)
        .join(catalogApp, sireFxPrdt.col(source_application_id) === catalogApp.col(id), left)
        .join(broadcast(catalogPrsPcv), sireFxPrdt.col(operation_nature_type) === catalogPrsPcv.col(id), left)
        .join(guaranteeCore, col(operation_deal_front_star_id) === guaranteeCore.col(contract_id), left)
        .join(catalogPrev, col(calculation_base_currency_type) === col(local_type), left)
        .select(coalesce(catalogApp.col(value), when(sireFxPrdt.col(source_application_id) === emptyString, BGM_BIS)
          .otherwise(sireFxPrdt.col(source_application_id))).as(gf_origin_application_id),
          coalesce(catalogApp.col(value), when(sireFxPrdt.col(source_application_id) === emptyString, BGM_BIS)
            .otherwise(sireFxPrdt.col(source_application_id))).as(gf_front_sys_name),
          col(operation_deal_front_star_id).as(gf_front_sys_trd_id), col(operation_deal_back_star_id).as(gf_back_sys_trd_id),
          lit(oneString).cast(IntegerType).as(gf_trd_leg_id), lit(oneString).as(gf_trd_phase_id),
          lit(nullString).cast(StringType).as(gf_trd_leg_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_leg_adj_trmnt_date),
          lit(nullString).cast(StringType).as(gf_trd_phase_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_phase_adj_trmnt_date),
          col(market_oper_recv_notional_amount).as(gf_underlying_amount), abs(col(market_oper_recv_notional_amount)).alias(gf_settl_amount),
          when(col(operation_nature_type) === COMPRA, PAYER)
            .when(col(operation_nature_type) === VENTA, RECEIVER).as(gf_trd_party_payer_recv_type),
          lit(emptyString).as(g_undly_asset_isin_id), lit(X).as(g_call_put_option_type),
          lit(nullString).cast(StringType).as(g_exercise_option_type), lit(nullString).cast(StringType).as(g_option_exercise_freq_type),
          lit(nullString).cast(StringType).as(gf_opt_adj_ex_dt_desc), lit(nullString).cast(StringType).as(gf_am_opt_fst_ex_adj_date),
          lit(nullString).cast(StringType).as(gf_option_strike_amount), lit(nullString).cast(StringType).as(g_interest_rate_type),
          lit(nullString).cast(StringType).as(g_interest_pymt_frequency_type), lit(nullString).cast(StringType).as(gf_pmt_dt_ref_typo_desc),
          lit(nullString).cast(StringType).as(gf_upfront_pmt_amount), lit(nullString).cast(StringType).as(gf_fixed_rate_per),
          lit(nullString).cast(StringType).as(g_amortization_frequency_type), lit(nullString).cast(StringType).as(gf_float_rt_ini_per),
          lit(nullString).cast(StringType).as(gf_current_interest_rate_per), lit(nullString).cast(StringType).as(gf_net_life_cap_per),
          lit(nullString).cast(StringType).as(gf_net_life_floor_per), lit(nullString).cast(StringType).as(gf_swap_tenor_months_number),
          when(col(holding_id).isNull, lit("XX")).otherwise(col(holding_id)).as(g_day_count_convention_type),
          lit(nullString).cast(StringType).as(g_compounding_frequency_type), lit(nullString).cast(StringType).as(g_renewal_frequency_type),
          lit(nullString).cast(StringType).as(g_reference_index_id), lit(nullString).cast(StringType).as(g_amortization_type),
          col(forward_price_amount).as(gf_forward_price_amount), col(forward_price_amount).as(gf_fx_forward_exch_rate_amount),
          lit(nullString).cast(StringType).as(gf_am_opt_lst_ex_adj_date),
          concat(
            lit(MX0074),
            when(col(seller_branch_id).isNull, lit(FourZeros))
              .otherwise(lpad(trim(col(seller_branch_id)), four, zero_string)),
            when(col(operation_deal_front_star_id) === emptyString, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === zero_string, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === 0, col(operation_deal_back_star_id))
              .otherwise(col(operation_deal_front_star_id))
          ).as(gf_local_contract_number_id),
          lit(nullString).cast(StringType).as(gf_sec_irr_per),
          col(guarantee_type).as(gf_colat_typo_desc), col(isin_id_coll).as(gf_collateral_isin_desc),
          col(current_guaranteed_amount).as(gf_colat_nmnl_amt_desc),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_initial_interest_rate_per),
          coalesce(catalogPrsPcv.col(value), lit(X)).as(g_trade_position_type),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_ref_index_interest_rate_per)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }


  def organizedMarkets(derivadosMmooBis: DataFrame, tsiOperacion: DataFrame, tsiSwapsTasa: DataFrame, tsiOperacionMmo: DataFrame,
                       catalogOptionType: DataFrame, catalogApp: DataFrame, guaranteeCore: DataFrame,
                       catalogPrev: DataFrame): DataFrame = {
    try {
      derivadosMmooBis.join(tsiOperacion, Seq(operation_deal_front_star_id, counterpart_id), left)
        .join(tsiSwapsTasa, Seq(operation_deal_front_star_id), left)
        .join(catalogOptionType, col(warrant_type) === col(gf_catlg_field_value_es_desc), left)
        .join(tsiOperacionMmo, Seq(operation_deal_front_star_id, counterpart_id), left)
        .join(catalogApp, derivadosMmooBis.col(source_application_id) === catalogApp.col(id), left)
        .join(guaranteeCore, col(operation_deal_front_star_id) === guaranteeCore.col(contract_id), left)
        .join(catalogPrev, col(calculation_interest_name) === col(local_type), left)
        .select(coalesce(catalogApp.col(value), when(derivadosMmooBis.col(source_application_id) === emptyString, BGM_BIS)
          .otherwise(derivadosMmooBis.col(source_application_id))).as(gf_origin_application_id),
          coalesce(catalogApp.col(value), when(derivadosMmooBis.col(source_application_id) === emptyString, BGM_BIS)
            .otherwise(derivadosMmooBis.col(source_application_id))).as(gf_front_sys_name),
          col(operation_deal_front_star_id).as(gf_front_sys_trd_id), col(operation_deal_back_star_id).as(gf_back_sys_trd_id),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_leg_exch_int_mark_type) + 1), lit(oneString)).cast(IntegerType).as(gf_trd_leg_id),
          coalesce(when(col(product_type) =!= F3, when(col(operation_stage_number) === 0, col(operation_stage_number) + 1).
            otherwise(col(operation_stage_number))), lit(oneString)).as(gf_trd_phase_id),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_active_value_start_date)), lit(nullString)).cast(StringType).as(gf_trd_leg_adj_eff_date),
          coalesce(when(col(product_type) =!= F3, col(underlying_expiry_date)), lit(nullString)).cast(StringType).as(gf_trd_leg_adj_trmnt_date),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_oper_phase_start_date)), lit(nullString)).cast(StringType).as(gf_trd_phase_adj_eff_date),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_oper_phase_end_date)), lit(nullString)).cast(StringType).as(gf_trd_phase_adj_trmnt_date),
          abs(when(col(trading_mark_type) === V, col(market_oper_pay_notional_amount)).otherwise(col(market_oper_recv_notional_amount)))
            .as(gf_underlying_amount),
          when(col(product_type) === IRS, col(fin_derivative_settlement_amount)).otherwise(col(market_oper_pay_notional_amount)).as(gf_settl_amount),
          when((when(col(product_type).isin(IRS, IRC), col(market_operation_type)).otherwise(col(trading_mark_type))) === C, PAYER)
            .otherwise(RECEIVER).as(gf_trd_party_payer_recv_type),
          col(isin_id).as(g_undly_asset_isin_id), coalesce(col(gf_catalog_val_id), lit(X)).as(g_call_put_option_type),
          col(option_style_mark_type).as(g_exercise_option_type), lit(nullString).cast(StringType).as(g_option_exercise_freq_type),
          coalesce(when(col(product_type).isin(optProd: _*), col(expiration_date)), lit(nullString)).cast(StringType).as(gf_opt_adj_ex_dt_desc),
          coalesce(when(col(option_style_mark_type) === A, col(value_date)), lit(nullString)).cast(StringType).as(gf_am_opt_fst_ex_adj_date),
          derivadosMmooBis.col(strike_amount).as(gf_option_strike_amount),
          coalesce(when(col(product_type) =!= F3, (when(col(fin_derv_leg_exch_int_mark_type) === zero_string, F).
            when(col(fin_derv_leg_exch_int_mark_type) === oneString, V))), lit(nullString)).cast(StringType).as(g_interest_rate_type),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_leg_flow_frequency_name)), lit(nullString)).cast(StringType).as(g_interest_pymt_frequency_type),
          lit(nullString).cast(StringType).as(gf_pmt_dt_ref_typo_desc), lit("-").as(gf_upfront_pmt_amount),
          coalesce(when(col(product_type) =!= F3, (when(col(fin_derv_leg_exch_int_mark_type) === zero_string, col(current_spread_amount)))), lit(nullString))
            .cast(StringType).as(gf_fixed_rate_per),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_leg_flow_frequency_name)), lit(nullString)).as(g_amortization_frequency_type),
          coalesce(when(col(product_type) =!= F3, (when(col(fin_derv_leg_exch_int_mark_type) === oneString, col(interest_rate_amount)))), lit(nullString))
            .cast(StringType).as(gf_float_rt_ini_per),
          when(col(product_type) =!= F3, (when(col(fin_derv_leg_exch_int_mark_type) === oneString, col(forward_swap_pay_rate_amount))
            .otherwise(col(forward_swap_recv_rate_amount)))).as(gf_current_interest_rate_per),
          lit(nullString).cast(StringType).as(gf_net_life_cap_per), lit(nullString).cast(StringType).as(gf_net_life_floor_per),
          lit(nullString).cast(StringType).as(gf_swap_tenor_months_number),
          when(col(holding_id).isNull, lit("XX")).otherwise(col(holding_id)).as(g_day_count_convention_type),
          coalesce(when(col(product_type) =!= F3, col(fin_derv_leg_flow_frequency_name)), lit(nullString)).as(g_compounding_frequency_type),
          lit(nullString).cast(StringType).as(g_renewal_frequency_type),
          coalesce(when(col(product_type) =!= F3, when(col(fin_derv_leg_exch_int_mark_type) === oneString, col(underline_reference_type))), lit(emptyString))
            .cast(StringType).as(g_reference_index_id),
          coalesce(when(col(product_type) =!= F3, col(operation_repayment_number)), lit(nullString)).cast(StringType).as(g_amortization_type),
          col(contract_amount).as(gf_forward_price_amount), col(contract_amount).as(gf_fx_forward_exch_rate_amount),
          coalesce(when((col(product_type).isin(optProd: _*)) && (col(option_style_mark_type) === A), col(expiration_date)), lit(nullString))
            .cast(StringType).as(gf_am_opt_lst_ex_adj_date),
          concat(
            lit(MX0074),
            when(col(seller_branch_id).isNull, lit(FourZeros))
              .otherwise(lpad(trim(col(seller_branch_id)), four, zero_string)),
            when(col(operation_deal_front_star_id) === emptyString, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === zero_string, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === 0, col(operation_deal_back_star_id))
              .otherwise(col(operation_deal_front_star_id))
          ).as(gf_local_contract_number_id),
          lit(nullString).cast(StringType).as(gf_sec_irr_per), col(guarantee_type).as(gf_colat_typo_desc),
          col(isin_id_coll).as(gf_collateral_isin_desc),
          col(current_guaranteed_amount).as(gf_colat_nmnl_amt_desc),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_initial_interest_rate_per),
          coalesce(when(col(product_type).isin(IRS, IRC),
            col(market_operation_type)).otherwise(col(trading_mark_type)), lit(X)).as(g_trade_position_type),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_ref_index_interest_rate_per)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }


  def overTheCounter(finDervOtcBis: DataFrame, activeOperations: DataFrame, catalogOptionType: DataFrame, subproductCfc: DataFrame,
                     catalogApp: DataFrame, tsiOperacionOtc: DataFrame, guaranteeCore: DataFrame, catalogPrev: DataFrame): DataFrame = {
    try {
      finDervOtcBis.join(activeOperations, Seq(operation_deal_front_star_id), left)
        .join(catalogOptionType, col(warrant_type) === col(gf_catlg_field_value_es_desc), left)
        .join(subproductCfc, Seq(operation_deal_front_star_id), left)
        .join(catalogApp, finDervOtcBis.col(source_application_id) === catalogApp.col(id), left)
        .join(tsiOperacionOtc, Seq(operation_deal_front_star_id, portfolio_type, counterpart_id), left)
        .join(guaranteeCore, col(operation_deal_front_star_id) === guaranteeCore.col(contract_id), left)
        .join(catalogPrev, col(coupon_rate_name) === col(local_type), left)
        .select(
          coalesce(catalogApp.col(value), when(finDervOtcBis.col(source_application_id) === emptyString, BGM_BIS)
            .otherwise(finDervOtcBis.col(source_application_id))).as(gf_origin_application_id),
          coalesce(catalogApp.col(value), when(finDervOtcBis.col(source_application_id) === emptyString, BGM_BIS)
            .otherwise(finDervOtcBis.col(source_application_id))).as(gf_front_sys_name),
          col(operation_deal_front_star_id).as(gf_front_sys_trd_id), col(operation_deal_back_star_id).as(gf_back_sys_trd_id),
          coalesce((col(swap_legs_id) + 1), (col(operation_parts_number) + 1), lit(oneString)).cast(IntegerType).as(gf_trd_leg_id),
          coalesce(when(col(operation_stage_number) === 0, (col(operation_stage_number) + 1)).otherwise(col(operation_stage_number)),
            lit(oneString)).as(gf_trd_phase_id), col(contract_register_date).as(gf_trd_leg_adj_eff_date),
          col(market_operation_expiry_date).as(gf_trd_leg_adj_trmnt_date), col(market_operation_start_date).as(gf_trd_phase_adj_eff_date),
          coalesce(col(fin_derv_oper_phase_end_date), col(underlying_expiry_date)).as(gf_trd_phase_adj_trmnt_date),
          abs(col(nominal_amount).cast(DecimalType(twenty_six, six))).as(gf_underlying_amount),
          when(col(product_type) === IRS, col(fin_derivative_settlement_amount)).otherwise(lit(nullString)).as(gf_settl_amount),
          when((when(tsiOperacionOtc.col(market_operation_type).isNotNull, tsiOperacionOtc.col(market_operation_type))
            .otherwise(col(trading_mark_type))) === C, PAYER).otherwise(RECEIVER).as(gf_trd_party_payer_recv_type),
          col(isin_id).as(g_undly_asset_isin_id), coalesce(col(gf_catalog_val_id), lit(X)).as(g_call_put_option_type),
          col(option_style_mark_type).substr(0, 1).as(g_exercise_option_type), lit(nullString).cast(StringType).as(g_option_exercise_freq_type),
          when(col(product_type).contains(OPCIONES), col(expiration_date)).as(gf_opt_adj_ex_dt_desc),
          when(col(product_type).contains(OPCIONES) && col(option_style_mark_type) === AMERICANA, col(value_date)).as(gf_am_opt_fst_ex_adj_date),
          col(strike_amount).as(gf_option_strike_amount),
          coalesce(when(subproductCfc.col(fixed_var_flow_leg_mark_type) === F || col(fin_derv_leg_exch_int_mark_type) === zero_string, F)
            .when(subproductCfc.col(fixed_var_flow_leg_mark_type) === V || col(fin_derv_leg_exch_int_mark_type) === oneString, V),
            lit(nullString)).as(g_interest_rate_type),
          col(fin_derv_leg_flow_frequency_name).cast(StringType).as(g_interest_pymt_frequency_type),
          col(operations_date_payment_type).cast(StringType).as(gf_pmt_dt_ref_typo_desc), lit(nullString).cast(StringType).as(gf_upfront_pmt_amount),
          abs((coalesce(when(subproductCfc.col(fixed_var_flow_leg_mark_type) === F ||
            (col(fin_derv_leg_exch_int_mark_type) === zero_string &&
              col(product_type) =!= WARRANTN), coalesce(col(current_spread_amount), col(forward_swap_recv_rate_amount))),
            lit(nullString))).cast(DecimalType(twelve, nine))).as(gf_fixed_rate_per), col(fin_derv_leg_flow_frequency_name)
            .cast(StringType).as(g_amortization_frequency_type),
          abs((coalesce(when(subproductCfc.col(fixed_var_flow_leg_mark_type) === V ||
            (col(fin_derv_leg_exch_int_mark_type) === oneString &&
              col(product_type) =!= WARRANTN), coalesce(col(interest_rate_amount), col(forward_swap_pay_rate_amount))),
            lit(nullString))).cast(DecimalType(twelve, nine))).as(gf_float_rt_ini_per), when(col(fin_derv_leg_exch_int_mark_type) === oneString,
            col(forward_swap_pay_rate_amount))
            .otherwise(col(forward_swap_recv_rate_amount)).as(gf_current_interest_rate_per), col(maximum_operation_rate_per)
            .cast(StringType).as(gf_net_life_cap_per),
          col(minimum_operation_rate_per).cast(StringType).as(gf_net_life_floor_per),
          when(col(subproduct_type) === OSW, months_between(col(fin_derv_oper_phase_end_date), col(fin_derv_oper_phase_start_date)))
            .cast(DecimalType(eight, four)).as(gf_swap_tenor_months_number),
          when(col(holding_id).isNull, lit(XX)).otherwise(col(holding_id)).as(g_day_count_convention_type),
          col(fin_derv_leg_flow_frequency_name).as(g_compounding_frequency_type),
          lit(nullString).as(g_renewal_frequency_type),
          coalesce(when(subproductCfc.col(fixed_var_flow_leg_mark_type) === V || col(fin_derv_leg_exch_int_mark_type) === oneString,
            col(underline_reference_type)), lit(emptyString)).as(g_reference_index_id),
          col(operation_repayment_number).as(g_amortization_type), col(forward_price_amount).as(gf_forward_price_amount),
          col(forward_price_amount).as(gf_fx_forward_exch_rate_amount),
          coalesce(when(col(product_type).contains(OPCIONES) && col(option_style_mark_type) === AMERICANA, col(expiration_date)),
            lit(nullString)).as(gf_am_opt_lst_ex_adj_date),
          concat(
            lit(MX0074),
            when(col(seller_branch_id).isNull, lit(FourZeros))
              .otherwise(lpad(trim(col(seller_branch_id)), four, zero_string)),
            when(col(operation_deal_front_star_id) === emptyString, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === zero_string, lit(ten_zero))
              .when(col(operation_deal_front_star_id) === zero, col(operation_deal_back_star_id))
              .otherwise(col(operation_deal_front_star_id))
          ).as(gf_local_contract_number_id),
          lit(emptyString).as(gf_sec_irr_per), col(guarantee_type).as(gf_colat_typo_desc),
          col(isin_id_coll).as(gf_collateral_isin_desc),
          col(current_guaranteed_amount).as(gf_colat_nmnl_amt_desc),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_initial_interest_rate_per),
          coalesce(col(trading_mark_type), lit(X)).as(g_trade_position_type),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_ref_index_interest_rate_per)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def deposits(internalOperMurexDepos: DataFrame, tsiOperacion: DataFrame, tsiDepositos: DataFrame, guranteeCore: DataFrame,
               catalogPrev: DataFrame, mdcoMoneyMktBis: DataFrame): DataFrame = {
    try {
      internalOperMurexDepos
        .join(tsiOperacion, Seq(operation_deal_front_star_id), left)
        .join(tsiDepositos, Seq(operation_deal_front_star_id, sire_id), left)
        .join(guranteeCore, Seq(contract_id), left)
        .join(catalogPrev, col(calculation_interest_name) === col(local_type), left)
        .join(mdcoMoneyMktBis, Seq(operation_deal_front_star_id), left)
        .select(lit(MUREX).as(gf_origin_application_id), lit(MUREX).as(gf_front_sys_name),
          col(operation_deal_front_star_id).as(gf_front_sys_trd_id), lit(nullString).cast(StringType).as(gf_back_sys_trd_id),
          lit(oneString).cast(IntegerType).as(gf_trd_leg_id),
          coalesce(when(tsiDepositos.col(operation_stage_number) === zero, tsiDepositos.col(operation_stage_number) + 1)
            .otherwise(tsiDepositos.col(operation_stage_number)), lit(oneString)).as(gf_trd_phase_id),
          lit(nullString).cast(StringType).as(gf_trd_leg_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_leg_adj_trmnt_date),
          lit(nullString).cast(StringType).as(gf_trd_phase_adj_eff_date), lit(nullString).cast(StringType).as(gf_trd_phase_adj_trmnt_date),
          abs(col(current_operation_nom_amount)).as(gf_underlying_amount), lit(nullString).cast(StringType).as(gf_settl_amount),
          when(col(transaction_type) === B, PAYER).when(col(transaction_type) === S, RECEIVER).as(gf_trd_party_payer_recv_type),
          lit(nullString).cast(StringType).as(g_undly_asset_isin_id), lit(X).as(g_call_put_option_type),
          lit(nullString).cast(StringType).as(g_exercise_option_type), lit(nullString).cast(StringType).as(g_option_exercise_freq_type),
          lit(nullString).cast(StringType).as(gf_opt_adj_ex_dt_desc), lit(nullString).cast(StringType).as(gf_am_opt_fst_ex_adj_date),
          lit(nullString).cast(StringType).as(gf_option_strike_amount), col(fin_derv_leg_exch_int_mark_type).as(g_interest_rate_type),
          tsiDepositos.col(fin_derv_leg_flow_frequency_name).as(g_interest_pymt_frequency_type),
          lit(nullString).cast(StringType).as(gf_pmt_dt_ref_typo_desc), lit(nullString).cast(StringType).as(gf_upfront_pmt_amount),
          coalesce(when(col(fin_derv_leg_exch_int_mark_type) === F, col(forward_rate_amount)), lit(nullString)).as(gf_fixed_rate_per),
          lit(nullString).cast(StringType).as(g_amortization_frequency_type),
          coalesce(when(col(fin_derv_leg_exch_int_mark_type) === V, col(forward_rate_amount)), lit(nullString)).as(gf_float_rt_ini_per),
          col(forward_rate_amount).as(gf_current_interest_rate_per),
          lit(nullString).cast(StringType).as(gf_net_life_cap_per), lit(nullString).cast(StringType).as(gf_net_life_floor_per),
          lit(nullString).cast(StringType).as(gf_swap_tenor_months_number),
          when(col(holding_id).isNull, lit(XX)).otherwise(col(holding_id)).as(g_day_count_convention_type),
          tsiDepositos.col(fin_derv_leg_flow_frequency_name).as(g_compounding_frequency_type),
          tsiDepositos.col(fin_derv_leg_flow_frequency_name).as(g_renewal_frequency_type),
          col(underlying_main_index_id).as(g_reference_index_id),
          coalesce(col(amortization1_id), col(amortization_id)).as(g_amortization_type), col(forward_price_amount).as(gf_forward_price_amount),
          lit(nullString).cast(StringType).as(gf_fx_forward_exch_rate_amount), lit(nullString).cast(StringType).as(gf_am_opt_lst_ex_adj_date),
          concat(
            lit(MX0074),
            when(col(seller_branch_id).isNull, lit(FourZeros))
              .otherwise(lpad(trim(col(seller_branch_id)), four, zero_string)),
            col(operation_deal_front_star_id)
          ).as(gf_local_contract_number_id),
          lit(nullString).cast(StringType).as(gf_sec_irr_per), col(guarantee_type).as(gf_colat_typo_desc), col(isin_id_coll).as(gf_collateral_isin_desc),
          col(current_guaranteed_amount).as(gf_colat_nmnl_amt_desc),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_initial_interest_rate_per),
          coalesce(col(transaction_type), lit(X)).as(g_trade_position_type),
          lit(nullString).cast(DecimalType(twelve, nine)).as(gf_ref_index_interest_rate_per)
        )
        .distinct()
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  def tradeProd(fixedRent: DataFrame, forexTrading: DataFrame, organizedMarkets: DataFrame, overTheCounter: DataFrame, deposits: DataFrame): DataFrame = {
    try {
      fixedRent.union(forexTrading).union(organizedMarkets).union(overTheCounter).union(deposits)
        .select(
          when(col(gf_origin_application_id) === emptyString, BGM_BIS).otherwise(col(gf_origin_application_id))
            .as(gf_origin_application_id_aux),
          col(gf_front_sys_name).as(gf_front_sys_name_aux),
          col(gf_front_sys_trd_id).as(gf_front_sys_trd_id_aux),
          col(gf_back_sys_trd_id).as(gf_back_sys_trd_id_aux),
          col(gf_trd_leg_id).as(gf_trd_leg_id_aux),
          col(gf_trd_phase_id).as(gf_trd_phase_id_aux),
          col(gf_trd_leg_adj_eff_date).as(gf_trd_leg_adj_eff_date_aux),
          col(gf_trd_leg_adj_trmnt_date).as(gf_trd_leg_adj_trmnt_date_aux),
          col(gf_trd_phase_adj_eff_date).as(gf_trd_phase_adj_eff_date_aux),
          col(gf_trd_phase_adj_trmnt_date).as(gf_trd_phase_adj_trmnt_date_aux),
          col(gf_underlying_amount).as(gf_underlying_amount_aux),
          col(gf_settl_amount).as(gf_settl_amount_aux),
          col(gf_trd_party_payer_recv_type).as(gf_trd_party_payer_recv_type_aux),
          col(g_undly_asset_isin_id).as(g_undly_asset_isin_id_aux),
          col(g_call_put_option_type).as(g_call_put_option_type_aux),
          col(g_exercise_option_type).as(g_exercise_option_type_aux),
          col(g_option_exercise_freq_type).as(g_option_exercise_freq_type_aux),
          col(gf_opt_adj_ex_dt_desc).as(gf_opt_adj_ex_dt_desc_aux),
          col(gf_am_opt_fst_ex_adj_date).as(gf_am_opt_fst_ex_adj_date_aux),
          col(gf_option_strike_amount).as(gf_option_strike_amount_aux),
          col(g_interest_rate_type).as(g_interest_rate_type_aux),
          col(g_interest_pymt_frequency_type).as(g_interest_pymt_frequency_type_aux),
          col(gf_pmt_dt_ref_typo_desc).as(gf_pmt_dt_ref_typo_desc_aux),
          col(gf_upfront_pmt_amount).as(gf_upfront_pmt_amount_aux),
          col(gf_fixed_rate_per).as(gf_fixed_rate_per_aux),
          col(g_amortization_frequency_type).as(g_amortization_frequency_type_aux),
          col(gf_float_rt_ini_per).as(gf_float_rt_ini_per_aux),
          col(gf_current_interest_rate_per).as(gf_current_interest_rate_per_aux),
          col(gf_net_life_cap_per).as(gf_net_life_cap_per_aux),
          col(gf_net_life_floor_per).as(gf_net_life_floor_per_aux),
          col(gf_swap_tenor_months_number).as(gf_swap_tenor_months_number_aux),
          col(g_day_count_convention_type).as(g_day_count_convention_type_aux),
          col(g_compounding_frequency_type).as(g_compounding_frequency_type_aux),
          col(g_renewal_frequency_type).as(g_renewal_frequency_type_aux),
          col(g_reference_index_id).as(g_reference_index_id_aux),
          col(g_amortization_type).as(g_amortization_type_aux),
          col(gf_forward_price_amount).as(gf_forward_price_amount_aux),
          col(gf_fx_forward_exch_rate_amount).as(gf_fx_forward_exch_rate_amount_aux),
          col(gf_am_opt_lst_ex_adj_date).as(gf_am_opt_lst_ex_adj_date_aux),
          col(gf_local_contract_number_id).as(gf_local_contract_number_id_aux),
          col(gf_sec_irr_per).as(gf_sec_irr_per_aux),
          col(gf_colat_typo_desc).as(gf_colat_typo_desc_aux),
          col(gf_collateral_isin_desc).as(gf_collateral_isin_desc_aux),
          col(gf_colat_nmnl_amt_desc).as(gf_colat_nmnl_amt_desc_aux),
          when(col(g_trade_position_type).isNotNull && col(g_trade_position_type) =!= lit(nullString), col(g_trade_position_type))
            .otherwise(lit(X))
            .as(g_trade_position_type_aux),
          col(gf_initial_interest_rate_per).as(gf_initial_interest_rate_per_aux),
          col(gf_ref_index_interest_rate_per).as(gf_ref_index_interest_rate_per_aux)
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

}
// Out:
// defined class Process

// %% [markdown]
// ## PreLayout

// %%
import Constants._
import org.apache.spark.sql.functions.{col, lit, current_timestamp, concat}
import org.apache.spark.sql.DataFrame
import org.apache.commons.lang3.exception.ExceptionUtils
import org.apache.spark.sql.types.{IntegerType, DecimalType, StringType, DateType, TimestampType}
import scala.util.Random

trait LayoutTradeProd {

  def finalLayout(data: DataFrame, odate: String): DataFrame = {
    try {
      sixPartLayout(fifthPartLayout(fourthPartLayout(thirdPartLayout(secondPartLayout(firstPartLayout(data, odate))))), odate)
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }

  }

  private def firstPartLayout(data: DataFrame, odate: String): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(MX).as(g_entific_id), col(gf_origin_application_id_aux).cast(StringType).as(gf_origin_application_id),
        col(gf_front_sys_name_aux).cast(StringType).as(gf_front_sys_name), lit(nullString).cast(StringType).as(gf_trade_region_id),
        col(gf_front_sys_trd_id_aux).cast(StringType).as(gf_front_sys_trd_id), col(gf_back_sys_trd_id_aux).cast(StringType).as(gf_back_sys_trd_id),
        col(gf_local_contract_number_id_aux).cast(StringType).as(gf_local_contract_number_id), col(gf_trd_leg_id_aux).cast(StringType).as(gf_trd_leg_id),
        col(gf_trd_phase_id_aux).cast(StringType).as(gf_trd_phase_id), lit(nullString).cast(DateType).as(gf_trd_date),
        lit(nullString).cast(StringType).as(gf_trd_strategy_id), lit(nullString).cast(StringType).as(gf_telemaco_trade_id),
        col(gf_trd_party_payer_recv_type_aux).cast(StringType).as(gf_trd_party_payer_recv_type), lit(nullString)
          .cast(StringType).as(gf_trd_info_period_typo_desc),
        lit(odate).cast(DateType).as(gf_cutoff_date), lit(MX0074).cast(StringType).as(g_entity_id),
        lit(nullString).cast(StringType).as(gf_srce_system_entity_id), lit(nullString).cast(StringType).as(gf_entity_name),
        lit(nullString).cast(DateType).as(gf_front_sys_trd_info_date), lit(nullString).cast(TimestampType).as(gf_front_sys_trd_info_tme_date),
        lit(nullString).cast(DateType).as(gf_trd_leg_unadj_eff_date), lit(nullString).cast(StringType).as(gf_trd_leg_eff_dt_bdc_desc),
        col(gf_trd_leg_adj_eff_date_aux).cast(DateType).as(gf_trd_leg_adj_eff_date), lit(nullString).cast(DateType).as(gf_trd_leg_unadj_trmnt_date),
        lit(nullString).cast(StringType).as(gf_trd_leg_trmnt_dt_bdc_desc), col(gf_trd_leg_adj_trmnt_date_aux).cast(DateType).as(gf_trd_leg_adj_trmnt_date),
        lit(nullString).cast(DateType).as(gf_trd_phase_unadj_eff_date), lit(nullString).cast(StringType).as(gf_trd_phase_eff_dt_bdc_desc),
        col(gf_trd_phase_adj_eff_date_aux).cast(DateType).as(gf_trd_phase_adj_eff_date), lit(nullString).cast(DateType).as(gf_trd_phase_unadj_trmnt_date),
        lit(nullString).cast(StringType).as(gf_trd_phase_trmnt_dt_bdc_desc),
        col(gf_trd_phase_adj_trmnt_date_aux).cast(DateType).as(gf_trd_phase_adj_trmnt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_leg_notl_amount), lit(nullString).cast(StringType).as(g_trd_leg_notl_curncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_leg_curr_notl_amount), lit(nullString).cast(StringType).as(g_trd_leg_curr_notl_curncy_id),
        lit(nullString).cast(StringType).as(gf_underline_asset_id), col(g_undly_asset_isin_id_aux).cast(StringType).as(g_undly_asset_isin_id),
        lit(nullString).cast(StringType).as(gf_undly_asset_name), lit(nullString).cast(StringType).as(gf_undly_asset_murex_id),
        lit(nullString).cast(StringType).as(gf_undly_asset_bloomberg_id), lit(nullString).cast(StringType).as(gf_undly_secur_label_desc),
        lit(nullString).cast(DateType).as(gf_undly_asset_effective_date),
        col(gf_underlying_amount_aux).cast(DecimalType(twenty_six, six)).as(gf_underlying_amount),
        lit(nullString).cast(StringType).as(g_undly_curncy_id), lit(nullString).cast(StringType).as(gf_udl_divd_valtn_dt_bdc_desc),
        lit(nullString).cast(DateType).as(gf_undly_unadj_divd_valtn_date), lit(nullString).cast(DecimalType(twelve, four)).as(gf_trd_undly_asset_number),
        lit(nullString).cast(StringType).as(gf_undly_divd_pyt_cond_desc), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_undly_divd_pyt_ratio_per),
        lit(nullString).cast(StringType).as(gf_undly_am_depositary_rcpt_id), lit(nullString).cast(DateType).as(gf_underlying_maturity_date),
        lit(nullString).cast(StringType).as(gf_undly_prc_calc_meth_desc), lit(nullString).cast(StringType).as(g_undly_fx_rt_bc_id),
        lit(nullString).cast(StringType).as(g_undly_fx_rt_qcncy_id), lit(nullString).cast(StringType).as(gf_undly_prc_fxg_tme_bc_desc),
        lit(nullString).cast(StringType).as(gf_undly_prc_fxg_dt_bdc_desc), lit(nullString).cast(StringType).as(gf_undly_prc_fxg_tme_date),
        lit(nullString).cast(StringType).as(gf_undly_prc_fxg_drc_type), lit(nullString).cast(StringType).as(gf_undly_prc_fxg_p_freq_type),
        lit(nullString).cast(StringType).as(gf_undly_prc_fxg_p_freq_d_desc), lit(nullString).cast(StringType).as(gf_undly_fxg_p_end_dt_desc),
        lit(nullString).cast(StringType).as(gf_undly_fxg_p_strt_dt_desc), lit(nullString).cast(StringType).as(gf_undly_avg_prc_wgt_fctr_desc),
        lit(nullString).cast(StringType).as(gf_undly_prc_fxg_dt_desc), lit(nullString).cast(StringType).as(gf_undly_prc_fxg_amt_desc),
        lit(nullString).cast(StringType).as(gf_undly_prc_fxg_dt_bc_desc), lit(nullString).cast(StringType).as(gf_undly_prc_source_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_undly_avg_prc_amount), lit(nullString).cast(StringType).as(gf_undly_avg_prc_use_type),
        lit(nullString).cast(StringType).as(gf_undly_divd_pmtd_bdc_desc), lit(nullString).cast(DateType).as(gf_undly_unadj_divd_pmt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_undly_divd_amount), lit(nullString).cast(StringType).as(gf_undly_divd_dt_ref_cal_desc),
        lit(nullString).cast(StringType).as(gf_undly_divd_dt_ref_ofst_id), lit(nullString).cast(StringType).as(gf_undly_divd_pmt_ofst_d_desc),
        lit(nullString).cast(StringType).as(gf_undly_divd_reinv_ind_type), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_undly_divd_paid_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_undly_divd_reinv_per), lit(nullString).cast(StringType).as(gf_undly_exch_mkt_id),
        lit(nullString).cast(StringType).as(g_undly_asset_mtm_currency_id), lit(nullString).cast(StringType).as(gf_undly_ini_prc_meth_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_udl_ini_cln_net_prc_amount), lit(nullString).cast(StringType).as(gf_undly_dpsty_rcpt_ind_type),
        lit(nullString).cast(DateType).as(gf_undly_adj_setl_date), lit(nullString).cast(StringType).as(gf_undly_setl_typo_desc),
        lit(nullString).cast(DateType).as(gf_undly_unadj_setl_date), lit(nullString).cast(StringType).as(gf_undly_undly_id),
        lit(nullString).cast(StringType).as(gf_undly_undly_name), lit(nullString).cast(StringType).as(gf_undly_undly_murex_id),
        lit(nullString).cast(StringType).as(gf_undly_undly_bbg_id), lit(nullString).cast(StringType).as(gf_undly_undly_exch_mkt_id),
        lit(nullString).cast(StringType).as(gf_undly_undly_isin_id), lit(nullString).cast(StringType).as(gf_undly_undly_prd_typo_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_undly_undly_amount), lit(nullString).cast(StringType).as(g_undly_undly_curncy_id),
        lit(nullString).cast(DateType).as(gf_undly_undly_maty_date), col(g_call_put_option_type_aux).cast(StringType).as(g_call_put_option_type),
        col(g_exercise_option_type_aux).cast(StringType).as(g_exercise_option_type),
        col(g_option_exercise_freq_type_aux).cast(StringType).as(g_option_exercise_freq_type),
        lit(nullString).cast(DateType).as(gf_opt_unadj_eff_date), lit(nullString).cast(StringType).as(gf_opt_eff_date_bdc_desc),
        lit(nullString).cast(DateType).as(gf_opt_adj_eff_date)
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  private def secondPartLayout(data: DataFrame): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(nullString).cast(StringType).as(gf_opt_expiry_cut_name),
        lit(nullString).cast(StringType).as(g_opt_call_curncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_call_amount),
        lit(nullString).cast(StringType).as(g_opt_put_curncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_put_amount),
        lit(nullString).cast(DecimalType(twenty_six, sixteen)).as(gf_opt_prem_pmt_amount), lit(nullString).cast(StringType).as(gf_opt_prem_pmt_typo_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_prem_fnl_amount), lit(nullString).cast(StringType).as(g_opt_prem_pmt_curncy_id),
        lit(nullString).cast(StringType).as(gf_opt_prem_pmt_meth_desc), lit(nullString).cast(DateType).as(gf_opt_prem_unadj_pmt_date),
        lit(nullString).cast(StringType).as(gf_opt_prem_position_type), lit(nullString).cast(DateType).as(gf_opt_prem_adj_pmt_date),
        lit(nullString).cast(StringType).as(gf_opt_prem_pmt_bdc_desc), lit(nullString).cast(StringType).as(g_opt_prem_fx_rt_bc_id),
        lit(nullString).cast(StringType).as(g_opt_prem_fx_rt_qcncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_prem_fx_rt_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_prem_cnv_amount), lit(nullString).cast(StringType).as(g_opt_prem_cnv_curncy_id),
        lit(nullString).cast(DecimalType(twelve, four)).as(gf_trd_ini_opt_number), lit(nullString).cast(DecimalType(twelve, four)).as(gf_trd_curr_opt_number),
        lit(nullString).cast(DecimalType(twelve, four)).as(gf_undly_unit_opt_number),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_prem_opt_amount),
        lit(nullString).cast(StringType).as(g_trd_prem_amt_opt_curncy_id), lit(nullString).cast(StringType).as(gf_opt_unadj_ex_dt_desc),
        lit(nullString).cast(StringType).as(gf_opt_ex_date_bdc_desc), col(gf_opt_adj_ex_dt_desc_aux).cast(StringType).as(gf_opt_adj_ex_dt_desc),
        lit(nullString).cast(StringType).as(gf_opt_earliest_ex_date), lit(nullString).cast(StringType).as(gf_earliest_ex_bus_center_desc),
        lit(nullString).cast(StringType).as(gf_opt_latst_ex_date), lit(nullString).cast(StringType).as(gf_latst_ex_bus_center_desc),
        lit(nullString).cast(DateType).as(gf_am_opt_fst_ex_unadj_date), lit(nullString).cast(StringType).as(gf_am_opt_fst_ex_dt_bdc_desc),
        col(gf_am_opt_fst_ex_adj_date_aux).cast(DateType).as(gf_am_opt_fst_ex_adj_date), lit(nullString).cast(DateType).as(gf_am_opt_lst_ex_unadj_date),
        col(gf_am_opt_lst_ex_adj_date_aux).cast(DateType).as(gf_am_opt_lst_ex_adj_date), lit(nullString).cast(StringType).as(gf_am_opt_lst_ex_dt_bdc_desc),
        lit(nullString).cast(StringType).as(gf_ex_folup_cnfrm_ind_type), lit(nullString).cast(StringType).as(gf_option_fbck_ex_ind_type),
        lit(nullString).cast(DateType).as(gf_cmpnd_opt_unadj_ex_date), lit(nullString).cast(StringType).as(gf_cmpnd_opt_ex_dt_bdc_desc),
        lit(nullString).cast(DateType).as(gf_cmpnd_opt_adj_ex_date), lit(nullString).cast(StringType).as(gf_cmpnd_opt_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cmpnd_opt_strike_amount),
        lit(nullString).cast(StringType).as(gf_opt_auto_ex_ind_type),
        lit(nullString).cast(StringType).as(gf_dig_opt_ind_type),
        col(gf_option_strike_amount_aux).cast(DecimalType(twenty_six, six)).as(gf_option_strike_amount),
        lit(nullString).cast(StringType).as(gf_opt_strk_quote_basis_desc), lit(nullString).cast(StringType).as(g_opt_strk_curncy_id),
        lit(nullString).cast(StringType).as(gf_opt_strk_quotn_type), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_pyt_amount),
        lit(nullString).cast(StringType).as(gf_opt_pyt_frmul_desc), lit(nullString).cast(StringType).as(g_opt_pyt_curncy_id),
        lit(nullString).cast(StringType).as(g_opt_pyt_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_opt_pyt_fx_rt_qcncy_id),
        lit(nullString).cast(StringType).as(gf_dig_opt_pyt_styl_desc), lit(nullString).cast(StringType).as(gf_dig_opt_strk_cond_desc),
        lit(nullString).cast(StringType).as(gf_opt_cond_fnl_sessn_ind_type), lit(nullString).cast(StringType).as(gf_dig_opt_strk_drctn_desc),
        lit(nullString).cast(StringType).as(gf_dig_opt_sec_strk_drctn_desc), lit(nullString).cast(StringType).as(gf_dig_opt_sec_strk_cond_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_dig_opt_sec_strk_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_barrier_value_amount),
        lit(nullString).cast(StringType).as(gf_opt_barrier_typo_desc), lit(nullString).cast(StringType).as(gf_opt_barrier_scope_desc),
        lit(nullString).cast(StringType).as(gf_opt_brr_fnl_sessn_ind_type), lit(nullString).cast(StringType).as(gf_opt_brr_styl_desc),
        lit(nullString).cast(StringType).as(gf_opt_brr_dirctn_desc), lit(nullString).cast(StringType).as(gf_brr_undly_prc_fxg_srce_id),
        lit(nullString).cast(StringType).as(g_brr_undly_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_brr_undly_fx_rt_qcncy_id),
        lit(nullString).cast(StringType).as(gf_brr_undly_prc_fxg_dt_desc), lit(nullString).cast(DateType).as(gf_brr_undly_prc_fxg_end_date),
        lit(nullString).cast(DateType).as(gf_brr_undly_prc_fxg_strt_date), lit(nullString).cast(StringType).as(gf_brr_undly_prc_fxg_freq_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_brr_rbt_amount), lit(nullString).cast(StringType).as(g_opt_brr_rbt_curncy_id),
        lit(nullString).cast(StringType).as(gf_opt_brr_rbt_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_sec_brr_val_amount),
        lit(nullString).cast(StringType).as(gf_opt_sec_brr_typo_desc), lit(nullString).cast(StringType).as(gf_opt_sec_brr_dirctn_desc),
        lit(nullString).cast(StringType).as(gf_opt_sec_brr_scope_desc), lit(nullString).cast(StringType).as(gf_opt_sec_brr_styl_desc),
        lit(nullString).cast(DateType).as(gf_opt_sec_brr_fxg_end_date), lit(nullString).cast(DateType).as(gf_opt_sec_brr_fxg_strt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_sec_brr_rbt_amount), lit(nullString).cast(StringType).as(g_opt_sec_brr_rbt_curncy_id),
        lit(nullString).cast(StringType).as(gf_opt_sec_brr_rbt_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_thd_brr_val_amount),
        lit(nullString).cast(StringType).as(gf_opt_thd_brr_typo_desc), lit(nullString).cast(StringType).as(gf_opt_thd_brr_dirctn_desc),
        lit(nullString).cast(StringType).as(gf_opt_thd_brr_scope_desc), lit(nullString).cast(StringType).as(gf_opt_thd_brr_styl_desc),
        lit(nullString).cast(DateType).as(gf_opt_thd_brr_fxg_end_date), lit(nullString).cast(DateType).as(gf_opt_thd_brr_fxg_strt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_opt_thd_brr_rbt_amount), lit(nullString).cast(StringType).as(g_opt_thd_brr_rbt_curncy_id)
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  private def thirdPartLayout(data: DataFrame): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(nullString).cast(StringType).as(gf_opt_thd_brr_rbt_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_brr_val_amount),
        lit(nullString).cast(StringType).as(gf_sec_opt_brr_typo_desc), lit(nullString).cast(StringType).as(gf_sec_opt_brr_scope_desc),
        lit(nullString).cast(StringType).as(gf_sec_opt_brr_sessn_ind_type), lit(nullString).cast(StringType).as(gf_sec_opt_brr_styl_desc),
        lit(nullString).cast(DateType).as(gf_secop_brr_fxg_end_date), lit(nullString).cast(DateType).as(gf_secop_brr_fxg_strt_date),
        lit(nullString).cast(StringType).as(gf_secop_brr_prc_fxg_freq_type), lit(nullString).cast(StringType).as(gf_sec_opt_brr_dirctn_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_brr_rbt_amount), lit(nullString).cast(StringType).as(g_sec_opt_brr_rbt_curncy_id),
        lit(nullString).cast(StringType).as(gf_sec_opt_brr_rbt_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_sec_brr_val_amount),
        lit(nullString).cast(StringType).as(gf_sec_opt_sec_brr_typo_desc), lit(nullString).cast(StringType).as(gf_sec_opt_sec_brr_dirctn_desc),
        lit(nullString).cast(StringType).as(gf_sec_opt_sec_brr_scope_desc),
        lit(nullString).cast(StringType).as(gf_sec_opt_sec_brr_styl_desc),
        lit(nullString).cast(DateType).as(gf_sec_opt_sec_brr_end_date), lit(nullString).cast(DateType).as(gf_sec_opt_sec_brr_strt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_sec_brr_rbt_amount),
        lit(nullString).cast(StringType).as(g_secop_sec_brr_rbt_curncy_id),
        lit(nullString).cast(StringType).as(gf_sec_opt_sec_brr_rbt_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_thd_brr_val_amount),
        lit(nullString).cast(StringType).as(gf_sec_opt_thd_brr_typo_desc),
        lit(nullString).cast(StringType).as(gf_sec_opt_thd_brr_dirctn_desc),
        lit(nullString).cast(StringType).as(gf_sec_opt_thd_brr_scope_desc), lit(nullString).cast(StringType).as(gf_sec_opt_thd_brr_styl_desc),
        lit(nullString).cast(DateType).as(gf_sec_opt_thd_brr_end_date), lit(nullString).cast(DateType).as(gf_sec_opt_thd_brr_strt_date),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_opt_thd_brr_rbt_amount),
        lit(nullString).cast(StringType).as(g_secop_thd_brr_rbt_curncy_id),
        lit(nullString).cast(StringType).as(gf_sec_opt_thd_brr_rbt_desc), lit(nullString).cast(DateType).as(gf_opt_flt_strk_prc_fxg_date),
        lit(nullString).cast(StringType).as(g_opt_flt_strk_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_opt_flt_strk_fx_rt_qcncy_id),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_opt_flt_strk_prc_sprd_per), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_opt_flt_strk_sprd_amount),
        lit(nullString).cast(StringType).as(gf_fwd_strt_opt_styl_desc), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_fwd_strt_opt_strk_per),
        lit(nullString).cast(DateType).as(gf_fwd_strt_opt_strt_date), lit(nullString).cast(StringType).as(gf_warrant_label_desc),
        lit(nullString).cast(DecimalType(twelve, four)).as(gf_warrant_quantity_number), lit(nullString).cast(StringType).as(gf_accrl_opt_typo_desc),
        lit(nullString).cast(StringType).as(g_fst_stp_opt_call_curncy_id), lit(nullString).cast(StringType).as(g_fst_stp_opt_put_curncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_fst_stp_opt_notl_amount), lit(nullString).cast(StringType).as(g_fst_stp_opt_notl_curncy_id),
        lit(nullString).cast(StringType).as(gf_fst_stp_opt_strk_quot_desc), lit(nullString).cast(StringType).as(gf_fst_stp_opt_strk_amt_desc),
        lit(nullString).cast(StringType).as(gf_fst_stp_opt_strk_eff_desc), lit(nullString).cast(StringType).as(gf_fst_stp_opt_strk_cond_desc),
        lit(nullString).cast(StringType).as(gf_fst_stp_opt_eff_dt_desc), lit(nullString).cast(StringType).as(gf_fstp_opt_expr_dt_desc),
        lit(nullString).cast(StringType).as(gf_fstp_opt_nmnl_wgt_amt_desc), lit(nullString).cast(StringType).as(gf_fstp_opt_sec_strk_amt_desc),
        lit(nullString).cast(StringType).as(gf_fstp_opt_sec_strk_efdt_desc), lit(nullString).cast(StringType).as(gf_fstp_opt_sec_strk_cond_desc),
        lit(nullString).cast(StringType).as(g_sec_stp_opt_call_curncy_id), lit(nullString).cast(StringType).as(g_sec_stp_opt_put_curncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_stp_opt_notl_amount), lit(nullString).cast(StringType).as(g_sec_stp_opt_notl_curncy_id),
        lit(nullString).cast(StringType).as(gf_sec_stp_opt_strk_quot_desc), lit(nullString).cast(StringType).as(gf_sec_stp_opt_strk_amt_desc),
        lit(nullString).cast(StringType).as(gf_sec_stp_opt_strk_eff_desc), lit(nullString).cast(StringType).as(gf_sec_stp_opt_strk_cond_desc),
        lit(nullString).cast(StringType).as(gf_sec_stp_opt_sec_strk_desc), lit(nullString).cast(StringType).as(gf_sec_stp_sec_strk_efdt_desc),
        lit(nullString).cast(StringType).as(gf_sec_stp_sec_strk_cond_desc), lit(nullString).cast(StringType).as(gf_accrl_rgn_calc_type),
        lit(nullString).cast(StringType).as(gf_accrl_rgn_upbnd_dirctn_desc), lit(nullString).cast(StringType).as(gf_accrl_rgn_upbnd_val_desc),
        lit(nullString).cast(StringType).as(gf_accrl_rgn_lwbnd_dirctn_desc), lit(nullString).cast(StringType).as(gf_accrl_rgn_lwbnd_val_desc),
        lit(nullString).cast(StringType).as(gf_accrl_rgn_fctr_desc), lit(nullString).cast(StringType).as(gf_accrl_rgn_notl_curncy_desc),
        lit(nullString).cast(StringType).as(gf_accrl_rgn_notl_amount_desc), lit(nullString).cast(StringType).as(gf_opt_accr_rgn_notl_wgt_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_accrl_opt_accr_amount), lit(nullString).cast(StringType).as(g_accrl_opt_accr_curncy_id),
        lit(nullString).cast(StringType).as(gf_evgn_opt_ext_pd_type), lit(nullString).cast(DateType).as(gf_cncl_opt_fee_adj_pmt_date),
        lit(nullString).cast(DateType).as(gf_cncl_opt_fee_unadj_pmt_date), lit(nullString).cast(StringType).as(gf_cncl_opt_fee_pmtd_bdc_desc),
        lit(nullString).cast(StringType).as(gf_cncl_opt_brm_ex_fee_desc), lit(nullString).cast(StringType).as(gf_cncl_opt_brm_noex_fee_desc),
        lit(nullString).cast(StringType).as(gf_cncl_opt_brm_ex_unadj_desc), lit(nullString).cast(StringType).as(gf_cncl_opt_brm_ex_adj_desc),
        lit(nullString).cast(StringType).as(gf_cncl_opt_brm_ex_dt_bdc_desc), lit(nullString).cast(StringType).as(gf_cncl_opt_brm_ex_dt_bc_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cncl_opt_ex_fee_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_cncl_opt_non_ex_fee_amount),
        lit(nullString).cast(DateType).as(gf_cncl_opt_am_ex_adj_date), lit(nullString).cast(StringType).as(gf_cncl_opt_am_ex_dt_bdc_desc),
        lit(nullString).cast(DateType).as(gf_cncl_opt_am_ex_unadj_date), lit(nullString).cast(StringType).as(gf_cncl_opt_erlst_ex_dt_bc_id),
        lit(nullString).cast(StringType).as(gf_cncl_opt_erlst_ex_date), lit(nullString).cast(StringType).as(gf_cncl_opt_expir_dt_bdc_desc),
        lit(nullString).cast(DateType).as(gf_cncl_opt_expir_adj_date), lit(nullString).cast(DateType).as(gf_cncl_opt_expir_unadj_date),
        lit(nullString).cast(StringType).as(gf_cncl_opt_expir_time_bc_desc), lit(nullString).cast(StringType).as(gf_cncl_opt_expir_time_date),
        lit(nullString).cast(StringType).as(gf_cncl_opt_both_ex_ind_type), col(g_interest_rate_type_aux).cast(StringType).as(g_interest_rate_type),
        col(g_interest_pymt_frequency_type_aux).cast(StringType).as(g_interest_pymt_frequency_type), lit(nullString).cast(StringType).as(g_pmt_curncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_pmt_amount), lit(nullString).cast(StringType).as(gf_pmt_meth_typo_desc),
        lit(nullString).cast(DateType).as(gf_unadj_pmt_date), lit(nullString).cast(StringType).as(gf_pmt_dt_ref_cal_typo_desc),
        lit(nullString).cast(DateType).as(gf_adjusted_pmt_date), lit(nullString).cast(StringType).as(gf_pmt_dt_bdc_typo_desc),
        lit(nullString).cast(StringType).as(gf_pmt_dt_bus_center_id), lit(nullString).cast(StringType).as(gf_pmt_dt_frequency_type),
        lit(nullString).cast(StringType).as(gf_pmt_dt_roll_cvtn_typo_desc),
        col(gf_pmt_dt_ref_typo_desc_aux).cast(StringType).as(gf_pmt_dt_ref_typo_desc),
        lit(nullString).cast(StringType).as(gf_pmt_dt_ofst_id), lit(nullString).cast(StringType).as(gf_pmt_dt_ofst_day_typo_desc),
        lit(nullString).cast(StringType).as(gf_pmt_disc_float_rt_index_id), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_pmt_disc_rt_per),
        lit(nullString).cast(StringType).as(gf_pmt_disc_typology_desc), lit(nullString).cast(DateType).as(gf_upfront_pmt_date),
        col(gf_upfront_pmt_amount_aux).cast(DecimalType(twenty_six, six)).as(gf_upfront_pmt_amount),
        lit(nullString).cast(StringType).as(g_upfront_pmt_curncy_id),
        lit(nullString).cast(DateType).as(gf_first_initial_payment_date), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_ini_pmt_amount),
        lit(nullString).cast(StringType).as(g_ini_pmt_curncy_id), col(gf_fixed_rate_per_aux).cast(DecimalType(twelve, nine)).as(gf_fixed_rate_per),
        lit(nullString).cast(StringType).as(gf_flt_rt_calc_meth_typo_desc), lit(nullString).cast(StringType).as(gf_rt_calc_meth_label_desc),
        lit(nullString).cast(StringType).as(gf_flt_indx_calc_frmul_desc), lit(nullString).cast(StringType).as(gf_cmpnd_meth_typology_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_bps_sales_margin_amount), lit(nullString)
          .cast(DecimalType(twelve, nine)).as(gf_sales_margin_yield_per),
        lit(nullString).cast(StringType).as(gf_calc_basis_id), lit(nullString).cast(DecimalType(thirthy_eight, zero)).as(gf_calc_p_days_number),
        lit(nullString).cast(DateType).as(gf_fst_calc_p_unadj_start_date), lit(nullString).cast(StringType).as(gf_fst_calc_p_strt_dt_bdc_desc),
        lit(nullString).cast(DateType).as(gf_fst_calc_p_adj_start_date), lit(nullString).cast(DateType).as(gf_first_reg_calc_p_start_date),
        lit(nullString).cast(DateType).as(gf_last_reg_calc_p_end_date), lit(nullString).cast(StringType).as(gf_calc_p_bdc_typo_desc),
        lit(nullString).cast(StringType).as(gf_calc_p_dt_bc_desc), lit(nullString).cast(StringType).as(gf_calc_p_roll_cvtn_type),
        lit(nullString).cast(StringType).as(gf_stub_calc_p_dist_meth_desc), lit(nullString).cast(StringType).as(gf_calc_p_frequency_type),
        lit(nullString).cast(StringType).as(gf_calc_p_frequency_desc), lit(nullString).cast(StringType).as(gf_flt_rt_fxg_dt_ref_cal_desc),
        lit(nullString).cast(StringType).as(gf_flt_rt_fxg_ref_dt_ofst_id), lit(nullString).cast(StringType).as(gf_flt_rt_fxg_dt_ofst_day_desc),
        lit(nullString).cast(StringType).as(gf_flt_rt_fxg_dt_bdc_desc), lit(nullString).cast(StringType).as(gf_flt_rt_fxg_dt_bus_cntr_id),
        lit(nullString).cast(StringType).as(gf_flt_rt_fxg_dt_freq_type), lit(nullString).cast(StringType).as(gf_flt_rt_fxg_drc_cvtn_type),
        lit(nullString).cast(StringType).as(gf_amort_formula_desc), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_amort_notl_chng_per),
        lit(nullString).cast(StringType).as(gf_amort_notl_chng_relval_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_amort_notl_chng_amount),
        lit(nullString).cast(DateType).as(gf_amort_start_date), col(g_amortization_frequency_type_aux).cast(StringType).as(g_amortization_frequency_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_last_amortized_notl_amount), lit(nullString).cast(StringType).as(gf_amort_incl_mrgn_ind_type),
        lit(nullString).cast(StringType).as(gf_amort_dt_cpt_chg_ind_type), lit(nullString).cast(StringType).as(gf_amort_int_reinv_ind_type),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_amort_int_reinv_frac_per), lit(nullString).cast(StringType).as(gf_int_amt_full_pmt_ind_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_amort_ini_fixed_amount), lit(nullString).cast(StringType).as(g_amort_ini_fixed_curncy_id),
        lit(nullString).cast(StringType).as(gf_float_rt_index_id), lit(nullString).cast(StringType).as(gf_float_rt_index_tenor_id),
        lit(nullString).cast(StringType).as(gf_undly_float_rt_indx_id), lit(nullString).cast(StringType).as(gf_undly_float_rt_indx_tnr_id),
        lit(nullString).cast(StringType).as(gf_float_rt_indx_desc), col(gf_float_rt_ini_per_aux).cast(DecimalType(twelve, nine)).as(gf_float_rt_ini_per),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_float_rt_mult_ini_number), lit(nullString)
          .cast(DecimalType(twelve, nine)).as(gf_tl_disper_intrnl_calc_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_int_rate_spread_margin_per), col(gf_current_interest_rate_per_aux)
          .cast(DecimalType(twelve, nine)).as(gf_current_interest_rate_per),
        col(gf_net_life_cap_per_aux).cast(DecimalType(twelve, nine)).as(gf_net_life_cap_per), col(gf_net_life_floor_per_aux)
          .cast(DecimalType(twelve, nine)).as(gf_net_life_floor_per),
        lit(nullString).cast(StringType).as(gf_float_rt_rnd_type), lit(nullString).cast(DecimalType(teen, zero)).as(gf_float_rt_rnd_precn_number),
        lit(nullString).cast(StringType).as(g_float_rt_indx_curncy_id), lit(nullString).cast(StringType).as(gf_float_rt_indx_source_id),
        lit(nullString).cast(StringType).as(gf_digital_payoff_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_payout_amount),
        lit(nullString).cast(StringType).as(g_payout_curncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_buy_strike_price_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sell_strike_price_amount), lit(nullString).cast(StringType).as(gf_neg_float_rt_treat_desc),
        lit(nullString).cast(StringType).as(gf_pyt_floor_rt_incl_ind_type), lit(nullString).cast(StringType).as(gf_payout_cap_rt_incl_ind_type),
        lit(nullString).cast(StringType).as(gf_inflation_indx_type_name), lit(nullString).cast(StringType).as(gf_infltn_rt_basis_ind_type),
        lit(nullString).cast(StringType).as(gf_float_rt_payout_frmul_desc), lit(nullString).cast(StringType).as(gf_infltn_rt_calc_iplt_desc),
        lit(nullString).cast(StringType).as(gf_float_rt_indx_bk_frmul_desc), lit(nullString).cast(StringType).as(gf_float_rt_payout_typo_desc),
        lit(nullString).cast(StringType).as(gf_ini_stub_calc_p_indx_id), lit(nullString).cast(StringType).as(gf_ini_stub_calc_p_indx_tnr_id)
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  private def fourthPartLayout(data: DataFrame): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(nullString).cast(StringType).as(gf_ini_stub_calc_p_sec_indx_id), lit(nullString).cast(StringType).as(gf_ini_stub_p_sec_indx_tnr_id),
        lit(nullString).cast(StringType).as(gf_final_stub_calc_p_indx_id), lit(nullString).cast(StringType).as(gf_fnl_stub_calc_p_indx_tnr_id),
        lit(nullString).cast(StringType).as(gf_fnl_stub_calc_p_sec_indx_id), lit(nullString).cast(StringType).as(gf_fnl_stub_p_sec_indx_tnr_id),
        lit(nullString).cast(StringType).as(gf_trd_ini_cpt_exch_ind_type), lit(nullString).cast(StringType).as(gf_trd_fnl_cpt_exch_ind_type),
        lit(nullString).cast(StringType).as(gf_trd_intcap_exch_ind_type), lit(nullString).cast(StringType).as(g_int_flow_curncy_id),
        lit(nullString).cast(StringType).as(g_ini_cpt_exch_curncy_id), lit(nullString).cast(StringType).as(g_intcap_exch_curncy_id),
        lit(nullString).cast(StringType).as(g_fnl_capital_exch_curncy_id), lit(nullString).cast(StringType).as(gf_ini_cpt_fx_fxg_dt_ofst_id),
        lit(nullString).cast(StringType).as(gf_ini_cpt_fx_fxg_dt_ofst_desc), lit(nullString).cast(StringType).as(gf_ini_cpt_fx_fxg_dt_bdc_desc),
        lit(nullString).cast(StringType).as(gf_ini_cpt_fx_fxg_dt_bc_desc), lit(nullString).cast(StringType).as(gf_ini_cpt_fx_fxg_dt_cal_desc),
        lit(nullString).cast(StringType).as(gf_ini_cpt_fx_settl_rt_srce_id), lit(nullString).cast(StringType).as(gf_intcap_fx_fxg_dt_ofst_id),
        lit(nullString).cast(StringType).as(gf_intcap_fx_fxg_dt_ofst_desc), lit(nullString).cast(StringType).as(gf_intcap_fx_fxg_dt_bdc_desc),
        lit(nullString).cast(StringType).as(gf_intcap_fx_fxg_dt_bc_desc), lit(nullString).cast(StringType).as(gf_intcap_fx_fxg_dt_cal_desc),
        lit(nullString).cast(StringType).as(gf_intcap_fx_rt_settl_srce_id), lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_fxg_dt_ofst_id),
        lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_fxg_dt_ofst_desc), lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_fxg_dt_bdc_desc),
        lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_fxg_dt_bc_id), lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_fxg_dt_cal_desc),
        lit(nullString).cast(StringType).as(gf_fnl_cpt_fx_rt_settl_srce_id), lit(nullString).cast(StringType).as(gf_int_flw_fx_fxg_dt_ofst_id),
        lit(nullString).cast(StringType).as(gf_int_flw_fx_fxg_dt_ofst_desc), lit(nullString).cast(StringType).as(gf_int_flw_fx_fxg_dt_bdc_desc),
        lit(nullString).cast(StringType).as(gf_int_flw_fx_fxg_dt_bc_desc),
        lit(nullString).cast(StringType).as(gf_int_flw_fx_fxg_dt_cal_desc),
        lit(nullString).cast(StringType).as(gf_int_flw_settl_rt_srce_id), col(gf_swap_tenor_months_number_aux)
          .cast(DecimalType(eight, four)).as(gf_swap_tenor_months_number),
        col(g_day_count_convention_type_aux).cast(StringType).as(g_day_count_convention_type),
        col(g_compounding_frequency_type_aux).cast(StringType).as(g_compounding_frequency_type),
        col(g_renewal_frequency_type_aux).cast(StringType).as(g_renewal_frequency_type),
        col(g_reference_index_id_aux).cast(StringType).as(g_reference_index_id),
        col(g_amortization_type_aux).cast(StringType).as(g_amortization_type), lit(nullString).cast(StringType).as(gf_valtn_fnl_prc_meth_desc),
        lit(nullString).cast(StringType).as(gf_valtn_fnl_prc_dt_bdc_desc), lit(nullString).cast(StringType).as(gf_valtn_fnl_prc_dt_ref_bc_id),
        lit(nullString).cast(StringType).as(gf_valtn_fnl_prc_dt_ofst_id), lit(nullString).cast(StringType).as(gf_valtn_fnl_prc_ofst_day_desc),
        lit(nullString).cast(StringType).as(gf_adj_unit_prd_cond_desc), lit(nullString).cast(StringType).as(gf_return_swap_typo_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_tax_cr_divd_amount), lit(nullString).cast(StringType).as(gf_tax_cr_dt_ref_cal_desc),
        lit(nullString).cast(StringType).as(gf_tax_cr_dt_ref_ofst_id), lit(nullString).cast(StringType).as(gf_tax_cr_dt_ofst_day_desc),
        lit(nullString).cast(StringType).as(gf_tax_cr_reinv_ind_type), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_tax_cr_paid_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_tax_cr_reinv_per),
        col(gf_settl_amount_aux).cast(DecimalType(twenty_six, six)).as(gf_settl_amount),
        lit(nullString).cast(StringType).as(gf_settl_typo_desc), lit(nullString).cast(StringType).as(g_settl_curncy_id),
        lit(nullString).cast(StringType).as(g_settl_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_settl_fx_rt_qcncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_settl_fx_rt_amount), lit(nullString).cast(DateType).as(gf_settl_fx_rt_fxg_date),
        lit(nullString).cast(StringType).as(g_quanto_opt_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_quanto_opt_fx_rt_qcncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_quanto_opt_fx_rt_amount), lit(nullString).cast(StringType).as(gf_setl_calc_cvtn_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_setl_clean_prc_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_setl_dirty_prc_amount),
        lit(nullString).cast(DateType).as(gf_settl_limit_date), lit(nullString).cast(DateType).as(gf_unadj_settl_date),
        lit(nullString).cast(DateType).as(gf_adj_settl_date), lit(nullString).cast(StringType).as(gf_settl_bdc_desc),
        lit(nullString).cast(StringType).as(gf_settl_pmt_meth_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_setl_csh_transf_amount),
        lit(nullString).cast(StringType).as(g_csh_setl_transf_curncy_id), lit(nullString).cast(StringType).as(gf_setl_phys_transf_ast_id),
        lit(nullString).cast(DecimalType(sixteen, zero)).as(gf_setl_phys_transf_ast_number), lit(nullString).cast(StringType).as(g_ndlvr_settl_curncy_id),
        lit(nullString).cast(StringType).as(g_ndlvr_fx_rt_bc_id), lit(nullString).cast(StringType).as(g_ndlvr_fx_rt_qcncy_id),
        lit(nullString).cast(DateType).as(gf_ndlvr_fx_rt_fxg_date), lit(nullString).cast(StringType).as(gf_ndlvr_fx_fxg_dt_ofst_id),
        lit(nullString).cast(StringType).as(gf_ndlvr_fx_fxg_dt_bdc_desc), lit(nullString).cast(StringType).as(gf_ndlvr_fx_fxg_dt_cal_desc),
        lit(nullString).cast(StringType).as(gf_ndlvr_fx_rt_source_id), lit(nullString).cast(StringType).as(gf_ndlvr_fx_rt_source_page_id),
        lit(nullString).cast(StringType).as(g_csh_settl_curncy_id), lit(nullString).cast(StringType).as(gf_csh_settl_calc_rt_typo_desc),
        lit(nullString).cast(StringType).as(gf_csh_setl_accr_int_ind_type), lit(nullString).cast(DecimalType(five, zero)).as(gf_csh_setl_dt_ofst_d_number),
        lit(nullString).cast(StringType).as(gf_csh_setl_dt_ofst_d_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_csh_setl_ast_min_qtn_amount),
        lit(nullString).cast(StringType).as(g_csh_setl_ast_min_qcncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_csh_setl_ast_max_qtn_amount),
        lit(nullString).cast(StringType).as(g_csh_setl_ast_max_qcncy_id), lit(nullString).cast(StringType).as(gf_cs_ref_ast_qtn_desc),
        lit(nullString).cast(DecimalType(five, zero)).as(gf_cs_qtn_dtofd_number), lit(nullString).cast(StringType).as(gf_cs_qtn_dtofd_desc),
        lit(nullString).cast(StringType).as(gf_csh_setl_ast_qtn_freq_type), lit(nullString).cast(DecimalType(five, zero)).as(gf_csh_setl_ast_qtn_dt_number),
        lit(nullString).cast(StringType).as(gf_cs_fnl_prc_valtn_meth_desc), lit(nullString).cast(StringType).as(gf_csh_setl_ast_qtn_bc_desc),
        lit(nullString).cast(StringType).as(gf_cs_ref_ast_qtn_hms_date), lit(nullString).cast(StringType).as(gf_phys_settl_typo_desc),
        lit(nullString).cast(StringType).as(gf_clrhs_phys_settl_ind_type), lit(nullString).cast(StringType).as(gf_settl_dlvry_by_val_ind_type),
        lit(nullString).cast(DecimalType(five, zero)).as(gf_phys_setl_dt_ofst_d_number), lit(nullString).cast(StringType).as(gf_phys_setl_dt_ofst_d_desc),
        lit(nullString).cast(DecimalType(five, zero)).as(gf_ps_max_dtofd_number), lit(nullString).cast(StringType).as(gf_ps_max_dtofd_desc),
        lit(nullString).cast(StringType).as(gf_ps_oblg_aclt_ind_type), lit(nullString).cast(StringType).as(gf_phys_setl_accr_int_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvob_asgn_loan_ind_type), lit(nullString).cast(StringType).as(gf_dlvrbl_oblg_categ_desc),
        lit(nullString).cast(StringType).as(gf_loan_cnst_req_ind_type), lit(nullString).cast(StringType).as(gf_dlvob_loan_prtcp_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvob_dspu_rsln_ind_type), lit(nullString).cast(StringType).as(gf_dlvrbl_oblg_listed_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvrbl_oblg_maty_desc), lit(nullString).cast(StringType).as(gf_dlvob_not_bear_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvob_not_ctg_ind_type), lit(nullString).cast(StringType).as(gf_dlvob_not_paybl_lc_ind_type),
        lit(nullString).cast(StringType).as(g_dlvob_paybl_lc_id), lit(nullString).cast(StringType).as(gf_dlvob_intl_iss_ind_type),
        lit(nullString).cast(StringType).as(gf_oblg_not_subj_law_ind_type), lit(nullString).cast(StringType).as(gf_dlvob_not_svrgn_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvob_not_sbor_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvob_pari_passu_ind_type),
        lit(nullString).cast(StringType).as(gf_dlvrbl_oblg_curncy_desc), lit(nullString).cast(StringType).as(gf_dlvrbl_oblg_xferbl_ind_type),
        lit(nullString).cast(StringType).as(gf_ps_escr_agnt_ind_type), lit(nullString).cast(StringType).as(gf_cr_claus_position_type),
        lit(nullString).cast(StringType).as(gf_cr_claus_issuer_name), lit(nullString).cast(StringType).as(gf_cr_claus_srty_typo_desc),
        lit(nullString).cast(StringType).as(gf_cr_claus_undly_ptctn_desc), lit(nullString).cast(StringType).as(gf_cr_claus_ptctn_frmul_desc),
        lit(nullString).cast(StringType).as(gf_cc_grt_ref_oblg_id), lit(nullString).cast(DecimalType(five, zero)).as(gf_dflt_cvr_bk_min_oblg_number),
        lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_id_desc), lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_nom_desc),
        lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_nl_ccy_desc), lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_re_desc),
        lit(nullString).cast(StringType).as(gf_cc_no_ref_oblg_ind_type),
        lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_re_id_desc),
        lit(nullString).cast(StringType).as(gf_cc_grt_bk_oblg_srty_desc),
        lit(nullString).cast(DecimalType(nineteen, two)).as(gf_cc_trc_atch_point_per),
        lit(nullString).cast(DecimalType(nineteen, two)).as(gf_cc_trc_exht_point_per),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cc_trc_nom_amount),
        lit(nullString).cast(StringType).as(g_cc_trc_nom_curncy_id), lit(nullString).cast(StringType).as(gf_cc_ptctn_bc_desc),
        lit(nullString).cast(StringType).as(gf_cc_ptctn_terms_bdc_desc), lit(nullString).cast(DateType).as(gf_cc_ptctn_adj_eff_date),
        lit(nullString).cast(DateType).as(gf_cc_ptctn_unadj_eff_date), lit(nullString).cast(DateType).as(gf_cc_ptctn_adj_trmnt_date),
        lit(nullString).cast(DateType).as(gf_cc_ptctn_unadj_trmnt_date), lit(nullString).cast(StringType).as(gf_cc_revlv_ind_type),
        lit(nullString).cast(StringType).as(gf_re_thpty_oblg_trd_ind_type), lit(nullString).cast(StringType).as(gf_cc_oblg_ref_ent_id),
        lit(nullString).cast(StringType).as(gf_cc_ref_oblg_grt_isin_id),
        lit(nullString).cast(StringType).as(gf_cc_ref_oblg_issr_id),
        lit(nullString).cast(StringType).as(gf_cc_ref_oblg_srty_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cc_ref_oblg_prc_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cc_ptctn_nom_amount),
        lit(nullString).cast(StringType).as(g_cc_ptctn_nom_curncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cc_ptctn_curr_nom_amount),
        lit(nullString).cast(StringType).as(g_cc_ptctn_curr_nom_curncy_id),
        lit(nullString).cast(StringType).as(gf_cc_ptctn_bnkrpc_ind_type),
        lit(nullString).cast(DecimalType(five, zero)).as(gf_cr_evt_cnfrm_mn_srce_number),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cr_evt_dflt_min_amount), lit(nullString).cast(StringType).as(g_cr_evt_dflt_min_curncy_id),
        lit(nullString).cast(StringType).as(gf_cc_prtct_failr_pay_ind_type), lit(nullString).cast(StringType).as(gf_cc_ptctn_fp_gp_ind_type),
        lit(nullString).cast(StringType).as(gf_cc_failr_pay_gp_type), lit(nullString).cast(StringType).as(gf_failr_pay_cc_gp_day_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cr_evt_failr_pay_mn_amount),
        lit(nullString).cast(StringType).as(g_cr_failr_pay_mn_curncy_id),
        lit(nullString).cast(StringType).as(gf_cc_prtct_oblg_aclt_ind_type), lit(nullString).cast(StringType).as(gf_cc_prtct_oblg_dflt_ind_type),
        lit(nullString).cast(StringType).as(gf_cc_prtct_mrtm_rpdt_ind_type), lit(nullString).cast(StringType).as(gf_cc_prtct_rstru_ind_type),
        lit(nullString).cast(StringType).as(gf_cond_xferbl_rstru_ind_type), lit(nullString).cast(StringType).as(gf_rstru_mt_lmt_ind_type),
        lit(nullString).cast(StringType).as(gf_rstru_mult_hold_ind_type), lit(nullString).cast(StringType).as(gf_cc_oblg_catg_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_cc_dig_pmt_amount), lit(nullString).cast(DecimalType(twelve, nine)).as(gf_cc_dig_pmt_rt_per),
        lit(nullString).cast(DecimalType(twenty, two)).as(gf_cc_lvrg_fctr_amount), lit(nullString).cast(StringType).as(gf_cc_dflt_prtct_pmt_desc),
        lit(nullString).cast(StringType).as(gf_cc_prem_pmt_typo_desc), lit(nullString).cast(StringType).as(gf_cc_prem_pmt_calc_typo_desc),
        lit(nullString).cast(StringType).as(gf_cc_prem_pmt_nom_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_premium_npv_amount),
        lit(nullString).cast(StringType).as(g_uniq_issuer_id), lit(nullString).cast(StringType).as(g_uniq_issuer_name),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_sec_yield_per), col(gf_sec_irr_per_aux).cast(DecimalType(twelve, nine)).as(gf_sec_irr_per),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_clean_market_price_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_dirty_market_price_amount)
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  private def fifthPartLayout(data: DataFrame): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(nullString).cast(StringType).as(gf_sec_nego_prc_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_accr_cpn_int_amount),
        lit(nullString).cast(StringType).as(g_accr_cpn_int_curncy_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_captl_factor_amount),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_sec_all_in_price_per), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_sec_gross_prin_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_sec_net_prin_amount), lit(nullString).cast(StringType).as(gf_coupon_typology_desc),
        lit(nullString).cast(StringType).as(gf_instm_murex_generator_id), lit(nullString).cast(DecimalType(two, zero)).as(gf_sec_debt_auct_round_number),
        lit(nullString).cast(StringType).as(gf_sec_cmpt_auct_ind_type), lit(nullString).cast(StringType).as(gf_sec_amort_sngl_pmt_ind_type),
        lit(nullString).cast(StringType).as(gf_nego_sec_der_ind_type), lit(nullString).cast(DecimalType(teen, zero)).as(gf_secur_days_to_mt_number),
        lit(nullString).cast(StringType).as(gf_secur_cpn_transf_ind_type), lit(nullString).cast(StringType).as(gf_amortizable_secur_ind_type),
        lit(nullString).cast(StringType).as(gf_accr_cpn_settl_ind_type),
        col(gf_forward_price_amount_aux).cast(DecimalType(seventeen, two)).as(gf_forward_price_amount),
        lit(nullString).cast(StringType).as(gf_product_basket_id), lit(nullString).cast(StringType).as(gf_product_basket_typo_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_prin_gen_int_amount), lit(nullString).cast(DateType).as(gf_repo_callable_date),
        lit(nullString).cast(StringType).as(gf_repo_colat_int_dspch_desc), lit(nullString).cast(StringType).as(gf_repo_prin_fill_typo_desc),
        lit(nullString).cast(StringType).as(gf_repo_prin_alloc_typo_desc), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_repo_total_price_amount),
        lit(nullString).cast(DecimalType(teen, zero)).as(gf_repo_accr_cpn_days_number), lit(nullString)
          .cast(DecimalType(twelve, nine)).as(gf_trd_repo_accr_coupon_per),
        lit(nullString).cast(StringType).as(gf_reprice_frequency_type), lit(nullString).cast(DecimalType(teen, zero)).as(gf_ctpty_min_acpt_colat_number),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_repo_mrgn_hrcut_per), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_bps_repo_mrgn_hrcut_amount),
        lit(nullString).cast(StringType).as(gf_repo_mrgn_hrcut_base_desc), lit(nullString).cast(StringType).as(gf_repo_mrgn_hrcut_frmul_desc),
        lit(nullString).cast(DecimalType(teen, zero)).as(gf_repo_mrgn_factor_number), lit(nullString).cast(StringType).as(gf_repo_mrgn_typo_desc),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_repo_calc_fix_rt_per), lit(nullString).cast(StringType).as(gf_repo_mt_typo_desc),
        lit(nullString).cast(StringType).as(gf_repo_notc_p_type), lit(nullString).cast(StringType).as(gf_repo_notc_p_day_typo_desc),
        lit(nullString).cast(DateType).as(gf_op_repo_erlst_unadj_date), lit(nullString).cast(DateType).as(gf_op_repo_erlst_adj_date),
        lit(nullString).cast(StringType).as(gf_op_repo_erls_call_bdc_desc), lit(nullString).cast(StringType).as(gf_op_repo_call_ctpty_desc),
        lit(nullString).cast(StringType).as(gf_repo_colat_sbst_desc), lit(nullString).cast(StringType).as(gf_repo_colat_max_sbst_desc),
        lit(nullString).cast(StringType).as(gf_repo_colat_sbst_freq_type), lit(nullString).cast(StringType).as(gf_repo_duration_typo_desc),
        lit(nullString).cast(StringType).as(gf_repo_uncolat_ind_type), lit(nullString).cast(StringType).as(gf_colat_price_ref_indx_desc),
        lit(nullString).cast(StringType).as(gf_colat_prc_indx_ini_rt_desc), lit(nullString).cast(StringType).as(gf_colat_indx_ini_sprd_desc),
        lit(nullString).cast(StringType).as(gf_colat_accr_cpn_amt_desc), lit(nullString).cast(StringType).as(gf_colat_clean_price_amt_desc),
        lit(nullString).cast(StringType).as(gf_colat_dirty_price_amt_desc),
        col(gf_colat_nmnl_amt_desc_aux).cast(StringType).as(gf_colat_nmnl_amt_desc),
        lit(nullString).cast(StringType).as(g_colat_nmnl_amt_curncy_desc), lit(nullString).cast(StringType).as(gf_colat_secur_nbr_desc),
        lit(nullString).cast(StringType).as(gf_trd_colat_shr_desc), col(gf_colat_typo_desc_aux).cast(StringType).as(gf_colat_typo_desc),
        lit(nullString).cast(StringType).as(gf_colat_ownership_desc), lit(nullString).cast(StringType).as(gf_colat_dlvry_meth_type),
        lit(nullString).cast(StringType).as(gf_colat_ytm_price_mdl_desc), lit(nullString).cast(StringType).as(gf_collateral_ytm_desc),
        lit(nullString).cast(StringType).as(gf_colat_unit_price_desc), lit(nullString).cast(StringType).as(g_colat_unit_price_curncy_desc),
        lit(nullString).cast(StringType).as(gf_colat_setl_cln_prc_desc), lit(nullString).cast(StringType).as(gf_colat_setl_drty_prc_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_colat_haircut_amount), col(gf_collateral_isin_desc_aux)
          .cast(StringType).as(gf_collateral_isin_desc),
        lit(nullString).cast(StringType).as(gf_collateral_currency_id_desc), lit(nullString).cast(StringType).as(g_collateral_reuse_ind_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_colat_value_amount), lit(nullString).cast(StringType).as(gf_uncolat_sft_ind_type),
        lit(nullString).cast(StringType).as(gf_buy_currency_calc_basis_id), lit(nullString).cast(StringType).as(gf_sell_currency_calc_basis_id),
        lit(nullString).cast(StringType).as(g_forex_trade_buy_currency_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_forex_trade_buy_amount),
        lit(nullString).cast(StringType).as(g_forex_trade_sell_currency_id), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_forex_trade_sell_amount),
        lit(nullString).cast(DateType).as(gf_fx_trd_bc_delivery_date), lit(nullString).cast(DateType).as(gf_fx_trd_qcncy_delivery_date),
        lit(nullString).cast(StringType).as(gf_fx_trd_bc_pmt_meth_desc), lit(nullString).cast(StringType).as(gf_fx_trd_qcncy_pmt_meth_desc),
        lit(nullString).cast(DateType).as(gf_fx_trd_bc_value_date), lit(nullString).cast(DateType).as(gf_fx_trd_qcncy_value_date),
        lit(nullString).cast(StringType).as(g_fx_rt_base_curncy_id), lit(nullString).cast(StringType).as(g_fx_rt_quote_curncy_id),
        lit(nullString).cast(DecimalType(eighteen, twelve)).as(gf_exchange_rate_amount), lit(nullString)
          .cast(DecimalType(eighteen, twelve)).as(gf_fx_rt_margin_amount),
        lit(nullString).cast(DecimalType(eighteen, twelve)).as(gf_fx_rt_ctval_amount), lit(nullString)
          .cast(DecimalType(seventeen, twelve)).as(gf_fx_spot_exch_rate_amount),
        lit(nullString).cast(DateType).as(gf_spot_fx_rate_fxg_date), col(gf_fx_forward_exch_rate_amount_aux)
          .cast(DecimalType(seventeen, twelve)).as(gf_fx_forward_exch_rate_amount),
        lit(nullString).cast(StringType).as(g_trd_cross_rt_bc_id), lit(nullString).cast(StringType).as(g_trd_cross_rt_qcncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_cross_rt_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_trd_accr_coupon_amount),
        lit(nullString).cast(StringType).as(gf_float_rt_est_curve_id), lit(nullString).cast(StringType).as(gf_issuing_securities_name),
        lit(nullString).cast(TimestampType).as(gf_trade_repo_data_insert_date), lit(nullString).cast(StringType).as(g_mifid_undly_option_isin_id),
        lit(nullString).cast(StringType).as(gf_valtn_meth_disc_curve_name), lit(nullString).cast(DecimalType(twelve, four)).as(gf_trd_leg_asset_tot_number),
        lit(nullString).cast(StringType).as(gf_trd_fin_prod_secur_type), lit(nullString).cast(StringType).as(gf_product_ric_id),
        lit(nullString).cast(StringType).as(gf_cr_clause_label_desc), lit(nullString).cast(DateType).as(gf_trd_first_cshflw_date),
        lit(nullString).cast(StringType).as(gf_opt_pyt_type_desc), lit(nullString).cast(StringType).as(gf_opt_strk_qcncy_pair_id),
        lit(nullString).cast(DateType).as(gf_coupon_date), lit(nullString).cast(StringType).as(gf_fin_prod_secur_group_name),
        lit(nullString).cast(StringType).as(gf_fin_prod_secur_murex_id), lit(nullString).cast(StringType).as(g_murex_generator_curncy_id),
        lit(nullString).cast(StringType).as(g_ndf_fx_trd_ind_type), lit(nullString).cast(StringType).as(gf_fut_cont_secur_label_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_prem_amount), lit(nullString).cast(StringType).as(gf_nl_expressed_type),
        lit(nullString).cast(StringType).as(gf_spot_leg_colat_nl_amt_desc), lit(nullString).cast(StringType).as(gf_fwd_leg_colat_nl_amt_desc),
        lit(nullString).cast(StringType).as(g_spot_leg_clt_nl_amt_ccy_desc), lit(nullString).cast(StringType).as(g_fwd_leg_clt_nl_amt_ccy_desc),
        lit(nullString).cast(StringType).as(g_spot_leg_fx_bc_id), lit(nullString).cast(StringType).as(g_spot_leg_fx_qcncy_id),
        lit(nullString).cast(StringType).as(g_fwd_leg_fx_bc_id), lit(nullString).cast(StringType).as(g_fwd_leg_fx_qcncy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_spot_leg_exch_rate_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fwd_leg_exch_rate_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_spot_leg_sec_gs_prin_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fwd_leg_sec_gs_prin_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_spot_leg_settl_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fwd_leg_settl_amount),
        lit(nullString).cast(StringType).as(g_spot_leg_settl_amt_curncy_id), lit(nullString).cast(StringType).as(g_fwd_leg_settl_amt_curncy_id),
        lit(nullString).cast(StringType).as(g_spot_leg_settl_curncy_id), lit(nullString).cast(StringType).as(g_fwd_leg_settl_curncy_id),
        lit(nullString).cast(StringType).as(gf_spot_leg_settl_bdc_desc), lit(nullString).cast(StringType).as(gf_fwd_leg_settl_bdc_desc),
        lit(nullString).cast(DateType).as(gf_spot_leg_bdc_unstl_date), lit(nullString).cast(DateType).as(gf_fwd_leg_bdc_unstl_date),
        lit(nullString).cast(DateType).as(gf_spot_leg_bdc_adj_settl_date), lit(nullString).cast(DateType).as(gf_fwd_leg_bdc_adj_settl_date),
        lit(nullString).cast(StringType).as(gf_spot_leg_ps_tr_asset_id), lit(nullString).cast(StringType).as(gf_fwd_leg_ps_tr_asset_id),
        lit(nullString).cast(StringType).as(g_fx_swap_near_leg_buy_ccy_id), lit(nullString).cast(StringType).as(g_fx_swap_far_leg_buy_ccy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_fx_swap_near_leg_buy_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fx_swap_far_leg_buy_amount),
        lit(nullString).cast(StringType).as(g_fx_swap_near_leg_sell_ccy_id), lit(nullString).cast(StringType).as(g_fx_swap_far_leg_sell_ccy_id),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_fxs_near_leg_sell_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fxs_far_leg_sell_amount),
        lit(nullString).cast(StringType).as(g_fx_swap_near_leg_rt_bc_id), lit(nullString).cast(StringType).as(g_fx_swap_far_leg_rt_bc_id),
        lit(nullString).cast(StringType).as(g_fx_swap_near_leg_rt_qcncy_id), lit(nullString).cast(StringType).as(g_fx_swap_far_leg_rt_qcncy_id),
        lit(nullString).cast(DecimalType(eighteen, twelve)).as(gf_fx_swap_near_leg_exr_amount), lit(nullString)
          .cast(DecimalType(eighteen, twelve)).as(gf_fx_swap_far_leg_exr_amount),
        lit(nullString).cast(DecimalType(eighteen, twelve)).as(gf_fxs_near_leg_rt_mrgn_amount), lit(nullString)
          .cast(DecimalType(eighteen, twelve)).as(gf_fxs_far_leg_rt_mrgn_amount),
        lit(nullString).cast(StringType).as(g_fxs_nrlg_ndlvr_setl_ccy_id), lit(nullString).cast(StringType).as(g_fxs_frlg_ndlvr_setl_ccy_id),
        lit(nullString).cast(StringType).as(g_fxs_near_leg_cross_rt_bc_id), lit(nullString).cast(StringType).as(g_fxs_far_leg_cross_rt_bc_id),
        lit(nullString).cast(StringType).as(g_fxs_nrlg_cross_rt_qcncy_id), lit(nullString).cast(StringType).as(g_fxs_frlg_cross_rt_qcncy_id)
      )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }

  private def sixPartLayout(data: DataFrame, odate: String): DataFrame = {
    try {
      data.select(
        col("*"),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_fxs_nrlg_cross_rt_amount), lit(nullString)
          .cast(DecimalType(twenty_six, six)).as(gf_fxs_far_leg_cross_rt_amount),
        lit(nullString).cast(DateType).as(gf_fxs_nrlg_spot_rt_fxg_date), lit(nullString).cast(DateType).as(gf_fxs_frlg_spot_rt_fxg_date),
        lit(nullString).cast(StringType).as(gf_fxs_nrlg_bc_pmt_meth_desc), lit(nullString).cast(StringType).as(gf_fxs_frlg_bc_pmt_meth_desc),
        lit(nullString).cast(StringType).as(gf_fxs_nrlg_qcncy_pmt_desc), lit(nullString).cast(StringType).as(gf_fxs_frlg_qcncy_pmt_desc),
        lit(nullString).cast(DecimalType(eighteen, twelve)).as(gf_fxs_near_leg_rt_ctvl_amount), lit(nullString)
          .cast(DecimalType(eighteen, twelve)).as(gf_fxs_far_leg_rt_ctvl_amount),
        lit(nullString).cast(StringType).as(gf_fxs_nrlg_phys_settl_desc), lit(nullString).cast(StringType).as(gf_fxs_frlg_phys_settl_desc),
        lit(nullString).cast(StringType).as(g_fxs_nr_ndv_setl_rt_qcncy_id), lit(nullString).cast(StringType).as(g_fxs_fr_ndv_setl_rt_qcncy_id),
        lit(nullString).cast(StringType).as(gf_fxs_nr_ndlvr_setl_rt_src_id), lit(nullString).cast(StringType).as(gf_fxs_fr_ndlvr_setl_rt_src_id),
        lit(nullString).cast(DateType).as(gf_fxs_nr_ndv_setl_rt_fxg_date), lit(nullString).cast(DateType).as(gf_fxs_fr_ndv_setl_rt_fxg_date),
        lit(nullString).cast(StringType).as(g_fxs_near_leg_ndlvr_rt_bc_id), lit(nullString).cast(StringType).as(g_fxs_far_leg_ndlvr_rt_bc_id),
        lit(nullString).cast(DateType).as(gf_fxs_trd_frlg_value_date), lit(nullString).cast(DateType).as(gf_fxs_trd_nrlg_value_date),
        lit(nullString).cast(StringType).as(gf_phys_setl_sec_nom_amt_desc), lit(nullString).cast(StringType).as(gf_phys_setl_sec_isin_desc),
        lit(nullString).cast(StringType).as(gf_phys_setl_sec_ccy_desc), lit(nullString).cast(StringType).as(gf_underlying_sec_nom_amt_desc),
        lit(nullString).cast(StringType).as(gf_underlying_sec_isin_desc), lit(nullString).cast(StringType).as(gf_underlying_sec_ccy_desc),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_trd_lst_int_rate_per),
        col(gf_initial_interest_rate_per_aux).as(gf_initial_interest_rate_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_initial_spread_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_trd_last_spread_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_eff_haircut_per), lit(nullString).cast(StringType).as(gf_haircut_calc_type),
        lit(nullString).cast(StringType).as(gf_po_perspct_hct_drctn_type), lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_secur_notl_outstd_amount),
        lit(nullString).cast(StringType).as(gf_inv_clt_auto_alloc_ind_type), lit(nullString).cast(StringType).as(gf_ctp_choose_clt_bnd_ind_type),
        lit(nullString).cast(StringType).as(gf_trd_trmnt_type_desc), lit(nullString).cast(StringType).as(gf_trd_rdm_aplcnt_type),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_hct_trd_udl_iss_dprc_amount),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_udl_sec_dprc_amount),
        lit(nullString).cast(StringType).as(gf_year_id),
        lit(nullString).cast(DecimalType(six, zero)).as(gf_month_number),
        lit(nullString).cast(DecimalType(six, zero)).as(gf_day_number),
        col(g_trade_position_type_aux).as(g_trade_position_type),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_repo_internal_int_rate_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_repo_internal_sprd_rate_per),
        lit(nullString).cast(StringType).as(gf_trd_colat_prod_desc),
        lit(nullString).cast(StringType).as(gf_collateral_current_ir_desc),
        lit(nullString).cast(StringType).as(gf_collateral_initial_ir_desc),
        lit(nullString).cast(StringType).as(gf_clt_int_cal_pds_freq_desc),
        lit(nullString).cast(StringType).as(gf_clt_int_change_date_desc),
        lit(nullString).cast(StringType).as(gf_collateral_fixing_freq_desc),
        lit(nullString).cast(StringType).as(gf_collateral_apply_ir_type),
        col(gf_ref_index_interest_rate_per_aux).as(gf_ref_index_interest_rate_per),
        lit(nullString).cast(DateType).as(gf_trd_leg_int_chng_next_date),
        lit(nullString).cast(StringType).as(gf_amortization_id),
        lit(nullString).cast(StringType).as(gf_current_trd_contract_id),
        lit(nullString).cast(StringType).as(gf_management_portfolio_id),
        lit(nullString).cast(StringType).as(gf_financial_asset_class_type),
        lit(nullString).cast(StringType).as(gf_fin_product_group_type),
        lit(nullString).cast(StringType).as(gf_fin_product_sub_group_type),
        lit(nullString).cast(StringType).as(gf_trd_flex_tmpl_id),
        lit(nullString).cast(StringType).as(gf_trd_flex_tmpl_desc),
        lit(nullString).cast(StringType).as(gf_fin_product_typo_desc),
        lit(nullString).cast(StringType).as(gf_financial_product_desc),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_lot_size_number),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_trd_instm_qty_number),
        lit(nullString).cast(DecimalType(twenty_six, six)).as(gf_first_fixing_amount),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_sales_margin_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_corporate_margin_per),
        lit(nullString).cast(DecimalType(twelve, nine)).as(gf_net_margin_per),
        lit(nullString).cast(StringType).as(gf_schedule_generator_id),
        lit(nullString).cast(StringType).as(gf_fxg_date_ref_dt_typo_desc),

        lit(odate.replace("-", emptyString)).as(gf_odate_date_id),
        current_timestamp.as(gf_audit_date),
        concat(lit(odate.replace("-", emptyString)),
          lit(Random.alphanumeric take 11 mkString)).as(gf_run_id)
      )
        .drop(
          gf_origin_application_id_aux, gf_front_sys_name_aux, gf_front_sys_trd_id_aux,
          gf_back_sys_trd_id_aux, gf_trd_leg_id_aux, gf_trd_phase_id_aux, gf_trd_leg_adj_eff_date_aux,
          gf_trd_leg_adj_trmnt_date_aux, gf_trd_phase_adj_eff_date_aux, gf_trd_phase_adj_trmnt_date_aux,
          gf_underlying_amount_aux, gf_settl_amount_aux, gf_trd_party_payer_recv_type_aux, g_undly_asset_isin_id_aux, g_call_put_option_type_aux,
          g_exercise_option_type_aux,
          g_option_exercise_freq_type_aux, gf_opt_adj_ex_dt_desc_aux,
          gf_am_opt_fst_ex_adj_date_aux, gf_option_strike_amount_aux,
          g_interest_rate_type_aux, g_interest_pymt_frequency_type_aux, gf_pmt_dt_ref_typo_desc_aux,
          gf_upfront_pmt_amount_aux, gf_fixed_rate_per_aux, g_amortization_frequency_type_aux,
          gf_float_rt_ini_per_aux, gf_current_interest_rate_per_aux, gf_net_life_cap_per_aux,
          gf_net_life_floor_per_aux, gf_swap_tenor_months_number_aux, g_day_count_convention_type_aux,
          g_compounding_frequency_type_aux, g_renewal_frequency_type_aux, g_reference_index_id_aux,
          g_amortization_type_aux, gf_forward_price_amount_aux, gf_fx_forward_exch_rate_amount_aux,
          gf_am_opt_lst_ex_adj_date_aux, gf_local_contract_number_id_aux, gf_sec_irr_per_aux, gf_colat_typo_desc_aux,
          gf_collateral_isin_desc_aux, gf_colat_nmnl_amt_desc_aux,
          gf_initial_interest_rate_per_aux,
          g_trade_position_type_aux,
          gf_ref_index_interest_rate_per_aux
        )
    } catch {
      case e: Exception => ExceptionUtils.getStackTrace(e)
        throw e
    }
  }


}
// Out:
// defined trait LayoutTradeProd
// ...

// %%
// Out:
// usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
//            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
//            [-p | --paginate | --no-pager] [--no-replace-objects] [--bare]
//            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
//            <command> [<args>]
//
// These are common Git commands used in various situations:
//
// start a working area (see also: git help tutorial)
//    clone      Clone a repository into a new directory
//    init       Create an empty Git repository or reinitialize an existing one
//
// work on the current change (see also: git help everyday)
//    add        Add file contents to the index
//    mv         Move or rename a file, a directory, or a symlink
//    reset      Reset current HEAD to the specified state
//    rm         Remove files from the working tree and from the index
//
// examine the history and state (see also: git help revisions)
// ...

// %% [markdown]
// ## Layout

// %%
dsfsdfsdfsdf

// %%
import Constants._
import org.apache.spark.sql.functions.broadcast
import org.apache.spark.sql.SparkSession

val spark = SparkSession
    .builder()
    .appName("NztgTradeProd")
    .config("spark.some.config.option", "CDD")
    .getOrCreate()

val odate = "2022-06-30"
val hdate = "2022-06-30"

val catalog = new Catalog(spark)
val input = new InputReader(spark, hdate, odate)
val process = new Process(hdate) with LayoutTradeProd
val tsiTables = new ReadTsiTables(spark, hdate)

// Catálogos
val catalogOptionType = broadcast(catalog.catalogOptionType(path_t_ktny_catalog_values_taxonomy))
val catalogApp = broadcast(catalog.catalogApp(path_t_ktny_catalog_values_taxonomy))
val catalogPrev = broadcast(catalog.catalogPrev())
      val catalogPrsPcv = broadcast(catalog.catalogPrsPcv(path_t_ktny_catalog_values_taxonomy))
      val rentaFijaOpeBis = input.readRentaFijaOpeBis(path_t_mdco_renta_fija_ope_bis)
      val tsiContraparte = tsiTables.readTsiContraparte(path_t_mdco_tsi028_contraparte)
      val guaranteeCore = input.readGuaranteeCore(path_t_mdco_guarantee_core)
      val productsIntRateOptions = input.readProductsIntRateOptions(path_t_mdco_products_int_rate_options)
      val forwardIntRateProducts = input.readForwardIntRateProducts(path_t_mdco_forward_int_rate_products)
      val tsiSwapsTasa = tsiTables.readTsiSwapsTasa(path_t_mdco_tsi011_swaps_tasa)
      val tsiSwapsIv = tsiTables.readTsiSwapsIv(path_t_mdco_tsi013_swaps_iv)
      val tsiSwapsCre = tsiTables.readTsiSwapsCre(path_t_mdco_tsi014_swaps_cre)
      val tsiOperacion = tsiTables.readTsiOperacion(path_t_mdco_tsi001_operacion)
      val dataCountConvention = input.dataCountConvention(productsIntRateOptions, forwardIntRateProducts, tsiSwapsTasa, tsiSwapsIv, tsiSwapsCre)
      val tsiSwapsDiv = tsiTables.readTsiSwapsDiv(path_t_mdco_tsi012_swaps_div)
      val internalOperMurex = input.readInternalOperMurex(path_t_mdco_internal_oper_murex)
      val sireFxPrdt = input.readSireFxPrdt(path_t_mdco_sire_fx_prdt)
      val tsiFwdDiv = tsiTables.readTsiFwdDiv(path_t_mdco_tsi009_fwd_div)
      val derivadosMmooBis = input.readDerivadosMmooBis(path_t_mdco_derivados_mmoo_bis)
      val tsiOperacionMmo = tsiTables.readTsiOperacionMmo(path_t_mdco_tsi001_operacion)
      val finDervOtcBis = input.readFinDervOtcBis(path_t_mdco_fin_derv_otc_bis)
      val internalOperMurexDepos = input.readInternalOperMurexDepos(path_t_mdco_internal_oper_murex)
      val liquidityFlowsOverSwap = input.readLiquidityFlowsOverSwap(path_t_mrdc_liquidity_flows_over_swap)
      val liquidityFlowsOverSwapAux = input.readliquidityFlowsOverSwapAux(path_t_mrdc_liquidity_flows_over_swap)
      val tsiOpcionDiv = tsiTables.readTsiOpcionDiv(path_t_mdco_tsi004_opcion_div)
      val liqOverRateOptions = input.readLiqOverRateOptions(path_t_mdco_liq_over_rate_options)
      val liqOverRateOptionsOpt = input.readLiqOverRateOptionsOpt(path_t_mdco_liq_over_rate_options)
      val subproductCfc = input.subproductCfc(tsiOperacion, liqOverRateOptionsOpt)
      val tsiEconomicData = input.tsiEconomicData(tsiSwapsIv, tsiSwapsCre, tsiSwapsTasa, productsIntRateOptions, forwardIntRateProducts)
      val tsiEconomicDataSwaps = input.tsiEconomicDataSwaps(tsiSwapsDiv, internalOperMurex)
      val tsiEconomicDataSwapsOpc = input.tsiEconomicDataSwapsOpc(liqOverRateOptions, liquidityFlowsOverSwap)
      val activeOperationsEconomicData = input.activeOperationsEconomicData(tsiOperacion, tsiEconomicData, tsiEconomicDataSwapsOpc, liquidityFlowsOverSwapAux)
      val activeOperationsEconomicDataSwaps = input.activeOperationsEconomicDataSwaps(tsiOperacion, tsiEconomicDataSwaps, tsiOpcionDiv,
        liquidityFlowsOverSwapAux)
      val activeOperations = input.activeOperations(activeOperationsEconomicData, activeOperationsEconomicDataSwaps)
      val tsiOperacionOtc = input.readTsiOperacionOtc(path_t_mdco_tsi001_operacion)
      val tsiDepositos = input.readTsiDepositos(path_t_mrdc_tsi016_depositos)
      val fixedRent =  process.fixedRent(rentaFijaOpeBis, tsiContraparte, dataCountConvention, catalogApp, catalogPrsPcv, guaranteeCore)
      val forexTrading = process.forexTrading(sireFxPrdt, tsiOperacion, tsiFwdDiv, catalogApp, catalogPrsPcv, guaranteeCore, catalogPrev)
      val organizedMarkets = process.organizedMarkets(derivadosMmooBis, tsiOperacion, tsiSwapsTasa, tsiOperacionMmo, catalogOptionType,
        catalogApp, guaranteeCore, catalogPrev)
      val overTheCounter = process.overTheCounter(finDervOtcBis, activeOperations, catalogOptionType, subproductCfc, catalogApp, tsiOperacionOtc,
        guaranteeCore, catalogPrev)
      val deposits = process.deposits(internalOperMurexDepos, tsiOperacion, tsiDepositos, guaranteeCore, catalogPrev)

// Trade Prod
val prevTradeProd = process.tradeProd(fixedRent, forexTrading, organizedMarkets, overTheCounter, deposits)


// Layout Trade Prod
val tradeProd = process.finalLayout(prevTradeProd, odate)
// Out:
// spark = org.apache.spark.sql.SparkSession@1a42a60
// odate = 2022-06-30
// hdate = 2022-06-30
// catalog = Catalog@61d9f62e
// input = InputReader@41fdc92d
// process = $anon$1@151bddc4
// tsiTables = ReadTsiTables@354c022d
// catalogOptionType = [gf_catalog_val_id: string, gf_catlg_field_value_es_desc: string]
// catalogApp = [id: string, value: string]
// catalogPrev = [local_type: string, holding_type: string ... 1 more fie...
// [local_type: string, holding_type: string ... 1 more fie...

// %%
tradeProd.write.mode("overwrite")
.parquet(s"/data/sandboxes/m6hn/data/projects/cdd/modelo/nztg/data/t_nztg_trade_prod_inf_bo_eom/g_entific_id=MX/gf_cutoff_date=$odate")
